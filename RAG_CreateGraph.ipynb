# %% [markdown]
# # Installation Requirements
#
# *   [Neo4j](https://neo4j.com/) is used as the underlying graph vector database.
# *   Langchain is used to orchestrate the database and LLM for final output.
# *   This notebook aims to parse all blogs and construct a knowledge graph of the text data with embeddings.

# %%
# !pip install neo4j
# !pip install langchain
# !pip install langchain_community
# !pip install transformers torch
# !pip install emoji
# !pip install python-dotenv
# Out:
# Collecting neo4j
#   Downloading neo4j-5.25.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from neo4j) (2024.2)
# Downloading neo4j-5.25.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.6/296.6 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: neo4j
# Successfully installed neo4j-5.25.0
# Collecting langchain
#   Downloading langchain-0.3.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.12 (from langchain)
#   Downloading langchain_core-0.3.12-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.137-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.12->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.4 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.3.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.0 MB/s eta 0:00:00
# Downloading langchain_core-0.3.12-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 30.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.137-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 26.5 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 8.1 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 14.8 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.5 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: orjson, jsonpointer, h11, requests-toolbelt, jsonpatch, httpcore, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.4 langchain-core-0.3.12 langchain-text-splitters-0.3.0 langsmith-0.1.137 orjson-3.10.10 requests-toolbelt-1.0.0
# Collecting langchain_community
#   Downloading langchain_community-0.3.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.10.10)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.3.4)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.3.12)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.6.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.4->langchain_community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.4->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.4->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.4->langchain_community) (2.23.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.2.2)
# Downloading langchain_community-0.3.3-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading pydantic_settings-2.6.0-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, typing-inspect, pydantic-settings, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain_community-0.3.3 marshmallow-3.23.0 mypy-extensions-1.0.0 pydantic-settings-2.6.0 python-dotenv-1.0.1 typing-inspect-0.9.0
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=14b5c9aa47a07b0d928140740de60ca3efaa4b8657001b14ef0dc7e8f03710d8
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %% [markdown]
# # Text Preprocessing

# %%
WORDLIMIT = 50 # text blocks with less than 50 words are ignored

# %%
import emoji

def remove_emoji(text):
    return emoji.replace_emoji(text, replace='')  # Replace emoji with an empty string

#basic funtion to remove emoji and non-breaking space
def text_cleaning(text_list):
    new_list = []
    for text in text_list:
        if len(text.split()) > WORDLIMIT:
            text = remove_emoji(text)
            text = text.replace('\xa0', '')
            new_list.append(text)
    return new_list

# %% [markdown]
# # Create KG

# %% [markdown]
# ## Setting up vector database

# %%
from langchain_community.graphs import Neo4jGraph
from langchain_community.vectorstores import Neo4jVector
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQAWithSourcesChain
from neo4j import GraphDatabase
from dotenv import load_dotenv
import os

# %%
#Parameters to connect Neo4j graph database
load_dotenv('.env', override=True)
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')
NEO4J_DATABASE = os.getenv('NEO4J_DATABASE')
AUTH = (NEO4J_DATABASE, NEO4J_PASSWORD)



with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

# %%
kg = Neo4jGraph(
    url=NEO4J_URI, username=NEO4J_USERNAME, password=NEO4J_PASSWORD, database=NEO4J_DATABASE
)

# %% [markdown]
# ## Embeddings

# %%
import torch
from transformers import BertTokenizer, BertModel

# Load the NB-BERT model and tokenizer
model_name = "NbAiLab/nb-bert-base"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# Ensure the model is in evaluation mode
model.eval()

def get_embeddings(texts):
    # Tokenize the input texts
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")

    # Move inputs to the appropriate device (GPU if available)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    inputs = {key: val.to(device) for key, val in inputs.items()}
    model.to(device)

    # Generate embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Get the embeddings from the last hidden state
    embeddings = outputs.last_hidden_state

    # Return the mean of the embeddings for each sentence
    return torch.mean(embeddings, dim=1).cpu().numpy()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %% [markdown]
# ## Create nodes (Blog, Chunk) and relationships (Next, Part of)
#
#
# Rules to construct the knowledge graph:
# *   A Blog node is created for each blog.
# *   Blog nodes have properties: title, time, label, source, id, and intro.
# *   Each blog is splitt into several chunks and a chunk node is created for each chunk.
# *   Chunk nodes have properties: id, sequence_id, title, text, embedding (vector property).
# *   PART_OF relationship is established for each blog node and all its chunk nodes.
# *   The consecutive chunks are connected with NEXT relationship.
#
#
#
# The JSON file look like this:
#
#     "label": "Prosess og rådgivning",
#
#     "source": "https://www.kantega.no/blogg/komplekst-prosjekt-hva-na",
#
#     "title": "Komplekst prosjekt, hva nå?",
#
#     "time": "2019-10-25 03:00",
#
#     "intro": "Vi har testet ut et samtaleverktøy for å snakke om kompleksitetene i prosjekter... ",
#
#     "text": [
#         "Vi har testet ut et samtaleverktøy for å snakke om kompleksitetene i prosjekter...",
#
#         "Introduksjon og bakgrunnDet var en tidlig mai-morgen og ..."
#
#     ]

# %%
import json

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 512,
    chunk_overlap  = 50,
    length_function = len,
    is_separator_regex = False,
)

def chunk_data_from_file(filepath, file_id):
    blog_with_metadata = {}
    chunks_with_metadata = [] # use this to accumlate chunk records
    doc_title = os.path.basename(filepath)
    # Open the JSON file
    with open(filepath, 'r') as file:
        data = json.load(file)  # Load the JSON data into a Python object
        blog_with_metadata['label'] = data['label']
        blog_with_metadata['title'] = data['title']
        blog_with_metadata['source'] = data['source']
        blog_with_metadata['time'] = data['time']
        blog_with_metadata['intro'] = data['intro']
        blog_with_metadata['fileId'] = file_id

        text_list = text_cleaning(data['text'])
        chunk_seq_id = 0
        for text in text_list:
            doc_chunks = text_splitter.split_text(text)
            for chunk in doc_chunks:
                chunks_with_metadata.append({
                    'text': chunk,
                    'chunkSeqId': chunk_seq_id,
                    # constructed metadata...
                    'fileId': f'{file_id}', # pulled from the filename
                    'chunkId': f'{file_id}-chunk{chunk_seq_id:04d}',
                    # metadata from file...
                    'title': doc_title.replace(".json",""),
                    'textEmbedding': get_embeddings(chunk),
                })
                chunk_seq_id += 1
            print(f'\tSplit into {chunk_seq_id} chunks')
    return blog_with_metadata, chunks_with_metadata

# %%
import os
import glob


filepath = '/content/drive/MyDrive/Projects/rag/json_data2/'
doc_files = glob.glob(os.path.join(filepath, "*.json"))

file_id = 0
all_blogs = []
all_chunks = []
for doc in doc_files:
    blog, doc_chunks = chunk_data_from_file(doc, file_id)
    all_blogs.append(blog)
    all_chunks.extend(doc_chunks)
    file_id += 1
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 	Split into 1 chunks
# 	Split into 20 chunks
# 	Split into 8 chunks
# 	Split into 1 chunks
# 	Split into 18 chunks
# 	Split into 11 chunks
# 	Split into 1 chunks
# 	Split into 22 chunks
# 	Split into 33 chunks
# 	Split into 25 chunks
# 	Split into 1 chunks
# 	Split into 16 chunks
# 	Split into 14 chunks
# 	Split into 20 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 27 chunks
# 	Split into 28 chunks
# 	Split into 14 chunks
# 	Split into 5 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 41 chunks
# 	Split into 1 chunks
# 	Split into 25 chunks
# 	Split into 16 chunks
# 	Split into 15 chunks
# 	Split into 24 chunks
# 	Split into 1 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 35 chunks
# 	Split into 25 chunks
# 	Split into 5 chunks
# 	Split into 17 chunks
# 	Split into 1 chunks
# 	Split into 23 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 11 chunks
# 	Split into 16 chunks
# 	Split into 9 chunks
# 	Split into 30 chunks
# 	Split into 22 chunks
# 	Split into 1 chunks
# 	Split into 17 chunks
# 	Split into 13 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 2 chunks
# 	Split into 17 chunks
# 	Split into 1 chunks
# 	Split into 24 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 5 chunks
# 	Split into 18 chunks
# 	Split into 21 chunks
# 	Split into 1 chunks
# 	Split into 17 chunks
# 	Split into 1 chunks
# 	Split into 30 chunks
# 	Split into 15 chunks
# 	Split into 1 chunks
# 	Split into 34 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 21 chunks
# 	Split into 1 chunks
# 	Split into 21 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 20 chunks
# 	Split into 1 chunks
# 	Split into 12 chunks
# 	Split into 13 chunks
# 	Split into 17 chunks
# 	Split into 1 chunks
# 	Split into 29 chunks
# 	Split into 22 chunks
# 	Split into 1 chunks
# 	Split into 20 chunks
# 	Split into 9 chunks
# 	Split into 20 chunks
# 	Split into 25 chunks
# 	Split into 17 chunks
# 	Split into 21 chunks
# 	Split into 13 chunks
# 	Split into 14 chunks
# 	Split into 15 chunks
# 	Split into 10 chunks
# 	Split into 15 chunks
# 	Split into 2 chunks
# 	Split into 18 chunks
# 	Split into 9 chunks
# 	Split into 18 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 18 chunks
# 	Split into 1 chunks
# 	Split into 12 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 17 chunks
# 	Split into 7 chunks
# 	Split into 2 chunks
# 	Split into 19 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 22 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 39 chunks
# 	Split into 5 chunks
# 	Split into 6 chunks
# 	Split into 6 chunks
# 	Split into 19 chunks
# 	Split into 1 chunks
# 	Split into 10 chunks
# 	Split into 18 chunks
# 	Split into 1 chunks
# 	Split into 26 chunks
# 	Split into 1 chunks
# 	Split into 8 chunks
# 	Split into 10 chunks
# 	Split into 50 chunks
# 	Split into 1 chunks
# 	Split into 17 chunks
# 	Split into 3 chunks
# 	Split into 2 chunks
# 	Split into 16 chunks
# 	Split into 4 chunks
# 	Split into 3 chunks
# 	Split into 1 chunks
# 	Split into 30 chunks
# 	Split into 20 chunks
# 	Split into 4 chunks
# 	Split into 14 chunks
# 	Split into 4 chunks
# 	Split into 10 chunks
# 	Split into 11 chunks
# 	Split into 1 chunks
# 	Split into 20 chunks
# 	Split into 3 chunks
# 	Split into 18 chunks
# 	Split into 36 chunks
# 	Split into 13 chunks
# 	Split into 17 chunks
# 	Split into 17 chunks
# 	Split into 7 chunks
# 	Split into 32 chunks
# 	Split into 1 chunks
# 	Split into 21 chunks
# 	Split into 32 chunks
# 	Split into 13 chunks
# 	Split into 7 chunks
# 	Split into 10 chunks
# 	Split into 4 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 26 chunks
# 	Split into 1 chunks
# 	Split into 31 chunks
# 	Split into 6 chunks
# 	Split into 4 chunks
# 	Split into 7 chunks
# 	Split into 12 chunks
# 	Split into 31 chunks
# 	Split into 18 chunks
# 	Split into 24 chunks
# 	Split into 29 chunks
# 	Split into 1 chunks
# 	Split into 28 chunks
# 	Split into 1 chunks
# 	Split into 33 chunks
# 	Split into 1 chunks
# 	Split into 41 chunks
# 	Split into 10 chunks
# 	Split into 20 chunks
# 	Split into 1 chunks
# 	Split into 12 chunks
# 	Split into 13 chunks
# 	Split into 15 chunks
# 	Split into 1 chunks
# 	Split into 32 chunks
# 	Split into 9 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 11 chunks
# 	Split into 1 chunks
# 	Split into 11 chunks
# 	Split into 1 chunks
# 	Split into 9 chunks
# 	Split into 9 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 1 chunks
# 	Split into 38 chunks
# 	Split into 5 chunks
# 	Split into 11 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 1 chunks
# 	Split into 23 chunks
# 	Split into 2 chunks
# 	Split into 21 chunks
# 	Split into 5 chunks
# 	Split into 1 chunks
# 	Split into 26 chunks
# 	Split into 1 chunks
# 	Split into 25 chunks
# 	Split into 8 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 19 chunks
# 	Split into 1 chunks
# 	Split into 13 chunks
# 	Split into 1 chunks
# 	Split into 17 chunks
# 	Split into 12 chunks
# 	Split into 2 chunks
# 	Split into 39 chunks
# 	Split into 2 chunks
# 	Split into 28 chunks
# 	Split into 1 chunks
# 	Split into 30 chunks
# 	Split into 33 chunks
# 	Split into 1 chunks
# 	Split into 30 chunks
# 	Split into 1 chunks
# 	Split into 18 chunks
# 	Split into 10 chunks
# 	Split into 12 chunks
# 	Split into 1 chunks
# 	Split into 14 chunks
# 	Split into 12 chunks
# 	Split into 19 chunks
# 	Split into 32 chunks
# 	Split into 36 chunks
# 	Split into 16 chunks
# 	Split into 1 chunks
# 	Split into 16 chunks
# 	Split into 37 chunks
# 	Split into 1 chunks
# 	Split into 13 chunks
# 	Split into 28 chunks
# 	Split into 19 chunks
# 	Split into 12 chunks
# 	Split into 44 chunks
# 	Split into 19 chunks
# 	Split into 10 chunks
# 	Split into 75 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 1 chunks
# 	Split into 18 chunks
# 	Split into 31 chunks
# 	Split into 25 chunks
# 	Split into 1 chunks
# 	Split into 5 chunks
# 	Split into 1 chunks
# 	Split into 6 chunks
# 	Split into 16 chunks
# 	Split into 13 chunks
# 	Split into 10 chunks
# 	Split into 1 chunks
# 	Split into 22 chunks
# 	Split into 7 chunks
# 	Split into 2 chunks
# 	Split into 14 chunks
# 	Split into 18 chunks
# 	Split into 10 chunks
# 	Split into 13 chunks
# 	Split into 27 chunks
# 	Split into 50 chunks
# 	Split into 1 chunks
# 	Split into 12 chunks
# 	Split into 23 chunks
# 	Split into 14 chunks
# 	Split into 12 chunks
# 	Split into 1 chunks
# 	Split into 15 chunks
# 	Split into 16 chunks
# 	Split into 17 chunks
# 	Split into 12 chunks
# 	Split into 5 chunks
# 	Split into 14 chunks
# 	Split into 17 chunks
# 	Split into 1 chunks
# 	Split into 20 chunks
# 	Split into 14 chunks
# 	Split into 13 chunks
# 	Split into 17 chunks
# 	Split into 17 chunks
# 	Split into 14 chunks
# 	Split into 10 chunks
# 	Split into 11 chunks
# 	Split into 12 chunks
# 	Split into 1 chunks
# 	Split into 9 chunks
# 	Split into 8 chunks
# 	Split into 16 chunks
# 	Split into 17 chunks
# 	Split into 8 chunks
# 	Split into 18 chunks
# 	Split into 7 chunks
# 	Split into 7 chunks
# 	Split into 9 chunks
# 	Split into 7 chunks

# %%
len(all_chunks)
# Out:
# 4020

# %%
#Cypher statement to creat blog nodes with properties
merge_blog_node_query = """
MERGE(mergedBlog:Blog {fileId: $blogParam.fileId})
    ON CREATE SET
        mergedBlog.title = $blogParam.title,
        mergedBlog.label = $blogParam.label,
        mergedBlog.source = $blogParam.source,
        mergedBlog.time = $blogParam.time,
        mergedBlog.intro = $blogParam.intro,
        mergedBlog.fileId = toString($blogParam.fileId)
RETURN mergedBlog
"""

# %%
all_blogs[0]
# Out:
# {'label': 'NAN',
#  'title': 'Kredittorakel basert på språkmodeller (2024, Trondheim)',
#  'source': 'https://www.kantega.no/blogg/kredittorakel-basert-pa-sprakmodeller-2024-trondheim',
#  'time': '2024-08-30 10:00',
#  'intro': 'Hva må man ha i bakhodet når man designer løsninger med AI-menneske-interaksjon? Hvordan kan man bruke RAG for å forbedre løsninger som benytter språkmodeller? Hvordan sperrer man et mastercard? Og viktigst av alt, hva er egentlig forskjellen på en terrasse, balkong og altan? Det er disse spørsmålene som har preget sommeren vår som sommerstudenter hos Kantega Trondheim, og vi skal nå dele noe av det vi har funnet ut av.',
#  'fileId': 0}

# %%
#create a blog node for each blog
blog_count = 0
for blog in all_blogs:
    print(f"Creating `:Blog` node for blog ID {blog['fileId']}")
    kg.query(merge_blog_node_query,
            params={
                'blogParam': blog
            })
    blog_count += 1
print(f"Created {blog_count} nodes")
# Out:
# Creating `:Blog` node for blog ID 0
# Creating `:Blog` node for blog ID 1
# Creating `:Blog` node for blog ID 2
# Creating `:Blog` node for blog ID 3
# Creating `:Blog` node for blog ID 4
# Creating `:Blog` node for blog ID 5
# Creating `:Blog` node for blog ID 6
# Creating `:Blog` node for blog ID 7
# Creating `:Blog` node for blog ID 8
# Creating `:Blog` node for blog ID 9
# Creating `:Blog` node for blog ID 10
# Creating `:Blog` node for blog ID 11
# Creating `:Blog` node for blog ID 12
# Creating `:Blog` node for blog ID 13
# Creating `:Blog` node for blog ID 14
# Creating `:Blog` node for blog ID 15
# Creating `:Blog` node for blog ID 16
# Creating `:Blog` node for blog ID 17
# Creating `:Blog` node for blog ID 18
# Creating `:Blog` node for blog ID 19
# Creating `:Blog` node for blog ID 20
# Creating `:Blog` node for blog ID 21
# Creating `:Blog` node for blog ID 22
# Creating `:Blog` node for blog ID 23
# Creating `:Blog` node for blog ID 24
# Creating `:Blog` node for blog ID 25
# Creating `:Blog` node for blog ID 26
# Creating `:Blog` node for blog ID 27
# Creating `:Blog` node for blog ID 28
# Creating `:Blog` node for blog ID 29
# Creating `:Blog` node for blog ID 30
# Creating `:Blog` node for blog ID 31
# Creating `:Blog` node for blog ID 32
# Creating `:Blog` node for blog ID 33
# Creating `:Blog` node for blog ID 34
# Creating `:Blog` node for blog ID 35
# Creating `:Blog` node for blog ID 36
# Creating `:Blog` node for blog ID 37
# Creating `:Blog` node for blog ID 38
# Creating `:Blog` node for blog ID 39
# Creating `:Blog` node for blog ID 40
# Creating `:Blog` node for blog ID 41
# Creating `:Blog` node for blog ID 42
# Creating `:Blog` node for blog ID 43
# Creating `:Blog` node for blog ID 44
# Creating `:Blog` node for blog ID 45
# Creating `:Blog` node for blog ID 46
# Creating `:Blog` node for blog ID 47
# Creating `:Blog` node for blog ID 48
# Creating `:Blog` node for blog ID 49
# Creating `:Blog` node for blog ID 50
# Creating `:Blog` node for blog ID 51
# Creating `:Blog` node for blog ID 52
# Creating `:Blog` node for blog ID 53
# Creating `:Blog` node for blog ID 54
# Creating `:Blog` node for blog ID 55
# Creating `:Blog` node for blog ID 56
# Creating `:Blog` node for blog ID 57
# Creating `:Blog` node for blog ID 58
# Creating `:Blog` node for blog ID 59
# Creating `:Blog` node for blog ID 60
# Creating `:Blog` node for blog ID 61
# Creating `:Blog` node for blog ID 62
# Creating `:Blog` node for blog ID 63
# Creating `:Blog` node for blog ID 64
# Creating `:Blog` node for blog ID 65
# Creating `:Blog` node for blog ID 66
# Creating `:Blog` node for blog ID 67
# Creating `:Blog` node for blog ID 68
# Creating `:Blog` node for blog ID 69
# Creating `:Blog` node for blog ID 70
# Creating `:Blog` node for blog ID 71
# Creating `:Blog` node for blog ID 72
# Creating `:Blog` node for blog ID 73
# Creating `:Blog` node for blog ID 74
# Creating `:Blog` node for blog ID 75
# Creating `:Blog` node for blog ID 76
# Creating `:Blog` node for blog ID 77
# Creating `:Blog` node for blog ID 78
# Creating `:Blog` node for blog ID 79
# Creating `:Blog` node for blog ID 80
# Creating `:Blog` node for blog ID 81
# Creating `:Blog` node for blog ID 82
# Creating `:Blog` node for blog ID 83
# Creating `:Blog` node for blog ID 84
# Creating `:Blog` node for blog ID 85
# Creating `:Blog` node for blog ID 86
# Creating `:Blog` node for blog ID 87
# Creating `:Blog` node for blog ID 88
# Creating `:Blog` node for blog ID 89
# Creating `:Blog` node for blog ID 90
# Creating `:Blog` node for blog ID 91
# Creating `:Blog` node for blog ID 92
# Creating `:Blog` node for blog ID 93
# Creating `:Blog` node for blog ID 94
# Creating `:Blog` node for blog ID 95
# Creating `:Blog` node for blog ID 96
# Creating `:Blog` node for blog ID 97
# Creating `:Blog` node for blog ID 98
# Creating `:Blog` node for blog ID 99
# Creating `:Blog` node for blog ID 100
# Creating `:Blog` node for blog ID 101
# Creating `:Blog` node for blog ID 102
# Creating `:Blog` node for blog ID 103
# Creating `:Blog` node for blog ID 104
# Creating `:Blog` node for blog ID 105
# Creating `:Blog` node for blog ID 106
# Creating `:Blog` node for blog ID 107
# Creating `:Blog` node for blog ID 108
# Creating `:Blog` node for blog ID 109
# Creating `:Blog` node for blog ID 110
# Creating `:Blog` node for blog ID 111
# Creating `:Blog` node for blog ID 112
# Creating `:Blog` node for blog ID 113
# Creating `:Blog` node for blog ID 114
# Creating `:Blog` node for blog ID 115
# Creating `:Blog` node for blog ID 116
# Creating `:Blog` node for blog ID 117
# Creating `:Blog` node for blog ID 118
# Creating `:Blog` node for blog ID 119
# Creating `:Blog` node for blog ID 120
# Creating `:Blog` node for blog ID 121
# Creating `:Blog` node for blog ID 122
# Creating `:Blog` node for blog ID 123
# Creating `:Blog` node for blog ID 124
# Creating `:Blog` node for blog ID 125
# Creating `:Blog` node for blog ID 126
# Creating `:Blog` node for blog ID 127
# Creating `:Blog` node for blog ID 128
# Creating `:Blog` node for blog ID 129
# Creating `:Blog` node for blog ID 130
# Creating `:Blog` node for blog ID 131
# Creating `:Blog` node for blog ID 132
# Creating `:Blog` node for blog ID 133
# Creating `:Blog` node for blog ID 134
# Creating `:Blog` node for blog ID 135
# Creating `:Blog` node for blog ID 136
# Creating `:Blog` node for blog ID 137
# Creating `:Blog` node for blog ID 138
# Creating `:Blog` node for blog ID 139
# Creating `:Blog` node for blog ID 140
# Creating `:Blog` node for blog ID 141
# Creating `:Blog` node for blog ID 142
# Creating `:Blog` node for blog ID 143
# Creating `:Blog` node for blog ID 144
# Creating `:Blog` node for blog ID 145
# Creating `:Blog` node for blog ID 146
# Creating `:Blog` node for blog ID 147
# Creating `:Blog` node for blog ID 148
# Creating `:Blog` node for blog ID 149
# Creating `:Blog` node for blog ID 150
# Creating `:Blog` node for blog ID 151
# Creating `:Blog` node for blog ID 152
# Creating `:Blog` node for blog ID 153
# Creating `:Blog` node for blog ID 154
# Creating `:Blog` node for blog ID 155
# Creating `:Blog` node for blog ID 156
# Creating `:Blog` node for blog ID 157
# Creating `:Blog` node for blog ID 158
# Creating `:Blog` node for blog ID 159
# Creating `:Blog` node for blog ID 160
# Creating `:Blog` node for blog ID 161
# Creating `:Blog` node for blog ID 162
# Creating `:Blog` node for blog ID 163
# Creating `:Blog` node for blog ID 164
# Creating `:Blog` node for blog ID 165
# Creating `:Blog` node for blog ID 166
# Creating `:Blog` node for blog ID 167
# Creating `:Blog` node for blog ID 168
# Creating `:Blog` node for blog ID 169
# Creating `:Blog` node for blog ID 170
# Creating `:Blog` node for blog ID 171
# Creating `:Blog` node for blog ID 172
# Creating `:Blog` node for blog ID 173
# Creating `:Blog` node for blog ID 174
# Creating `:Blog` node for blog ID 175
# Creating `:Blog` node for blog ID 176
# Creating `:Blog` node for blog ID 177
# Creating `:Blog` node for blog ID 178
# Creating `:Blog` node for blog ID 179
# Creating `:Blog` node for blog ID 180
# Creating `:Blog` node for blog ID 181
# Creating `:Blog` node for blog ID 182
# Creating `:Blog` node for blog ID 183
# Creating `:Blog` node for blog ID 184
# Creating `:Blog` node for blog ID 185
# Creating `:Blog` node for blog ID 186
# Creating `:Blog` node for blog ID 187
# Creating `:Blog` node for blog ID 188
# Creating `:Blog` node for blog ID 189
# Creating `:Blog` node for blog ID 190
# Creating `:Blog` node for blog ID 191
# Creating `:Blog` node for blog ID 192
# Creating `:Blog` node for blog ID 193
# Creating `:Blog` node for blog ID 194
# Creating `:Blog` node for blog ID 195
# Creating `:Blog` node for blog ID 196
# Creating `:Blog` node for blog ID 197
# Creating `:Blog` node for blog ID 198
# Creating `:Blog` node for blog ID 199
# Creating `:Blog` node for blog ID 200
# Creating `:Blog` node for blog ID 201
# Creating `:Blog` node for blog ID 202
# Creating `:Blog` node for blog ID 203
# Creating `:Blog` node for blog ID 204
# Creating `:Blog` node for blog ID 205
# Creating `:Blog` node for blog ID 206
# Creating `:Blog` node for blog ID 207
# Creating `:Blog` node for blog ID 208
# Creating `:Blog` node for blog ID 209
# Creating `:Blog` node for blog ID 210
# Creating `:Blog` node for blog ID 211
# Creating `:Blog` node for blog ID 212
# Creating `:Blog` node for blog ID 213
# Creating `:Blog` node for blog ID 214
# Creating `:Blog` node for blog ID 215
# Creating `:Blog` node for blog ID 216
# Creating `:Blog` node for blog ID 217
# Creating `:Blog` node for blog ID 218
# Creating `:Blog` node for blog ID 219
# Creating `:Blog` node for blog ID 220
# Creating `:Blog` node for blog ID 221
# Creating `:Blog` node for blog ID 222
# Creating `:Blog` node for blog ID 223
# Creating `:Blog` node for blog ID 224
# Creating `:Blog` node for blog ID 225
# Creating `:Blog` node for blog ID 226
# Creating `:Blog` node for blog ID 227
# Creating `:Blog` node for blog ID 228
# Creating `:Blog` node for blog ID 229
# Creating `:Blog` node for blog ID 230
# Creating `:Blog` node for blog ID 231
# Creating `:Blog` node for blog ID 232
# Creating `:Blog` node for blog ID 233
# Creating `:Blog` node for blog ID 234
# Creating `:Blog` node for blog ID 235
# Creating `:Blog` node for blog ID 236
# Creating `:Blog` node for blog ID 237
# Creating `:Blog` node for blog ID 238
# Created 239 nodes

# %%
#Cypher statement to creat chunk nodes with properties
merge_chunk_node_query = """
MERGE(mergedChunk:Chunk {chunkId: $chunkParam.chunkId})
    ON CREATE SET
        mergedChunk.title = $chunkParam.title,
        mergedChunk.formId = $chunkParam.fileId,
        mergedChunk.chunkId = $chunkParam.chunkId,
        mergedChunk.chunkSeqId = $chunkParam.chunkSeqId,
        mergedChunk.text = $chunkParam.text
RETURN mergedChunk
"""

# %%
#create a chunk node for each chunk
node_count = 0
for chunk in all_chunks:
    print(f"Creating `:Chunk` node for chunk ID {chunk['chunkId']}")
    kg.query(merge_chunk_node_query,
            params={
                'chunkParam': chunk
            })
    node_count += 1
print(f"Created {node_count} nodes")
# Out:
# Creating `:Chunk` node for chunk ID 0-chunk0000
# Creating `:Chunk` node for chunk ID 0-chunk0001
# Creating `:Chunk` node for chunk ID 0-chunk0002
# Creating `:Chunk` node for chunk ID 0-chunk0003
# Creating `:Chunk` node for chunk ID 0-chunk0004
# Creating `:Chunk` node for chunk ID 0-chunk0005
# Creating `:Chunk` node for chunk ID 0-chunk0006
# Creating `:Chunk` node for chunk ID 0-chunk0007
# Creating `:Chunk` node for chunk ID 0-chunk0008
# Creating `:Chunk` node for chunk ID 0-chunk0009
# Creating `:Chunk` node for chunk ID 0-chunk0010
# Creating `:Chunk` node for chunk ID 0-chunk0011
# Creating `:Chunk` node for chunk ID 0-chunk0012
# Creating `:Chunk` node for chunk ID 0-chunk0013
# Creating `:Chunk` node for chunk ID 0-chunk0014
# Creating `:Chunk` node for chunk ID 0-chunk0015
# Creating `:Chunk` node for chunk ID 0-chunk0016
# Creating `:Chunk` node for chunk ID 0-chunk0017
# Creating `:Chunk` node for chunk ID 0-chunk0018
# Creating `:Chunk` node for chunk ID 0-chunk0019
# Creating `:Chunk` node for chunk ID 1-chunk0000
# Creating `:Chunk` node for chunk ID 1-chunk0001
# Creating `:Chunk` node for chunk ID 1-chunk0002
# Creating `:Chunk` node for chunk ID 1-chunk0003
# Creating `:Chunk` node for chunk ID 1-chunk0004
# Creating `:Chunk` node for chunk ID 1-chunk0005
# Creating `:Chunk` node for chunk ID 1-chunk0006
# Creating `:Chunk` node for chunk ID 1-chunk0007
# Creating `:Chunk` node for chunk ID 2-chunk0000
# Creating `:Chunk` node for chunk ID 2-chunk0001
# Creating `:Chunk` node for chunk ID 2-chunk0002
# Creating `:Chunk` node for chunk ID 2-chunk0003
# Creating `:Chunk` node for chunk ID 2-chunk0004
# Creating `:Chunk` node for chunk ID 2-chunk0005
# Creating `:Chunk` node for chunk ID 2-chunk0006
# Creating `:Chunk` node for chunk ID 2-chunk0007
# Creating `:Chunk` node for chunk ID 2-chunk0008
# Creating `:Chunk` node for chunk ID 2-chunk0009
# Creating `:Chunk` node for chunk ID 2-chunk0010
# Creating `:Chunk` node for chunk ID 2-chunk0011
# Creating `:Chunk` node for chunk ID 2-chunk0012
# Creating `:Chunk` node for chunk ID 2-chunk0013
# Creating `:Chunk` node for chunk ID 2-chunk0014
# Creating `:Chunk` node for chunk ID 2-chunk0015
# Creating `:Chunk` node for chunk ID 2-chunk0016
# Creating `:Chunk` node for chunk ID 2-chunk0017
# Creating `:Chunk` node for chunk ID 3-chunk0000
# Creating `:Chunk` node for chunk ID 3-chunk0001
# Creating `:Chunk` node for chunk ID 3-chunk0002
# Creating `:Chunk` node for chunk ID 3-chunk0003
# Creating `:Chunk` node for chunk ID 3-chunk0004
# Creating `:Chunk` node for chunk ID 3-chunk0005
# Creating `:Chunk` node for chunk ID 3-chunk0006
# Creating `:Chunk` node for chunk ID 3-chunk0007
# Creating `:Chunk` node for chunk ID 3-chunk0008
# Creating `:Chunk` node for chunk ID 3-chunk0009
# Creating `:Chunk` node for chunk ID 3-chunk0010
# Creating `:Chunk` node for chunk ID 4-chunk0000
# Creating `:Chunk` node for chunk ID 4-chunk0001
# Creating `:Chunk` node for chunk ID 4-chunk0002
# Creating `:Chunk` node for chunk ID 4-chunk0003
# Creating `:Chunk` node for chunk ID 4-chunk0004
# Creating `:Chunk` node for chunk ID 4-chunk0005
# Creating `:Chunk` node for chunk ID 4-chunk0006
# Creating `:Chunk` node for chunk ID 4-chunk0007
# Creating `:Chunk` node for chunk ID 4-chunk0008
# Creating `:Chunk` node for chunk ID 4-chunk0009
# Creating `:Chunk` node for chunk ID 4-chunk0010
# Creating `:Chunk` node for chunk ID 4-chunk0011
# Creating `:Chunk` node for chunk ID 4-chunk0012
# Creating `:Chunk` node for chunk ID 4-chunk0013
# Creating `:Chunk` node for chunk ID 4-chunk0014
# Creating `:Chunk` node for chunk ID 4-chunk0015
# Creating `:Chunk` node for chunk ID 4-chunk0016
# Creating `:Chunk` node for chunk ID 4-chunk0017
# Creating `:Chunk` node for chunk ID 4-chunk0018
# Creating `:Chunk` node for chunk ID 4-chunk0019
# Creating `:Chunk` node for chunk ID 4-chunk0020
# Creating `:Chunk` node for chunk ID 4-chunk0021
# Creating `:Chunk` node for chunk ID 5-chunk0000
# Creating `:Chunk` node for chunk ID 5-chunk0001
# Creating `:Chunk` node for chunk ID 5-chunk0002
# Creating `:Chunk` node for chunk ID 5-chunk0003
# Creating `:Chunk` node for chunk ID 5-chunk0004
# Creating `:Chunk` node for chunk ID 5-chunk0005
# Creating `:Chunk` node for chunk ID 5-chunk0006
# Creating `:Chunk` node for chunk ID 5-chunk0007
# Creating `:Chunk` node for chunk ID 5-chunk0008
# Creating `:Chunk` node for chunk ID 5-chunk0009
# Creating `:Chunk` node for chunk ID 5-chunk0010
# Creating `:Chunk` node for chunk ID 5-chunk0011
# Creating `:Chunk` node for chunk ID 5-chunk0012
# Creating `:Chunk` node for chunk ID 5-chunk0013
# Creating `:Chunk` node for chunk ID 5-chunk0014
# Creating `:Chunk` node for chunk ID 5-chunk0015
# Creating `:Chunk` node for chunk ID 5-chunk0016
# Creating `:Chunk` node for chunk ID 5-chunk0017
# Creating `:Chunk` node for chunk ID 5-chunk0018
# Creating `:Chunk` node for chunk ID 5-chunk0019
# Creating `:Chunk` node for chunk ID 5-chunk0020
# Creating `:Chunk` node for chunk ID 5-chunk0021
# Creating `:Chunk` node for chunk ID 5-chunk0022
# Creating `:Chunk` node for chunk ID 5-chunk0023
# Creating `:Chunk` node for chunk ID 5-chunk0024
# Creating `:Chunk` node for chunk ID 5-chunk0025
# Creating `:Chunk` node for chunk ID 5-chunk0026
# Creating `:Chunk` node for chunk ID 5-chunk0027
# Creating `:Chunk` node for chunk ID 5-chunk0028
# Creating `:Chunk` node for chunk ID 5-chunk0029
# Creating `:Chunk` node for chunk ID 5-chunk0030
# Creating `:Chunk` node for chunk ID 5-chunk0031
# Creating `:Chunk` node for chunk ID 5-chunk0032
# Creating `:Chunk` node for chunk ID 6-chunk0000
# Creating `:Chunk` node for chunk ID 6-chunk0001
# Creating `:Chunk` node for chunk ID 6-chunk0002
# Creating `:Chunk` node for chunk ID 6-chunk0003
# Creating `:Chunk` node for chunk ID 6-chunk0004
# Creating `:Chunk` node for chunk ID 6-chunk0005
# Creating `:Chunk` node for chunk ID 6-chunk0006
# Creating `:Chunk` node for chunk ID 6-chunk0007
# Creating `:Chunk` node for chunk ID 6-chunk0008
# Creating `:Chunk` node for chunk ID 6-chunk0009
# Creating `:Chunk` node for chunk ID 6-chunk0010
# Creating `:Chunk` node for chunk ID 6-chunk0011
# Creating `:Chunk` node for chunk ID 6-chunk0012
# Creating `:Chunk` node for chunk ID 6-chunk0013
# Creating `:Chunk` node for chunk ID 6-chunk0014
# Creating `:Chunk` node for chunk ID 6-chunk0015
# Creating `:Chunk` node for chunk ID 6-chunk0016
# Creating `:Chunk` node for chunk ID 6-chunk0017
# Creating `:Chunk` node for chunk ID 6-chunk0018
# Creating `:Chunk` node for chunk ID 6-chunk0019
# Creating `:Chunk` node for chunk ID 6-chunk0020
# Creating `:Chunk` node for chunk ID 6-chunk0021
# Creating `:Chunk` node for chunk ID 6-chunk0022
# Creating `:Chunk` node for chunk ID 6-chunk0023
# Creating `:Chunk` node for chunk ID 6-chunk0024
# Creating `:Chunk` node for chunk ID 7-chunk0000
# Creating `:Chunk` node for chunk ID 7-chunk0001
# Creating `:Chunk` node for chunk ID 7-chunk0002
# Creating `:Chunk` node for chunk ID 7-chunk0003
# Creating `:Chunk` node for chunk ID 7-chunk0004
# Creating `:Chunk` node for chunk ID 7-chunk0005
# Creating `:Chunk` node for chunk ID 7-chunk0006
# Creating `:Chunk` node for chunk ID 7-chunk0007
# Creating `:Chunk` node for chunk ID 7-chunk0008
# Creating `:Chunk` node for chunk ID 7-chunk0009
# Creating `:Chunk` node for chunk ID 7-chunk0010
# Creating `:Chunk` node for chunk ID 7-chunk0011
# Creating `:Chunk` node for chunk ID 7-chunk0012
# Creating `:Chunk` node for chunk ID 7-chunk0013
# Creating `:Chunk` node for chunk ID 7-chunk0014
# Creating `:Chunk` node for chunk ID 7-chunk0015
# Creating `:Chunk` node for chunk ID 8-chunk0000
# Creating `:Chunk` node for chunk ID 8-chunk0001
# Creating `:Chunk` node for chunk ID 8-chunk0002
# Creating `:Chunk` node for chunk ID 8-chunk0003
# Creating `:Chunk` node for chunk ID 8-chunk0004
# Creating `:Chunk` node for chunk ID 8-chunk0005
# Creating `:Chunk` node for chunk ID 8-chunk0006
# Creating `:Chunk` node for chunk ID 8-chunk0007
# Creating `:Chunk` node for chunk ID 8-chunk0008
# Creating `:Chunk` node for chunk ID 8-chunk0009
# Creating `:Chunk` node for chunk ID 8-chunk0010
# Creating `:Chunk` node for chunk ID 8-chunk0011
# Creating `:Chunk` node for chunk ID 8-chunk0012
# Creating `:Chunk` node for chunk ID 8-chunk0013
# Creating `:Chunk` node for chunk ID 9-chunk0000
# Creating `:Chunk` node for chunk ID 9-chunk0001
# Creating `:Chunk` node for chunk ID 9-chunk0002
# Creating `:Chunk` node for chunk ID 9-chunk0003
# Creating `:Chunk` node for chunk ID 9-chunk0004
# Creating `:Chunk` node for chunk ID 9-chunk0005
# Creating `:Chunk` node for chunk ID 9-chunk0006
# Creating `:Chunk` node for chunk ID 9-chunk0007
# Creating `:Chunk` node for chunk ID 9-chunk0008
# Creating `:Chunk` node for chunk ID 9-chunk0009
# Creating `:Chunk` node for chunk ID 9-chunk0010
# Creating `:Chunk` node for chunk ID 9-chunk0011
# Creating `:Chunk` node for chunk ID 9-chunk0012
# Creating `:Chunk` node for chunk ID 9-chunk0013
# Creating `:Chunk` node for chunk ID 9-chunk0014
# Creating `:Chunk` node for chunk ID 9-chunk0015
# Creating `:Chunk` node for chunk ID 9-chunk0016
# Creating `:Chunk` node for chunk ID 9-chunk0017
# Creating `:Chunk` node for chunk ID 9-chunk0018
# Creating `:Chunk` node for chunk ID 9-chunk0019
# Creating `:Chunk` node for chunk ID 10-chunk0000
# Creating `:Chunk` node for chunk ID 10-chunk0001
# Creating `:Chunk` node for chunk ID 10-chunk0002
# Creating `:Chunk` node for chunk ID 10-chunk0003
# Creating `:Chunk` node for chunk ID 10-chunk0004
# Creating `:Chunk` node for chunk ID 10-chunk0005
# Creating `:Chunk` node for chunk ID 10-chunk0006
# Creating `:Chunk` node for chunk ID 10-chunk0007
# Creating `:Chunk` node for chunk ID 10-chunk0008
# Creating `:Chunk` node for chunk ID 10-chunk0009
# Creating `:Chunk` node for chunk ID 10-chunk0010
# Creating `:Chunk` node for chunk ID 10-chunk0011
# Creating `:Chunk` node for chunk ID 10-chunk0012
# Creating `:Chunk` node for chunk ID 10-chunk0013
# Creating `:Chunk` node for chunk ID 11-chunk0000
# Creating `:Chunk` node for chunk ID 11-chunk0001
# Creating `:Chunk` node for chunk ID 11-chunk0002
# Creating `:Chunk` node for chunk ID 11-chunk0003
# Creating `:Chunk` node for chunk ID 11-chunk0004
# Creating `:Chunk` node for chunk ID 11-chunk0005
# Creating `:Chunk` node for chunk ID 11-chunk0006
# Creating `:Chunk` node for chunk ID 11-chunk0007
# Creating `:Chunk` node for chunk ID 11-chunk0008
# Creating `:Chunk` node for chunk ID 11-chunk0009
# Creating `:Chunk` node for chunk ID 11-chunk0010
# Creating `:Chunk` node for chunk ID 11-chunk0011
# Creating `:Chunk` node for chunk ID 11-chunk0012
# Creating `:Chunk` node for chunk ID 11-chunk0013
# Creating `:Chunk` node for chunk ID 11-chunk0014
# Creating `:Chunk` node for chunk ID 11-chunk0015
# Creating `:Chunk` node for chunk ID 11-chunk0016
# Creating `:Chunk` node for chunk ID 11-chunk0017
# Creating `:Chunk` node for chunk ID 11-chunk0018
# Creating `:Chunk` node for chunk ID 11-chunk0019
# Creating `:Chunk` node for chunk ID 11-chunk0020
# Creating `:Chunk` node for chunk ID 11-chunk0021
# Creating `:Chunk` node for chunk ID 11-chunk0022
# Creating `:Chunk` node for chunk ID 11-chunk0023
# Creating `:Chunk` node for chunk ID 11-chunk0024
# Creating `:Chunk` node for chunk ID 11-chunk0025
# Creating `:Chunk` node for chunk ID 11-chunk0026
# Creating `:Chunk` node for chunk ID 12-chunk0000
# Creating `:Chunk` node for chunk ID 12-chunk0001
# Creating `:Chunk` node for chunk ID 12-chunk0002
# Creating `:Chunk` node for chunk ID 12-chunk0003
# Creating `:Chunk` node for chunk ID 12-chunk0004
# Creating `:Chunk` node for chunk ID 12-chunk0005
# Creating `:Chunk` node for chunk ID 12-chunk0006
# Creating `:Chunk` node for chunk ID 12-chunk0007
# Creating `:Chunk` node for chunk ID 12-chunk0008
# Creating `:Chunk` node for chunk ID 12-chunk0009
# Creating `:Chunk` node for chunk ID 12-chunk0010
# Creating `:Chunk` node for chunk ID 12-chunk0011
# Creating `:Chunk` node for chunk ID 12-chunk0012
# Creating `:Chunk` node for chunk ID 12-chunk0013
# Creating `:Chunk` node for chunk ID 12-chunk0014
# Creating `:Chunk` node for chunk ID 12-chunk0015
# Creating `:Chunk` node for chunk ID 12-chunk0016
# Creating `:Chunk` node for chunk ID 12-chunk0017
# Creating `:Chunk` node for chunk ID 12-chunk0018
# Creating `:Chunk` node for chunk ID 12-chunk0019
# Creating `:Chunk` node for chunk ID 12-chunk0020
# Creating `:Chunk` node for chunk ID 12-chunk0021
# Creating `:Chunk` node for chunk ID 12-chunk0022
# Creating `:Chunk` node for chunk ID 12-chunk0023
# Creating `:Chunk` node for chunk ID 12-chunk0024
# Creating `:Chunk` node for chunk ID 12-chunk0025
# Creating `:Chunk` node for chunk ID 12-chunk0026
# Creating `:Chunk` node for chunk ID 12-chunk0027
# Creating `:Chunk` node for chunk ID 13-chunk0000
# Creating `:Chunk` node for chunk ID 13-chunk0001
# Creating `:Chunk` node for chunk ID 13-chunk0002
# Creating `:Chunk` node for chunk ID 13-chunk0003
# Creating `:Chunk` node for chunk ID 13-chunk0004
# Creating `:Chunk` node for chunk ID 13-chunk0005
# Creating `:Chunk` node for chunk ID 13-chunk0006
# Creating `:Chunk` node for chunk ID 13-chunk0007
# Creating `:Chunk` node for chunk ID 13-chunk0008
# Creating `:Chunk` node for chunk ID 13-chunk0009
# Creating `:Chunk` node for chunk ID 13-chunk0010
# Creating `:Chunk` node for chunk ID 13-chunk0011
# Creating `:Chunk` node for chunk ID 13-chunk0012
# Creating `:Chunk` node for chunk ID 13-chunk0013
# Creating `:Chunk` node for chunk ID 14-chunk0000
# Creating `:Chunk` node for chunk ID 14-chunk0001
# Creating `:Chunk` node for chunk ID 14-chunk0002
# Creating `:Chunk` node for chunk ID 14-chunk0003
# Creating `:Chunk` node for chunk ID 14-chunk0004
# Creating `:Chunk` node for chunk ID 15-chunk0000
# Creating `:Chunk` node for chunk ID 15-chunk0001
# Creating `:Chunk` node for chunk ID 15-chunk0002
# Creating `:Chunk` node for chunk ID 15-chunk0003
# Creating `:Chunk` node for chunk ID 15-chunk0004
# Creating `:Chunk` node for chunk ID 15-chunk0005
# Creating `:Chunk` node for chunk ID 15-chunk0006
# Creating `:Chunk` node for chunk ID 15-chunk0007
# Creating `:Chunk` node for chunk ID 15-chunk0008
# Creating `:Chunk` node for chunk ID 15-chunk0009
# Creating `:Chunk` node for chunk ID 15-chunk0010
# Creating `:Chunk` node for chunk ID 15-chunk0011
# Creating `:Chunk` node for chunk ID 15-chunk0012
# Creating `:Chunk` node for chunk ID 15-chunk0013
# Creating `:Chunk` node for chunk ID 16-chunk0000
# Creating `:Chunk` node for chunk ID 16-chunk0001
# Creating `:Chunk` node for chunk ID 16-chunk0002
# Creating `:Chunk` node for chunk ID 16-chunk0003
# Creating `:Chunk` node for chunk ID 16-chunk0004
# Creating `:Chunk` node for chunk ID 16-chunk0005
# Creating `:Chunk` node for chunk ID 16-chunk0006
# Creating `:Chunk` node for chunk ID 16-chunk0007
# Creating `:Chunk` node for chunk ID 16-chunk0008
# Creating `:Chunk` node for chunk ID 16-chunk0009
# Creating `:Chunk` node for chunk ID 16-chunk0010
# Creating `:Chunk` node for chunk ID 16-chunk0011
# Creating `:Chunk` node for chunk ID 16-chunk0012
# Creating `:Chunk` node for chunk ID 16-chunk0013
# Creating `:Chunk` node for chunk ID 16-chunk0014
# Creating `:Chunk` node for chunk ID 16-chunk0015
# Creating `:Chunk` node for chunk ID 16-chunk0016
# Creating `:Chunk` node for chunk ID 16-chunk0017
# Creating `:Chunk` node for chunk ID 16-chunk0018
# Creating `:Chunk` node for chunk ID 16-chunk0019
# Creating `:Chunk` node for chunk ID 16-chunk0020
# Creating `:Chunk` node for chunk ID 16-chunk0021
# Creating `:Chunk` node for chunk ID 16-chunk0022
# Creating `:Chunk` node for chunk ID 16-chunk0023
# Creating `:Chunk` node for chunk ID 16-chunk0024
# Creating `:Chunk` node for chunk ID 16-chunk0025
# Creating `:Chunk` node for chunk ID 16-chunk0026
# Creating `:Chunk` node for chunk ID 16-chunk0027
# Creating `:Chunk` node for chunk ID 16-chunk0028
# Creating `:Chunk` node for chunk ID 16-chunk0029
# Creating `:Chunk` node for chunk ID 16-chunk0030
# Creating `:Chunk` node for chunk ID 16-chunk0031
# Creating `:Chunk` node for chunk ID 16-chunk0032
# Creating `:Chunk` node for chunk ID 16-chunk0033
# Creating `:Chunk` node for chunk ID 16-chunk0034
# Creating `:Chunk` node for chunk ID 16-chunk0035
# Creating `:Chunk` node for chunk ID 16-chunk0036
# Creating `:Chunk` node for chunk ID 16-chunk0037
# Creating `:Chunk` node for chunk ID 16-chunk0038
# Creating `:Chunk` node for chunk ID 16-chunk0039
# Creating `:Chunk` node for chunk ID 16-chunk0040
# Creating `:Chunk` node for chunk ID 17-chunk0000
# Creating `:Chunk` node for chunk ID 17-chunk0001
# Creating `:Chunk` node for chunk ID 17-chunk0002
# Creating `:Chunk` node for chunk ID 17-chunk0003
# Creating `:Chunk` node for chunk ID 17-chunk0004
# Creating `:Chunk` node for chunk ID 17-chunk0005
# Creating `:Chunk` node for chunk ID 17-chunk0006
# Creating `:Chunk` node for chunk ID 17-chunk0007
# Creating `:Chunk` node for chunk ID 17-chunk0008
# Creating `:Chunk` node for chunk ID 17-chunk0009
# Creating `:Chunk` node for chunk ID 17-chunk0010
# Creating `:Chunk` node for chunk ID 17-chunk0011
# Creating `:Chunk` node for chunk ID 17-chunk0012
# Creating `:Chunk` node for chunk ID 17-chunk0013
# Creating `:Chunk` node for chunk ID 17-chunk0014
# Creating `:Chunk` node for chunk ID 17-chunk0015
# Creating `:Chunk` node for chunk ID 17-chunk0016
# Creating `:Chunk` node for chunk ID 17-chunk0017
# Creating `:Chunk` node for chunk ID 17-chunk0018
# Creating `:Chunk` node for chunk ID 17-chunk0019
# Creating `:Chunk` node for chunk ID 17-chunk0020
# Creating `:Chunk` node for chunk ID 17-chunk0021
# Creating `:Chunk` node for chunk ID 17-chunk0022
# Creating `:Chunk` node for chunk ID 17-chunk0023
# Creating `:Chunk` node for chunk ID 17-chunk0024
# Creating `:Chunk` node for chunk ID 18-chunk0000
# Creating `:Chunk` node for chunk ID 18-chunk0001
# Creating `:Chunk` node for chunk ID 18-chunk0002
# Creating `:Chunk` node for chunk ID 18-chunk0003
# Creating `:Chunk` node for chunk ID 18-chunk0004
# Creating `:Chunk` node for chunk ID 18-chunk0005
# Creating `:Chunk` node for chunk ID 18-chunk0006
# Creating `:Chunk` node for chunk ID 18-chunk0007
# Creating `:Chunk` node for chunk ID 18-chunk0008
# Creating `:Chunk` node for chunk ID 18-chunk0009
# Creating `:Chunk` node for chunk ID 18-chunk0010
# Creating `:Chunk` node for chunk ID 18-chunk0011
# Creating `:Chunk` node for chunk ID 18-chunk0012
# Creating `:Chunk` node for chunk ID 18-chunk0013
# Creating `:Chunk` node for chunk ID 18-chunk0014
# Creating `:Chunk` node for chunk ID 18-chunk0015
# Creating `:Chunk` node for chunk ID 19-chunk0000
# Creating `:Chunk` node for chunk ID 19-chunk0001
# Creating `:Chunk` node for chunk ID 19-chunk0002
# Creating `:Chunk` node for chunk ID 19-chunk0003
# Creating `:Chunk` node for chunk ID 19-chunk0004
# Creating `:Chunk` node for chunk ID 19-chunk0005
# Creating `:Chunk` node for chunk ID 19-chunk0006
# Creating `:Chunk` node for chunk ID 19-chunk0007
# Creating `:Chunk` node for chunk ID 19-chunk0008
# Creating `:Chunk` node for chunk ID 19-chunk0009
# Creating `:Chunk` node for chunk ID 19-chunk0010
# Creating `:Chunk` node for chunk ID 19-chunk0011
# Creating `:Chunk` node for chunk ID 19-chunk0012
# Creating `:Chunk` node for chunk ID 19-chunk0013
# Creating `:Chunk` node for chunk ID 19-chunk0014
# Creating `:Chunk` node for chunk ID 20-chunk0000
# Creating `:Chunk` node for chunk ID 20-chunk0001
# Creating `:Chunk` node for chunk ID 20-chunk0002
# Creating `:Chunk` node for chunk ID 20-chunk0003
# Creating `:Chunk` node for chunk ID 20-chunk0004
# Creating `:Chunk` node for chunk ID 20-chunk0005
# Creating `:Chunk` node for chunk ID 20-chunk0006
# Creating `:Chunk` node for chunk ID 20-chunk0007
# Creating `:Chunk` node for chunk ID 20-chunk0008
# Creating `:Chunk` node for chunk ID 20-chunk0009
# Creating `:Chunk` node for chunk ID 20-chunk0010
# Creating `:Chunk` node for chunk ID 20-chunk0011
# Creating `:Chunk` node for chunk ID 20-chunk0012
# Creating `:Chunk` node for chunk ID 20-chunk0013
# Creating `:Chunk` node for chunk ID 20-chunk0014
# Creating `:Chunk` node for chunk ID 20-chunk0015
# Creating `:Chunk` node for chunk ID 20-chunk0016
# Creating `:Chunk` node for chunk ID 20-chunk0017
# Creating `:Chunk` node for chunk ID 20-chunk0018
# Creating `:Chunk` node for chunk ID 20-chunk0019
# Creating `:Chunk` node for chunk ID 20-chunk0020
# Creating `:Chunk` node for chunk ID 20-chunk0021
# Creating `:Chunk` node for chunk ID 20-chunk0022
# Creating `:Chunk` node for chunk ID 20-chunk0023
# Creating `:Chunk` node for chunk ID 21-chunk0000
# Creating `:Chunk` node for chunk ID 21-chunk0001
# Creating `:Chunk` node for chunk ID 21-chunk0002
# Creating `:Chunk` node for chunk ID 21-chunk0003
# Creating `:Chunk` node for chunk ID 21-chunk0004
# Creating `:Chunk` node for chunk ID 21-chunk0005
# Creating `:Chunk` node for chunk ID 21-chunk0006
# Creating `:Chunk` node for chunk ID 21-chunk0007
# Creating `:Chunk` node for chunk ID 21-chunk0008
# Creating `:Chunk` node for chunk ID 22-chunk0000
# Creating `:Chunk` node for chunk ID 22-chunk0001
# Creating `:Chunk` node for chunk ID 22-chunk0002
# Creating `:Chunk` node for chunk ID 22-chunk0003
# Creating `:Chunk` node for chunk ID 22-chunk0004
# Creating `:Chunk` node for chunk ID 22-chunk0005
# Creating `:Chunk` node for chunk ID 22-chunk0006
# Creating `:Chunk` node for chunk ID 22-chunk0007
# Creating `:Chunk` node for chunk ID 22-chunk0008
# Creating `:Chunk` node for chunk ID 22-chunk0009
# Creating `:Chunk` node for chunk ID 22-chunk0010
# Creating `:Chunk` node for chunk ID 22-chunk0011
# Creating `:Chunk` node for chunk ID 22-chunk0012
# Creating `:Chunk` node for chunk ID 22-chunk0013
# Creating `:Chunk` node for chunk ID 22-chunk0014
# Creating `:Chunk` node for chunk ID 22-chunk0015
# Creating `:Chunk` node for chunk ID 22-chunk0016
# Creating `:Chunk` node for chunk ID 22-chunk0017
# Creating `:Chunk` node for chunk ID 22-chunk0018
# Creating `:Chunk` node for chunk ID 22-chunk0019
# Creating `:Chunk` node for chunk ID 22-chunk0020
# Creating `:Chunk` node for chunk ID 22-chunk0021
# Creating `:Chunk` node for chunk ID 22-chunk0022
# Creating `:Chunk` node for chunk ID 22-chunk0023
# Creating `:Chunk` node for chunk ID 22-chunk0024
# Creating `:Chunk` node for chunk ID 22-chunk0025
# Creating `:Chunk` node for chunk ID 22-chunk0026
# Creating `:Chunk` node for chunk ID 22-chunk0027
# Creating `:Chunk` node for chunk ID 22-chunk0028
# Creating `:Chunk` node for chunk ID 22-chunk0029
# Creating `:Chunk` node for chunk ID 22-chunk0030
# Creating `:Chunk` node for chunk ID 22-chunk0031
# Creating `:Chunk` node for chunk ID 22-chunk0032
# Creating `:Chunk` node for chunk ID 22-chunk0033
# Creating `:Chunk` node for chunk ID 22-chunk0034
# Creating `:Chunk` node for chunk ID 23-chunk0000
# Creating `:Chunk` node for chunk ID 23-chunk0001
# Creating `:Chunk` node for chunk ID 23-chunk0002
# Creating `:Chunk` node for chunk ID 23-chunk0003
# Creating `:Chunk` node for chunk ID 23-chunk0004
# Creating `:Chunk` node for chunk ID 23-chunk0005
# Creating `:Chunk` node for chunk ID 23-chunk0006
# Creating `:Chunk` node for chunk ID 23-chunk0007
# Creating `:Chunk` node for chunk ID 23-chunk0008
# Creating `:Chunk` node for chunk ID 23-chunk0009
# Creating `:Chunk` node for chunk ID 23-chunk0010
# Creating `:Chunk` node for chunk ID 23-chunk0011
# Creating `:Chunk` node for chunk ID 23-chunk0012
# Creating `:Chunk` node for chunk ID 23-chunk0013
# Creating `:Chunk` node for chunk ID 23-chunk0014
# Creating `:Chunk` node for chunk ID 23-chunk0015
# Creating `:Chunk` node for chunk ID 23-chunk0016
# Creating `:Chunk` node for chunk ID 23-chunk0017
# Creating `:Chunk` node for chunk ID 23-chunk0018
# Creating `:Chunk` node for chunk ID 23-chunk0019
# Creating `:Chunk` node for chunk ID 23-chunk0020
# Creating `:Chunk` node for chunk ID 23-chunk0021
# Creating `:Chunk` node for chunk ID 23-chunk0022
# Creating `:Chunk` node for chunk ID 23-chunk0023
# Creating `:Chunk` node for chunk ID 23-chunk0024
# Creating `:Chunk` node for chunk ID 24-chunk0000
# Creating `:Chunk` node for chunk ID 24-chunk0001
# Creating `:Chunk` node for chunk ID 24-chunk0002
# Creating `:Chunk` node for chunk ID 24-chunk0003
# Creating `:Chunk` node for chunk ID 24-chunk0004
# Creating `:Chunk` node for chunk ID 25-chunk0000
# Creating `:Chunk` node for chunk ID 25-chunk0001
# Creating `:Chunk` node for chunk ID 25-chunk0002
# Creating `:Chunk` node for chunk ID 25-chunk0003
# Creating `:Chunk` node for chunk ID 25-chunk0004
# Creating `:Chunk` node for chunk ID 25-chunk0005
# Creating `:Chunk` node for chunk ID 25-chunk0006
# Creating `:Chunk` node for chunk ID 25-chunk0007
# Creating `:Chunk` node for chunk ID 25-chunk0008
# Creating `:Chunk` node for chunk ID 25-chunk0009
# Creating `:Chunk` node for chunk ID 25-chunk0010
# Creating `:Chunk` node for chunk ID 25-chunk0011
# Creating `:Chunk` node for chunk ID 25-chunk0012
# Creating `:Chunk` node for chunk ID 25-chunk0013
# Creating `:Chunk` node for chunk ID 25-chunk0014
# Creating `:Chunk` node for chunk ID 25-chunk0015
# Creating `:Chunk` node for chunk ID 25-chunk0016
# Creating `:Chunk` node for chunk ID 26-chunk0000
# Creating `:Chunk` node for chunk ID 26-chunk0001
# Creating `:Chunk` node for chunk ID 26-chunk0002
# Creating `:Chunk` node for chunk ID 26-chunk0003
# Creating `:Chunk` node for chunk ID 26-chunk0004
# Creating `:Chunk` node for chunk ID 26-chunk0005
# Creating `:Chunk` node for chunk ID 26-chunk0006
# Creating `:Chunk` node for chunk ID 26-chunk0007
# Creating `:Chunk` node for chunk ID 26-chunk0008
# Creating `:Chunk` node for chunk ID 26-chunk0009
# Creating `:Chunk` node for chunk ID 26-chunk0010
# Creating `:Chunk` node for chunk ID 26-chunk0011
# Creating `:Chunk` node for chunk ID 26-chunk0012
# Creating `:Chunk` node for chunk ID 26-chunk0013
# Creating `:Chunk` node for chunk ID 26-chunk0014
# Creating `:Chunk` node for chunk ID 26-chunk0015
# Creating `:Chunk` node for chunk ID 26-chunk0016
# Creating `:Chunk` node for chunk ID 26-chunk0017
# Creating `:Chunk` node for chunk ID 26-chunk0018
# Creating `:Chunk` node for chunk ID 26-chunk0019
# Creating `:Chunk` node for chunk ID 26-chunk0020
# Creating `:Chunk` node for chunk ID 26-chunk0021
# Creating `:Chunk` node for chunk ID 26-chunk0022
# Creating `:Chunk` node for chunk ID 27-chunk0000
# Creating `:Chunk` node for chunk ID 27-chunk0001
# Creating `:Chunk` node for chunk ID 27-chunk0002
# Creating `:Chunk` node for chunk ID 27-chunk0003
# Creating `:Chunk` node for chunk ID 27-chunk0004
# Creating `:Chunk` node for chunk ID 27-chunk0005
# Creating `:Chunk` node for chunk ID 27-chunk0006
# Creating `:Chunk` node for chunk ID 27-chunk0007
# Creating `:Chunk` node for chunk ID 27-chunk0008
# Creating `:Chunk` node for chunk ID 30-chunk0000
# Creating `:Chunk` node for chunk ID 30-chunk0001
# Creating `:Chunk` node for chunk ID 30-chunk0002
# Creating `:Chunk` node for chunk ID 30-chunk0003
# Creating `:Chunk` node for chunk ID 30-chunk0004
# Creating `:Chunk` node for chunk ID 30-chunk0005
# Creating `:Chunk` node for chunk ID 30-chunk0006
# Creating `:Chunk` node for chunk ID 30-chunk0007
# Creating `:Chunk` node for chunk ID 30-chunk0008
# Creating `:Chunk` node for chunk ID 30-chunk0009
# Creating `:Chunk` node for chunk ID 30-chunk0010
# Creating `:Chunk` node for chunk ID 31-chunk0000
# Creating `:Chunk` node for chunk ID 31-chunk0001
# Creating `:Chunk` node for chunk ID 31-chunk0002
# Creating `:Chunk` node for chunk ID 31-chunk0003
# Creating `:Chunk` node for chunk ID 31-chunk0004
# Creating `:Chunk` node for chunk ID 31-chunk0005
# Creating `:Chunk` node for chunk ID 31-chunk0006
# Creating `:Chunk` node for chunk ID 31-chunk0007
# Creating `:Chunk` node for chunk ID 31-chunk0008
# Creating `:Chunk` node for chunk ID 31-chunk0009
# Creating `:Chunk` node for chunk ID 31-chunk0010
# Creating `:Chunk` node for chunk ID 31-chunk0011
# Creating `:Chunk` node for chunk ID 31-chunk0012
# Creating `:Chunk` node for chunk ID 31-chunk0013
# Creating `:Chunk` node for chunk ID 31-chunk0014
# Creating `:Chunk` node for chunk ID 31-chunk0015
# Creating `:Chunk` node for chunk ID 36-chunk0000
# Creating `:Chunk` node for chunk ID 36-chunk0001
# Creating `:Chunk` node for chunk ID 36-chunk0002
# Creating `:Chunk` node for chunk ID 36-chunk0003
# Creating `:Chunk` node for chunk ID 36-chunk0004
# Creating `:Chunk` node for chunk ID 36-chunk0005
# Creating `:Chunk` node for chunk ID 36-chunk0006
# Creating `:Chunk` node for chunk ID 36-chunk0007
# Creating `:Chunk` node for chunk ID 36-chunk0008
# Creating `:Chunk` node for chunk ID 37-chunk0000
# Creating `:Chunk` node for chunk ID 37-chunk0001
# Creating `:Chunk` node for chunk ID 37-chunk0002
# Creating `:Chunk` node for chunk ID 37-chunk0003
# Creating `:Chunk` node for chunk ID 37-chunk0004
# Creating `:Chunk` node for chunk ID 37-chunk0005
# Creating `:Chunk` node for chunk ID 37-chunk0006
# Creating `:Chunk` node for chunk ID 37-chunk0007
# Creating `:Chunk` node for chunk ID 37-chunk0008
# Creating `:Chunk` node for chunk ID 37-chunk0009
# Creating `:Chunk` node for chunk ID 37-chunk0010
# Creating `:Chunk` node for chunk ID 37-chunk0011
# Creating `:Chunk` node for chunk ID 37-chunk0012
# Creating `:Chunk` node for chunk ID 37-chunk0013
# Creating `:Chunk` node for chunk ID 37-chunk0014
# Creating `:Chunk` node for chunk ID 37-chunk0015
# Creating `:Chunk` node for chunk ID 37-chunk0016
# Creating `:Chunk` node for chunk ID 37-chunk0017
# Creating `:Chunk` node for chunk ID 37-chunk0018
# Creating `:Chunk` node for chunk ID 37-chunk0019
# Creating `:Chunk` node for chunk ID 37-chunk0020
# Creating `:Chunk` node for chunk ID 37-chunk0021
# Creating `:Chunk` node for chunk ID 37-chunk0022
# Creating `:Chunk` node for chunk ID 37-chunk0023
# Creating `:Chunk` node for chunk ID 37-chunk0024
# Creating `:Chunk` node for chunk ID 37-chunk0025
# Creating `:Chunk` node for chunk ID 37-chunk0026
# Creating `:Chunk` node for chunk ID 37-chunk0027
# Creating `:Chunk` node for chunk ID 37-chunk0028
# Creating `:Chunk` node for chunk ID 37-chunk0029
# Creating `:Chunk` node for chunk ID 38-chunk0000
# Creating `:Chunk` node for chunk ID 38-chunk0001
# Creating `:Chunk` node for chunk ID 38-chunk0002
# Creating `:Chunk` node for chunk ID 38-chunk0003
# Creating `:Chunk` node for chunk ID 38-chunk0004
# Creating `:Chunk` node for chunk ID 38-chunk0005
# Creating `:Chunk` node for chunk ID 38-chunk0006
# Creating `:Chunk` node for chunk ID 38-chunk0007
# Creating `:Chunk` node for chunk ID 38-chunk0008
# Creating `:Chunk` node for chunk ID 38-chunk0009
# Creating `:Chunk` node for chunk ID 38-chunk0010
# Creating `:Chunk` node for chunk ID 38-chunk0011
# Creating `:Chunk` node for chunk ID 38-chunk0012
# Creating `:Chunk` node for chunk ID 38-chunk0013
# Creating `:Chunk` node for chunk ID 38-chunk0014
# Creating `:Chunk` node for chunk ID 38-chunk0015
# Creating `:Chunk` node for chunk ID 38-chunk0016
# Creating `:Chunk` node for chunk ID 38-chunk0017
# Creating `:Chunk` node for chunk ID 38-chunk0018
# Creating `:Chunk` node for chunk ID 38-chunk0019
# Creating `:Chunk` node for chunk ID 38-chunk0020
# Creating `:Chunk` node for chunk ID 38-chunk0021
# Creating `:Chunk` node for chunk ID 39-chunk0000
# Creating `:Chunk` node for chunk ID 39-chunk0001
# Creating `:Chunk` node for chunk ID 39-chunk0002
# Creating `:Chunk` node for chunk ID 39-chunk0003
# Creating `:Chunk` node for chunk ID 39-chunk0004
# Creating `:Chunk` node for chunk ID 39-chunk0005
# Creating `:Chunk` node for chunk ID 39-chunk0006
# Creating `:Chunk` node for chunk ID 39-chunk0007
# Creating `:Chunk` node for chunk ID 39-chunk0008
# Creating `:Chunk` node for chunk ID 39-chunk0009
# Creating `:Chunk` node for chunk ID 39-chunk0010
# Creating `:Chunk` node for chunk ID 39-chunk0011
# Creating `:Chunk` node for chunk ID 39-chunk0012
# Creating `:Chunk` node for chunk ID 39-chunk0013
# Creating `:Chunk` node for chunk ID 39-chunk0014
# Creating `:Chunk` node for chunk ID 39-chunk0015
# Creating `:Chunk` node for chunk ID 39-chunk0016
# Creating `:Chunk` node for chunk ID 40-chunk0000
# Creating `:Chunk` node for chunk ID 40-chunk0001
# Creating `:Chunk` node for chunk ID 40-chunk0002
# Creating `:Chunk` node for chunk ID 40-chunk0003
# Creating `:Chunk` node for chunk ID 40-chunk0004
# Creating `:Chunk` node for chunk ID 40-chunk0005
# Creating `:Chunk` node for chunk ID 40-chunk0006
# Creating `:Chunk` node for chunk ID 40-chunk0007
# Creating `:Chunk` node for chunk ID 40-chunk0008
# Creating `:Chunk` node for chunk ID 40-chunk0009
# Creating `:Chunk` node for chunk ID 40-chunk0010
# Creating `:Chunk` node for chunk ID 40-chunk0011
# Creating `:Chunk` node for chunk ID 40-chunk0012
# Creating `:Chunk` node for chunk ID 41-chunk0000
# Creating `:Chunk` node for chunk ID 41-chunk0001
# Creating `:Chunk` node for chunk ID 41-chunk0002
# Creating `:Chunk` node for chunk ID 41-chunk0003
# Creating `:Chunk` node for chunk ID 41-chunk0004
# Creating `:Chunk` node for chunk ID 41-chunk0005
# Creating `:Chunk` node for chunk ID 41-chunk0006
# Creating `:Chunk` node for chunk ID 41-chunk0007
# Creating `:Chunk` node for chunk ID 41-chunk0008
# Creating `:Chunk` node for chunk ID 41-chunk0009
# Creating `:Chunk` node for chunk ID 41-chunk0010
# Creating `:Chunk` node for chunk ID 41-chunk0011
# Creating `:Chunk` node for chunk ID 41-chunk0012
# Creating `:Chunk` node for chunk ID 41-chunk0013
# Creating `:Chunk` node for chunk ID 41-chunk0014
# Creating `:Chunk` node for chunk ID 42-chunk0000
# Creating `:Chunk` node for chunk ID 42-chunk0001
# Creating `:Chunk` node for chunk ID 42-chunk0002
# Creating `:Chunk` node for chunk ID 42-chunk0003
# Creating `:Chunk` node for chunk ID 42-chunk0004
# Creating `:Chunk` node for chunk ID 42-chunk0005
# Creating `:Chunk` node for chunk ID 42-chunk0006
# Creating `:Chunk` node for chunk ID 42-chunk0007
# Creating `:Chunk` node for chunk ID 42-chunk0008
# Creating `:Chunk` node for chunk ID 42-chunk0009
# Creating `:Chunk` node for chunk ID 42-chunk0010
# Creating `:Chunk` node for chunk ID 42-chunk0011
# Creating `:Chunk` node for chunk ID 42-chunk0012
# Creating `:Chunk` node for chunk ID 42-chunk0013
# Creating `:Chunk` node for chunk ID 42-chunk0014
# Creating `:Chunk` node for chunk ID 42-chunk0015
# Creating `:Chunk` node for chunk ID 42-chunk0016
# Creating `:Chunk` node for chunk ID 43-chunk0000
# Creating `:Chunk` node for chunk ID 43-chunk0001
# Creating `:Chunk` node for chunk ID 43-chunk0002
# Creating `:Chunk` node for chunk ID 43-chunk0003
# Creating `:Chunk` node for chunk ID 43-chunk0004
# Creating `:Chunk` node for chunk ID 43-chunk0005
# Creating `:Chunk` node for chunk ID 43-chunk0006
# Creating `:Chunk` node for chunk ID 43-chunk0007
# Creating `:Chunk` node for chunk ID 43-chunk0008
# Creating `:Chunk` node for chunk ID 43-chunk0009
# Creating `:Chunk` node for chunk ID 43-chunk0010
# Creating `:Chunk` node for chunk ID 43-chunk0011
# Creating `:Chunk` node for chunk ID 43-chunk0012
# Creating `:Chunk` node for chunk ID 43-chunk0013
# Creating `:Chunk` node for chunk ID 43-chunk0014
# Creating `:Chunk` node for chunk ID 43-chunk0015
# Creating `:Chunk` node for chunk ID 43-chunk0016
# Creating `:Chunk` node for chunk ID 43-chunk0017
# Creating `:Chunk` node for chunk ID 43-chunk0018
# Creating `:Chunk` node for chunk ID 43-chunk0019
# Creating `:Chunk` node for chunk ID 43-chunk0020
# Creating `:Chunk` node for chunk ID 43-chunk0021
# Creating `:Chunk` node for chunk ID 43-chunk0022
# Creating `:Chunk` node for chunk ID 43-chunk0023
# Creating `:Chunk` node for chunk ID 44-chunk0000
# Creating `:Chunk` node for chunk ID 44-chunk0001
# Creating `:Chunk` node for chunk ID 44-chunk0002
# Creating `:Chunk` node for chunk ID 44-chunk0003
# Creating `:Chunk` node for chunk ID 44-chunk0004
# Creating `:Chunk` node for chunk ID 44-chunk0005
# Creating `:Chunk` node for chunk ID 44-chunk0006
# Creating `:Chunk` node for chunk ID 44-chunk0007
# Creating `:Chunk` node for chunk ID 44-chunk0008
# Creating `:Chunk` node for chunk ID 44-chunk0009
# Creating `:Chunk` node for chunk ID 44-chunk0010
# Creating `:Chunk` node for chunk ID 44-chunk0011
# Creating `:Chunk` node for chunk ID 44-chunk0012
# Creating `:Chunk` node for chunk ID 44-chunk0013
# Creating `:Chunk` node for chunk ID 44-chunk0014
# Creating `:Chunk` node for chunk ID 45-chunk0000
# Creating `:Chunk` node for chunk ID 45-chunk0001
# Creating `:Chunk` node for chunk ID 45-chunk0002
# Creating `:Chunk` node for chunk ID 45-chunk0003
# Creating `:Chunk` node for chunk ID 45-chunk0004
# Creating `:Chunk` node for chunk ID 46-chunk0000
# Creating `:Chunk` node for chunk ID 46-chunk0001
# Creating `:Chunk` node for chunk ID 46-chunk0002
# Creating `:Chunk` node for chunk ID 46-chunk0003
# Creating `:Chunk` node for chunk ID 46-chunk0004
# Creating `:Chunk` node for chunk ID 46-chunk0005
# Creating `:Chunk` node for chunk ID 46-chunk0006
# Creating `:Chunk` node for chunk ID 46-chunk0007
# Creating `:Chunk` node for chunk ID 46-chunk0008
# Creating `:Chunk` node for chunk ID 46-chunk0009
# Creating `:Chunk` node for chunk ID 46-chunk0010
# Creating `:Chunk` node for chunk ID 46-chunk0011
# Creating `:Chunk` node for chunk ID 46-chunk0012
# Creating `:Chunk` node for chunk ID 46-chunk0013
# Creating `:Chunk` node for chunk ID 46-chunk0014
# Creating `:Chunk` node for chunk ID 46-chunk0015
# Creating `:Chunk` node for chunk ID 46-chunk0016
# Creating `:Chunk` node for chunk ID 46-chunk0017
# Creating `:Chunk` node for chunk ID 47-chunk0000
# Creating `:Chunk` node for chunk ID 47-chunk0001
# Creating `:Chunk` node for chunk ID 47-chunk0002
# Creating `:Chunk` node for chunk ID 47-chunk0003
# Creating `:Chunk` node for chunk ID 47-chunk0004
# Creating `:Chunk` node for chunk ID 47-chunk0005
# Creating `:Chunk` node for chunk ID 47-chunk0006
# Creating `:Chunk` node for chunk ID 47-chunk0007
# Creating `:Chunk` node for chunk ID 47-chunk0008
# Creating `:Chunk` node for chunk ID 47-chunk0009
# Creating `:Chunk` node for chunk ID 47-chunk0010
# Creating `:Chunk` node for chunk ID 47-chunk0011
# Creating `:Chunk` node for chunk ID 47-chunk0012
# Creating `:Chunk` node for chunk ID 47-chunk0013
# Creating `:Chunk` node for chunk ID 47-chunk0014
# Creating `:Chunk` node for chunk ID 47-chunk0015
# Creating `:Chunk` node for chunk ID 47-chunk0016
# Creating `:Chunk` node for chunk ID 47-chunk0017
# Creating `:Chunk` node for chunk ID 47-chunk0018
# Creating `:Chunk` node for chunk ID 47-chunk0019
# Creating `:Chunk` node for chunk ID 47-chunk0020
# Creating `:Chunk` node for chunk ID 48-chunk0000
# Creating `:Chunk` node for chunk ID 48-chunk0001
# Creating `:Chunk` node for chunk ID 48-chunk0002
# Creating `:Chunk` node for chunk ID 48-chunk0003
# Creating `:Chunk` node for chunk ID 48-chunk0004
# Creating `:Chunk` node for chunk ID 48-chunk0005
# Creating `:Chunk` node for chunk ID 48-chunk0006
# Creating `:Chunk` node for chunk ID 48-chunk0007
# Creating `:Chunk` node for chunk ID 48-chunk0008
# Creating `:Chunk` node for chunk ID 48-chunk0009
# Creating `:Chunk` node for chunk ID 48-chunk0010
# Creating `:Chunk` node for chunk ID 48-chunk0011
# Creating `:Chunk` node for chunk ID 48-chunk0012
# Creating `:Chunk` node for chunk ID 48-chunk0013
# Creating `:Chunk` node for chunk ID 48-chunk0014
# Creating `:Chunk` node for chunk ID 48-chunk0015
# Creating `:Chunk` node for chunk ID 48-chunk0016
# Creating `:Chunk` node for chunk ID 49-chunk0000
# Creating `:Chunk` node for chunk ID 49-chunk0001
# Creating `:Chunk` node for chunk ID 49-chunk0002
# Creating `:Chunk` node for chunk ID 49-chunk0003
# Creating `:Chunk` node for chunk ID 49-chunk0004
# Creating `:Chunk` node for chunk ID 49-chunk0005
# Creating `:Chunk` node for chunk ID 49-chunk0006
# Creating `:Chunk` node for chunk ID 49-chunk0007
# Creating `:Chunk` node for chunk ID 49-chunk0008
# Creating `:Chunk` node for chunk ID 49-chunk0009
# Creating `:Chunk` node for chunk ID 49-chunk0010
# Creating `:Chunk` node for chunk ID 49-chunk0011
# Creating `:Chunk` node for chunk ID 49-chunk0012
# Creating `:Chunk` node for chunk ID 49-chunk0013
# Creating `:Chunk` node for chunk ID 49-chunk0014
# Creating `:Chunk` node for chunk ID 49-chunk0015
# Creating `:Chunk` node for chunk ID 49-chunk0016
# Creating `:Chunk` node for chunk ID 49-chunk0017
# Creating `:Chunk` node for chunk ID 49-chunk0018
# Creating `:Chunk` node for chunk ID 49-chunk0019
# Creating `:Chunk` node for chunk ID 49-chunk0020
# Creating `:Chunk` node for chunk ID 49-chunk0021
# Creating `:Chunk` node for chunk ID 49-chunk0022
# Creating `:Chunk` node for chunk ID 49-chunk0023
# Creating `:Chunk` node for chunk ID 49-chunk0024
# Creating `:Chunk` node for chunk ID 49-chunk0025
# Creating `:Chunk` node for chunk ID 49-chunk0026
# Creating `:Chunk` node for chunk ID 49-chunk0027
# Creating `:Chunk` node for chunk ID 49-chunk0028
# Creating `:Chunk` node for chunk ID 49-chunk0029
# Creating `:Chunk` node for chunk ID 50-chunk0000
# Creating `:Chunk` node for chunk ID 50-chunk0001
# Creating `:Chunk` node for chunk ID 50-chunk0002
# Creating `:Chunk` node for chunk ID 50-chunk0003
# Creating `:Chunk` node for chunk ID 50-chunk0004
# Creating `:Chunk` node for chunk ID 50-chunk0005
# Creating `:Chunk` node for chunk ID 50-chunk0006
# Creating `:Chunk` node for chunk ID 50-chunk0007
# Creating `:Chunk` node for chunk ID 50-chunk0008
# Creating `:Chunk` node for chunk ID 50-chunk0009
# Creating `:Chunk` node for chunk ID 50-chunk0010
# Creating `:Chunk` node for chunk ID 50-chunk0011
# Creating `:Chunk` node for chunk ID 50-chunk0012
# Creating `:Chunk` node for chunk ID 50-chunk0013
# Creating `:Chunk` node for chunk ID 50-chunk0014
# Creating `:Chunk` node for chunk ID 51-chunk0000
# Creating `:Chunk` node for chunk ID 51-chunk0001
# Creating `:Chunk` node for chunk ID 51-chunk0002
# Creating `:Chunk` node for chunk ID 51-chunk0003
# Creating `:Chunk` node for chunk ID 51-chunk0004
# Creating `:Chunk` node for chunk ID 51-chunk0005
# Creating `:Chunk` node for chunk ID 51-chunk0006
# Creating `:Chunk` node for chunk ID 51-chunk0007
# Creating `:Chunk` node for chunk ID 51-chunk0008
# Creating `:Chunk` node for chunk ID 51-chunk0009
# Creating `:Chunk` node for chunk ID 51-chunk0010
# Creating `:Chunk` node for chunk ID 51-chunk0011
# Creating `:Chunk` node for chunk ID 51-chunk0012
# Creating `:Chunk` node for chunk ID 51-chunk0013
# Creating `:Chunk` node for chunk ID 51-chunk0014
# Creating `:Chunk` node for chunk ID 51-chunk0015
# Creating `:Chunk` node for chunk ID 51-chunk0016
# Creating `:Chunk` node for chunk ID 51-chunk0017
# Creating `:Chunk` node for chunk ID 51-chunk0018
# Creating `:Chunk` node for chunk ID 51-chunk0019
# Creating `:Chunk` node for chunk ID 51-chunk0020
# Creating `:Chunk` node for chunk ID 51-chunk0021
# Creating `:Chunk` node for chunk ID 51-chunk0022
# Creating `:Chunk` node for chunk ID 51-chunk0023
# Creating `:Chunk` node for chunk ID 51-chunk0024
# Creating `:Chunk` node for chunk ID 51-chunk0025
# Creating `:Chunk` node for chunk ID 51-chunk0026
# Creating `:Chunk` node for chunk ID 51-chunk0027
# Creating `:Chunk` node for chunk ID 51-chunk0028
# Creating `:Chunk` node for chunk ID 51-chunk0029
# Creating `:Chunk` node for chunk ID 51-chunk0030
# Creating `:Chunk` node for chunk ID 51-chunk0031
# Creating `:Chunk` node for chunk ID 51-chunk0032
# Creating `:Chunk` node for chunk ID 51-chunk0033
# Creating `:Chunk` node for chunk ID 52-chunk0000
# Creating `:Chunk` node for chunk ID 52-chunk0001
# Creating `:Chunk` node for chunk ID 52-chunk0002
# Creating `:Chunk` node for chunk ID 52-chunk0003
# Creating `:Chunk` node for chunk ID 52-chunk0004
# Creating `:Chunk` node for chunk ID 52-chunk0005
# Creating `:Chunk` node for chunk ID 52-chunk0006
# Creating `:Chunk` node for chunk ID 52-chunk0007
# Creating `:Chunk` node for chunk ID 52-chunk0008
# Creating `:Chunk` node for chunk ID 52-chunk0009
# Creating `:Chunk` node for chunk ID 52-chunk0010
# Creating `:Chunk` node for chunk ID 52-chunk0011
# Creating `:Chunk` node for chunk ID 52-chunk0012
# Creating `:Chunk` node for chunk ID 52-chunk0013
# Creating `:Chunk` node for chunk ID 52-chunk0014
# Creating `:Chunk` node for chunk ID 53-chunk0000
# Creating `:Chunk` node for chunk ID 53-chunk0001
# Creating `:Chunk` node for chunk ID 53-chunk0002
# Creating `:Chunk` node for chunk ID 53-chunk0003
# Creating `:Chunk` node for chunk ID 53-chunk0004
# Creating `:Chunk` node for chunk ID 53-chunk0005
# Creating `:Chunk` node for chunk ID 53-chunk0006
# Creating `:Chunk` node for chunk ID 53-chunk0007
# Creating `:Chunk` node for chunk ID 53-chunk0008
# Creating `:Chunk` node for chunk ID 53-chunk0009
# Creating `:Chunk` node for chunk ID 53-chunk0010
# Creating `:Chunk` node for chunk ID 53-chunk0011
# Creating `:Chunk` node for chunk ID 53-chunk0012
# Creating `:Chunk` node for chunk ID 53-chunk0013
# Creating `:Chunk` node for chunk ID 53-chunk0014
# Creating `:Chunk` node for chunk ID 54-chunk0000
# Creating `:Chunk` node for chunk ID 54-chunk0001
# Creating `:Chunk` node for chunk ID 54-chunk0002
# Creating `:Chunk` node for chunk ID 54-chunk0003
# Creating `:Chunk` node for chunk ID 54-chunk0004
# Creating `:Chunk` node for chunk ID 54-chunk0005
# Creating `:Chunk` node for chunk ID 54-chunk0006
# Creating `:Chunk` node for chunk ID 54-chunk0007
# Creating `:Chunk` node for chunk ID 54-chunk0008
# Creating `:Chunk` node for chunk ID 54-chunk0009
# Creating `:Chunk` node for chunk ID 54-chunk0010
# Creating `:Chunk` node for chunk ID 54-chunk0011
# Creating `:Chunk` node for chunk ID 54-chunk0012
# Creating `:Chunk` node for chunk ID 54-chunk0013
# Creating `:Chunk` node for chunk ID 54-chunk0014
# Creating `:Chunk` node for chunk ID 54-chunk0015
# Creating `:Chunk` node for chunk ID 54-chunk0016
# Creating `:Chunk` node for chunk ID 54-chunk0017
# Creating `:Chunk` node for chunk ID 54-chunk0018
# Creating `:Chunk` node for chunk ID 54-chunk0019
# Creating `:Chunk` node for chunk ID 54-chunk0020
# Creating `:Chunk` node for chunk ID 55-chunk0000
# Creating `:Chunk` node for chunk ID 55-chunk0001
# Creating `:Chunk` node for chunk ID 55-chunk0002
# Creating `:Chunk` node for chunk ID 55-chunk0003
# Creating `:Chunk` node for chunk ID 55-chunk0004
# Creating `:Chunk` node for chunk ID 55-chunk0005
# Creating `:Chunk` node for chunk ID 55-chunk0006
# Creating `:Chunk` node for chunk ID 55-chunk0007
# Creating `:Chunk` node for chunk ID 55-chunk0008
# Creating `:Chunk` node for chunk ID 55-chunk0009
# Creating `:Chunk` node for chunk ID 55-chunk0010
# Creating `:Chunk` node for chunk ID 55-chunk0011
# Creating `:Chunk` node for chunk ID 55-chunk0012
# Creating `:Chunk` node for chunk ID 55-chunk0013
# Creating `:Chunk` node for chunk ID 55-chunk0014
# Creating `:Chunk` node for chunk ID 55-chunk0015
# Creating `:Chunk` node for chunk ID 55-chunk0016
# Creating `:Chunk` node for chunk ID 55-chunk0017
# Creating `:Chunk` node for chunk ID 55-chunk0018
# Creating `:Chunk` node for chunk ID 55-chunk0019
# Creating `:Chunk` node for chunk ID 55-chunk0020
# Creating `:Chunk` node for chunk ID 56-chunk0000
# Creating `:Chunk` node for chunk ID 56-chunk0001
# Creating `:Chunk` node for chunk ID 56-chunk0002
# Creating `:Chunk` node for chunk ID 56-chunk0003
# Creating `:Chunk` node for chunk ID 56-chunk0004
# Creating `:Chunk` node for chunk ID 56-chunk0005
# Creating `:Chunk` node for chunk ID 56-chunk0006
# Creating `:Chunk` node for chunk ID 56-chunk0007
# Creating `:Chunk` node for chunk ID 56-chunk0008
# Creating `:Chunk` node for chunk ID 57-chunk0000
# Creating `:Chunk` node for chunk ID 57-chunk0001
# Creating `:Chunk` node for chunk ID 57-chunk0002
# Creating `:Chunk` node for chunk ID 57-chunk0003
# Creating `:Chunk` node for chunk ID 57-chunk0004
# Creating `:Chunk` node for chunk ID 57-chunk0005
# Creating `:Chunk` node for chunk ID 57-chunk0006
# Creating `:Chunk` node for chunk ID 57-chunk0007
# Creating `:Chunk` node for chunk ID 57-chunk0008
# Creating `:Chunk` node for chunk ID 57-chunk0009
# Creating `:Chunk` node for chunk ID 57-chunk0010
# Creating `:Chunk` node for chunk ID 57-chunk0011
# Creating `:Chunk` node for chunk ID 57-chunk0012
# Creating `:Chunk` node for chunk ID 57-chunk0013
# Creating `:Chunk` node for chunk ID 57-chunk0014
# Creating `:Chunk` node for chunk ID 57-chunk0015
# Creating `:Chunk` node for chunk ID 57-chunk0016
# Creating `:Chunk` node for chunk ID 57-chunk0017
# Creating `:Chunk` node for chunk ID 57-chunk0018
# Creating `:Chunk` node for chunk ID 57-chunk0019
# Creating `:Chunk` node for chunk ID 58-chunk0000
# Creating `:Chunk` node for chunk ID 58-chunk0001
# Creating `:Chunk` node for chunk ID 58-chunk0002
# Creating `:Chunk` node for chunk ID 58-chunk0003
# Creating `:Chunk` node for chunk ID 58-chunk0004
# Creating `:Chunk` node for chunk ID 58-chunk0005
# Creating `:Chunk` node for chunk ID 58-chunk0006
# Creating `:Chunk` node for chunk ID 58-chunk0007
# Creating `:Chunk` node for chunk ID 58-chunk0008
# Creating `:Chunk` node for chunk ID 58-chunk0009
# Creating `:Chunk` node for chunk ID 58-chunk0010
# Creating `:Chunk` node for chunk ID 58-chunk0011
# Creating `:Chunk` node for chunk ID 59-chunk0000
# Creating `:Chunk` node for chunk ID 59-chunk0001
# Creating `:Chunk` node for chunk ID 59-chunk0002
# Creating `:Chunk` node for chunk ID 59-chunk0003
# Creating `:Chunk` node for chunk ID 59-chunk0004
# Creating `:Chunk` node for chunk ID 59-chunk0005
# Creating `:Chunk` node for chunk ID 59-chunk0006
# Creating `:Chunk` node for chunk ID 59-chunk0007
# ...
# Creating `:Chunk` node for chunk ID 213-chunk0011
# Creating `:Chunk` node for chunk ID 213-chunk0012
# Creating `:Chunk` node for chunk ID 213-chunk0013
# Creating `:Chunk` node for chunk ID 213-chunk0014
# Creating `:Chunk` node for chunk ID 214-chunk0000
# Creating `:Chunk` node for chunk ID 214-chunk0001
# Creating `:Chunk` node for chunk ID 214-chunk0002
# Creating `:Chunk` node for chunk ID 214-chunk0003
# Creating `:Chunk` node for chunk ID 214-chunk0004
# Creating `:Chunk` node for chunk ID 214-chunk0005
# Creating `:Chunk` node for chunk ID 214-chunk0006
# Creating `:Chunk` node for chunk ID 214-chunk0007
# Creating `:Chunk` node for chunk ID 214-chunk0008
# Creating `:Chunk` node for chunk ID 214-chunk0009
# Creating `:Chunk` node for chunk ID 214-chunk0010
# Creating `:Chunk` node for chunk ID 214-chunk0011
# Creating `:Chunk` node for chunk ID 214-chunk0012
# Creating `:Chunk` node for chunk ID 214-chunk0013
# Creating `:Chunk` node for chunk ID 214-chunk0014
# Creating `:Chunk` node for chunk ID 214-chunk0015
# Creating `:Chunk` node for chunk ID 215-chunk0000
# Creating `:Chunk` node for chunk ID 215-chunk0001
# Creating `:Chunk` node for chunk ID 215-chunk0002
# Creating `:Chunk` node for chunk ID 215-chunk0003
# Creating `:Chunk` node for chunk ID 215-chunk0004
# Creating `:Chunk` node for chunk ID 215-chunk0005
# Creating `:Chunk` node for chunk ID 215-chunk0006
# Creating `:Chunk` node for chunk ID 215-chunk0007
# Creating `:Chunk` node for chunk ID 215-chunk0008
# Creating `:Chunk` node for chunk ID 215-chunk0009
# Creating `:Chunk` node for chunk ID 215-chunk0010
# Creating `:Chunk` node for chunk ID 215-chunk0011
# Creating `:Chunk` node for chunk ID 215-chunk0012
# Creating `:Chunk` node for chunk ID 215-chunk0013
# Creating `:Chunk` node for chunk ID 215-chunk0014
# Creating `:Chunk` node for chunk ID 215-chunk0015
# Creating `:Chunk` node for chunk ID 215-chunk0016
# Creating `:Chunk` node for chunk ID 216-chunk0000
# Creating `:Chunk` node for chunk ID 216-chunk0001
# Creating `:Chunk` node for chunk ID 216-chunk0002
# Creating `:Chunk` node for chunk ID 216-chunk0003
# Creating `:Chunk` node for chunk ID 216-chunk0004
# Creating `:Chunk` node for chunk ID 216-chunk0005
# Creating `:Chunk` node for chunk ID 216-chunk0006
# Creating `:Chunk` node for chunk ID 216-chunk0007
# Creating `:Chunk` node for chunk ID 216-chunk0008
# Creating `:Chunk` node for chunk ID 216-chunk0009
# Creating `:Chunk` node for chunk ID 216-chunk0010
# Creating `:Chunk` node for chunk ID 216-chunk0011
# Creating `:Chunk` node for chunk ID 217-chunk0000
# Creating `:Chunk` node for chunk ID 217-chunk0001
# Creating `:Chunk` node for chunk ID 217-chunk0002
# Creating `:Chunk` node for chunk ID 217-chunk0003
# Creating `:Chunk` node for chunk ID 217-chunk0004
# Creating `:Chunk` node for chunk ID 218-chunk0000
# Creating `:Chunk` node for chunk ID 218-chunk0001
# Creating `:Chunk` node for chunk ID 218-chunk0002
# Creating `:Chunk` node for chunk ID 218-chunk0003
# Creating `:Chunk` node for chunk ID 218-chunk0004
# Creating `:Chunk` node for chunk ID 218-chunk0005
# Creating `:Chunk` node for chunk ID 218-chunk0006
# Creating `:Chunk` node for chunk ID 218-chunk0007
# Creating `:Chunk` node for chunk ID 218-chunk0008
# Creating `:Chunk` node for chunk ID 218-chunk0009
# Creating `:Chunk` node for chunk ID 218-chunk0010
# Creating `:Chunk` node for chunk ID 218-chunk0011
# Creating `:Chunk` node for chunk ID 218-chunk0012
# Creating `:Chunk` node for chunk ID 218-chunk0013
# Creating `:Chunk` node for chunk ID 219-chunk0000
# Creating `:Chunk` node for chunk ID 219-chunk0001
# Creating `:Chunk` node for chunk ID 219-chunk0002
# Creating `:Chunk` node for chunk ID 219-chunk0003
# Creating `:Chunk` node for chunk ID 219-chunk0004
# Creating `:Chunk` node for chunk ID 219-chunk0005
# Creating `:Chunk` node for chunk ID 219-chunk0006
# Creating `:Chunk` node for chunk ID 219-chunk0007
# Creating `:Chunk` node for chunk ID 219-chunk0008
# Creating `:Chunk` node for chunk ID 219-chunk0009
# Creating `:Chunk` node for chunk ID 219-chunk0010
# Creating `:Chunk` node for chunk ID 219-chunk0011
# Creating `:Chunk` node for chunk ID 219-chunk0012
# Creating `:Chunk` node for chunk ID 219-chunk0013
# Creating `:Chunk` node for chunk ID 219-chunk0014
# Creating `:Chunk` node for chunk ID 219-chunk0015
# Creating `:Chunk` node for chunk ID 219-chunk0016
# Creating `:Chunk` node for chunk ID 220-chunk0000
# Creating `:Chunk` node for chunk ID 220-chunk0001
# Creating `:Chunk` node for chunk ID 220-chunk0002
# Creating `:Chunk` node for chunk ID 220-chunk0003
# Creating `:Chunk` node for chunk ID 220-chunk0004
# Creating `:Chunk` node for chunk ID 220-chunk0005
# Creating `:Chunk` node for chunk ID 220-chunk0006
# Creating `:Chunk` node for chunk ID 220-chunk0007
# Creating `:Chunk` node for chunk ID 220-chunk0008
# Creating `:Chunk` node for chunk ID 220-chunk0009
# Creating `:Chunk` node for chunk ID 220-chunk0010
# Creating `:Chunk` node for chunk ID 220-chunk0011
# Creating `:Chunk` node for chunk ID 220-chunk0012
# Creating `:Chunk` node for chunk ID 220-chunk0013
# Creating `:Chunk` node for chunk ID 220-chunk0014
# Creating `:Chunk` node for chunk ID 220-chunk0015
# Creating `:Chunk` node for chunk ID 220-chunk0016
# Creating `:Chunk` node for chunk ID 220-chunk0017
# Creating `:Chunk` node for chunk ID 220-chunk0018
# Creating `:Chunk` node for chunk ID 220-chunk0019
# Creating `:Chunk` node for chunk ID 221-chunk0000
# Creating `:Chunk` node for chunk ID 221-chunk0001
# Creating `:Chunk` node for chunk ID 221-chunk0002
# Creating `:Chunk` node for chunk ID 221-chunk0003
# Creating `:Chunk` node for chunk ID 221-chunk0004
# Creating `:Chunk` node for chunk ID 221-chunk0005
# Creating `:Chunk` node for chunk ID 221-chunk0006
# Creating `:Chunk` node for chunk ID 221-chunk0007
# Creating `:Chunk` node for chunk ID 221-chunk0008
# Creating `:Chunk` node for chunk ID 221-chunk0009
# Creating `:Chunk` node for chunk ID 221-chunk0010
# Creating `:Chunk` node for chunk ID 221-chunk0011
# Creating `:Chunk` node for chunk ID 221-chunk0012
# Creating `:Chunk` node for chunk ID 221-chunk0013
# Creating `:Chunk` node for chunk ID 222-chunk0000
# Creating `:Chunk` node for chunk ID 222-chunk0001
# Creating `:Chunk` node for chunk ID 222-chunk0002
# Creating `:Chunk` node for chunk ID 222-chunk0003
# Creating `:Chunk` node for chunk ID 222-chunk0004
# Creating `:Chunk` node for chunk ID 222-chunk0005
# Creating `:Chunk` node for chunk ID 222-chunk0006
# Creating `:Chunk` node for chunk ID 222-chunk0007
# Creating `:Chunk` node for chunk ID 222-chunk0008
# Creating `:Chunk` node for chunk ID 222-chunk0009
# Creating `:Chunk` node for chunk ID 222-chunk0010
# Creating `:Chunk` node for chunk ID 222-chunk0011
# Creating `:Chunk` node for chunk ID 222-chunk0012
# Creating `:Chunk` node for chunk ID 223-chunk0000
# Creating `:Chunk` node for chunk ID 223-chunk0001
# Creating `:Chunk` node for chunk ID 223-chunk0002
# Creating `:Chunk` node for chunk ID 223-chunk0003
# Creating `:Chunk` node for chunk ID 223-chunk0004
# Creating `:Chunk` node for chunk ID 223-chunk0005
# Creating `:Chunk` node for chunk ID 223-chunk0006
# Creating `:Chunk` node for chunk ID 223-chunk0007
# Creating `:Chunk` node for chunk ID 223-chunk0008
# Creating `:Chunk` node for chunk ID 223-chunk0009
# Creating `:Chunk` node for chunk ID 223-chunk0010
# Creating `:Chunk` node for chunk ID 223-chunk0011
# Creating `:Chunk` node for chunk ID 223-chunk0012
# Creating `:Chunk` node for chunk ID 223-chunk0013
# Creating `:Chunk` node for chunk ID 223-chunk0014
# Creating `:Chunk` node for chunk ID 223-chunk0015
# Creating `:Chunk` node for chunk ID 223-chunk0016
# Creating `:Chunk` node for chunk ID 224-chunk0000
# Creating `:Chunk` node for chunk ID 224-chunk0001
# Creating `:Chunk` node for chunk ID 224-chunk0002
# Creating `:Chunk` node for chunk ID 224-chunk0003
# Creating `:Chunk` node for chunk ID 224-chunk0004
# Creating `:Chunk` node for chunk ID 224-chunk0005
# Creating `:Chunk` node for chunk ID 224-chunk0006
# Creating `:Chunk` node for chunk ID 224-chunk0007
# Creating `:Chunk` node for chunk ID 224-chunk0008
# Creating `:Chunk` node for chunk ID 224-chunk0009
# Creating `:Chunk` node for chunk ID 224-chunk0010
# Creating `:Chunk` node for chunk ID 224-chunk0011
# Creating `:Chunk` node for chunk ID 224-chunk0012
# Creating `:Chunk` node for chunk ID 224-chunk0013
# Creating `:Chunk` node for chunk ID 224-chunk0014
# Creating `:Chunk` node for chunk ID 224-chunk0015
# Creating `:Chunk` node for chunk ID 224-chunk0016
# Creating `:Chunk` node for chunk ID 225-chunk0000
# Creating `:Chunk` node for chunk ID 225-chunk0001
# Creating `:Chunk` node for chunk ID 225-chunk0002
# Creating `:Chunk` node for chunk ID 225-chunk0003
# Creating `:Chunk` node for chunk ID 225-chunk0004
# Creating `:Chunk` node for chunk ID 225-chunk0005
# Creating `:Chunk` node for chunk ID 225-chunk0006
# Creating `:Chunk` node for chunk ID 225-chunk0007
# Creating `:Chunk` node for chunk ID 225-chunk0008
# Creating `:Chunk` node for chunk ID 225-chunk0009
# Creating `:Chunk` node for chunk ID 225-chunk0010
# Creating `:Chunk` node for chunk ID 225-chunk0011
# Creating `:Chunk` node for chunk ID 225-chunk0012
# Creating `:Chunk` node for chunk ID 225-chunk0013
# Creating `:Chunk` node for chunk ID 226-chunk0000
# Creating `:Chunk` node for chunk ID 226-chunk0001
# Creating `:Chunk` node for chunk ID 226-chunk0002
# Creating `:Chunk` node for chunk ID 226-chunk0003
# Creating `:Chunk` node for chunk ID 226-chunk0004
# Creating `:Chunk` node for chunk ID 226-chunk0005
# Creating `:Chunk` node for chunk ID 226-chunk0006
# Creating `:Chunk` node for chunk ID 226-chunk0007
# Creating `:Chunk` node for chunk ID 226-chunk0008
# Creating `:Chunk` node for chunk ID 226-chunk0009
# Creating `:Chunk` node for chunk ID 227-chunk0000
# Creating `:Chunk` node for chunk ID 227-chunk0001
# Creating `:Chunk` node for chunk ID 227-chunk0002
# Creating `:Chunk` node for chunk ID 227-chunk0003
# Creating `:Chunk` node for chunk ID 227-chunk0004
# Creating `:Chunk` node for chunk ID 227-chunk0005
# Creating `:Chunk` node for chunk ID 227-chunk0006
# Creating `:Chunk` node for chunk ID 227-chunk0007
# Creating `:Chunk` node for chunk ID 227-chunk0008
# Creating `:Chunk` node for chunk ID 227-chunk0009
# Creating `:Chunk` node for chunk ID 227-chunk0010
# Creating `:Chunk` node for chunk ID 228-chunk0000
# Creating `:Chunk` node for chunk ID 228-chunk0001
# Creating `:Chunk` node for chunk ID 228-chunk0002
# Creating `:Chunk` node for chunk ID 228-chunk0003
# Creating `:Chunk` node for chunk ID 228-chunk0004
# Creating `:Chunk` node for chunk ID 228-chunk0005
# Creating `:Chunk` node for chunk ID 228-chunk0006
# Creating `:Chunk` node for chunk ID 228-chunk0007
# Creating `:Chunk` node for chunk ID 228-chunk0008
# Creating `:Chunk` node for chunk ID 228-chunk0009
# Creating `:Chunk` node for chunk ID 228-chunk0010
# Creating `:Chunk` node for chunk ID 228-chunk0011
# Creating `:Chunk` node for chunk ID 229-chunk0000
# Creating `:Chunk` node for chunk ID 229-chunk0001
# Creating `:Chunk` node for chunk ID 229-chunk0002
# Creating `:Chunk` node for chunk ID 229-chunk0003
# Creating `:Chunk` node for chunk ID 229-chunk0004
# Creating `:Chunk` node for chunk ID 229-chunk0005
# Creating `:Chunk` node for chunk ID 229-chunk0006
# Creating `:Chunk` node for chunk ID 229-chunk0007
# Creating `:Chunk` node for chunk ID 229-chunk0008
# Creating `:Chunk` node for chunk ID 230-chunk0000
# Creating `:Chunk` node for chunk ID 230-chunk0001
# Creating `:Chunk` node for chunk ID 230-chunk0002
# Creating `:Chunk` node for chunk ID 230-chunk0003
# Creating `:Chunk` node for chunk ID 230-chunk0004
# Creating `:Chunk` node for chunk ID 230-chunk0005
# Creating `:Chunk` node for chunk ID 230-chunk0006
# Creating `:Chunk` node for chunk ID 230-chunk0007
# Creating `:Chunk` node for chunk ID 231-chunk0000
# Creating `:Chunk` node for chunk ID 231-chunk0001
# Creating `:Chunk` node for chunk ID 231-chunk0002
# Creating `:Chunk` node for chunk ID 231-chunk0003
# Creating `:Chunk` node for chunk ID 231-chunk0004
# Creating `:Chunk` node for chunk ID 231-chunk0005
# Creating `:Chunk` node for chunk ID 231-chunk0006
# Creating `:Chunk` node for chunk ID 231-chunk0007
# Creating `:Chunk` node for chunk ID 231-chunk0008
# Creating `:Chunk` node for chunk ID 231-chunk0009
# Creating `:Chunk` node for chunk ID 231-chunk0010
# Creating `:Chunk` node for chunk ID 231-chunk0011
# Creating `:Chunk` node for chunk ID 231-chunk0012
# Creating `:Chunk` node for chunk ID 231-chunk0013
# Creating `:Chunk` node for chunk ID 231-chunk0014
# Creating `:Chunk` node for chunk ID 231-chunk0015
# Creating `:Chunk` node for chunk ID 232-chunk0000
# Creating `:Chunk` node for chunk ID 232-chunk0001
# Creating `:Chunk` node for chunk ID 232-chunk0002
# Creating `:Chunk` node for chunk ID 232-chunk0003
# Creating `:Chunk` node for chunk ID 232-chunk0004
# Creating `:Chunk` node for chunk ID 232-chunk0005
# Creating `:Chunk` node for chunk ID 232-chunk0006
# Creating `:Chunk` node for chunk ID 232-chunk0007
# Creating `:Chunk` node for chunk ID 232-chunk0008
# Creating `:Chunk` node for chunk ID 232-chunk0009
# Creating `:Chunk` node for chunk ID 232-chunk0010
# Creating `:Chunk` node for chunk ID 232-chunk0011
# Creating `:Chunk` node for chunk ID 232-chunk0012
# Creating `:Chunk` node for chunk ID 232-chunk0013
# Creating `:Chunk` node for chunk ID 232-chunk0014
# Creating `:Chunk` node for chunk ID 232-chunk0015
# Creating `:Chunk` node for chunk ID 232-chunk0016
# Creating `:Chunk` node for chunk ID 233-chunk0000
# Creating `:Chunk` node for chunk ID 233-chunk0001
# Creating `:Chunk` node for chunk ID 233-chunk0002
# Creating `:Chunk` node for chunk ID 233-chunk0003
# Creating `:Chunk` node for chunk ID 233-chunk0004
# Creating `:Chunk` node for chunk ID 233-chunk0005
# Creating `:Chunk` node for chunk ID 233-chunk0006
# Creating `:Chunk` node for chunk ID 233-chunk0007
# Creating `:Chunk` node for chunk ID 234-chunk0000
# Creating `:Chunk` node for chunk ID 234-chunk0001
# Creating `:Chunk` node for chunk ID 234-chunk0002
# Creating `:Chunk` node for chunk ID 234-chunk0003
# Creating `:Chunk` node for chunk ID 234-chunk0004
# Creating `:Chunk` node for chunk ID 234-chunk0005
# Creating `:Chunk` node for chunk ID 234-chunk0006
# Creating `:Chunk` node for chunk ID 234-chunk0007
# Creating `:Chunk` node for chunk ID 234-chunk0008
# Creating `:Chunk` node for chunk ID 234-chunk0009
# Creating `:Chunk` node for chunk ID 234-chunk0010
# Creating `:Chunk` node for chunk ID 234-chunk0011
# Creating `:Chunk` node for chunk ID 234-chunk0012
# Creating `:Chunk` node for chunk ID 234-chunk0013
# Creating `:Chunk` node for chunk ID 234-chunk0014
# Creating `:Chunk` node for chunk ID 234-chunk0015
# Creating `:Chunk` node for chunk ID 234-chunk0016
# Creating `:Chunk` node for chunk ID 234-chunk0017
# Creating `:Chunk` node for chunk ID 235-chunk0000
# Creating `:Chunk` node for chunk ID 235-chunk0001
# Creating `:Chunk` node for chunk ID 235-chunk0002
# Creating `:Chunk` node for chunk ID 235-chunk0003
# Creating `:Chunk` node for chunk ID 235-chunk0004
# Creating `:Chunk` node for chunk ID 235-chunk0005
# Creating `:Chunk` node for chunk ID 235-chunk0006
# Creating `:Chunk` node for chunk ID 236-chunk0000
# Creating `:Chunk` node for chunk ID 236-chunk0001
# Creating `:Chunk` node for chunk ID 236-chunk0002
# Creating `:Chunk` node for chunk ID 236-chunk0003
# Creating `:Chunk` node for chunk ID 236-chunk0004
# Creating `:Chunk` node for chunk ID 236-chunk0005
# Creating `:Chunk` node for chunk ID 236-chunk0006
# Creating `:Chunk` node for chunk ID 237-chunk0000
# Creating `:Chunk` node for chunk ID 237-chunk0001
# Creating `:Chunk` node for chunk ID 237-chunk0002
# Creating `:Chunk` node for chunk ID 237-chunk0003
# Creating `:Chunk` node for chunk ID 237-chunk0004
# Creating `:Chunk` node for chunk ID 237-chunk0005
# Creating `:Chunk` node for chunk ID 237-chunk0006
# Creating `:Chunk` node for chunk ID 237-chunk0007
# Creating `:Chunk` node for chunk ID 237-chunk0008
# Creating `:Chunk` node for chunk ID 238-chunk0000
# Creating `:Chunk` node for chunk ID 238-chunk0001
# Creating `:Chunk` node for chunk ID 238-chunk0002
# Creating `:Chunk` node for chunk ID 238-chunk0003
# Creating `:Chunk` node for chunk ID 238-chunk0004
# Creating `:Chunk` node for chunk ID 238-chunk0005
# Creating `:Chunk` node for chunk ID 238-chunk0006
# Created 4020 nodes

# %%
#nodes to be queried need to have a source property
kg.query("""MATCH (chunk:Chunk)-[PART_OF]->(blog:Blog)
            SET
            chunk.source = blog.source""", )
# Out:
# []

# %%
cypher = """
  MATCH (anyBlog:Blog)
  RETURN anyBlog.fileId AS fileId
  """
file_list = kg.query(cypher)

# %%
#Create PART_OF relationship between blog node and chunk nodes belonging to it
for file in file_list:
    cypher = """
      MATCH (from_same_file:Chunk), (blog:Blog{fileId: $formIdParam})
      WHERE from_same_file.formId = $formIdParam
      MERGE (from_same_file)-[:PART_OF]->(blog)
      WITH collect(from_same_file) as file_chunk_list
      RETURN size(file_chunk_list)
    """
    len = kg.query(cypher, params={'formIdParam': file['fileId']})
    print(f"Linked {len} chunks from file {file}")
kg.refresh_schema()
print(kg.schema)
# Out:
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '0'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '1'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '2'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '3'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '4'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '5'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '6'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '7'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '8'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '9'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '10'}
# Linked [{'size(file_chunk_list)': 27}] chunks from file {'fileId': '11'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '12'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '13'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '14'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '15'}
# Linked [{'size(file_chunk_list)': 41}] chunks from file {'fileId': '16'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '17'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '18'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '19'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '20'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '21'}
# Linked [{'size(file_chunk_list)': 35}] chunks from file {'fileId': '22'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '23'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '24'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '25'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '26'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '27'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '28'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '29'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '30'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '31'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '32'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '33'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '34'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '35'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '36'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '37'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '38'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '39'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '40'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '41'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '42'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '43'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '44'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '45'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '46'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '47'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '48'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '49'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '50'}
# Linked [{'size(file_chunk_list)': 34}] chunks from file {'fileId': '51'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '52'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '53'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '54'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '55'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '56'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '57'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '58'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '59'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '60'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '61'}
# Linked [{'size(file_chunk_list)': 29}] chunks from file {'fileId': '62'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '63'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '64'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '65'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '66'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '67'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '68'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '69'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '70'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '71'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '72'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '73'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '74'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '75'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '76'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '77'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '78'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '79'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '80'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '81'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '82'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '83'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '84'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '85'}
# Linked [{'size(file_chunk_list)': 39}] chunks from file {'fileId': '86'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '87'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '88'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '89'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '90'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '91'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '92'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '93'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '94'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '95'}
# Linked [{'size(file_chunk_list)': 50}] chunks from file {'fileId': '96'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '97'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '98'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '99'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '100'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '101'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '102'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '103'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '104'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '105'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '106'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '107'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '108'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '109'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '110'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '111'}
# Linked [{'size(file_chunk_list)': 36}] chunks from file {'fileId': '112'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '113'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '114'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '115'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '116'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '117'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '118'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '119'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '120'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '121'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '122'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '123'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '124'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '125'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '126'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '127'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '128'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '129'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '130'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '131'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '132'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '133'}
# Linked [{'size(file_chunk_list)': 29}] chunks from file {'fileId': '134'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '135'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '136'}
# Linked [{'size(file_chunk_list)': 41}] chunks from file {'fileId': '137'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '138'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '139'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '140'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '141'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '142'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '143'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '144'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '145'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '146'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '147'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '148'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '149'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '150'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '151'}
# Linked [{'size(file_chunk_list)': 38}] chunks from file {'fileId': '152'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '153'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '154'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '155'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '156'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '157'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '158'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '159'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '160'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '161'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '162'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '163'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '164'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '165'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '166'}
# Linked [{'size(file_chunk_list)': 39}] chunks from file {'fileId': '167'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '168'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '169'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '170'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '171'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '172'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '173'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '174'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '175'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '176'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '177'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '178'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '179'}
# Linked [{'size(file_chunk_list)': 36}] chunks from file {'fileId': '180'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '181'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '182'}
# Linked [{'size(file_chunk_list)': 37}] chunks from file {'fileId': '183'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '184'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '185'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '186'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '187'}
# Linked [{'size(file_chunk_list)': 44}] chunks from file {'fileId': '188'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '189'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '190'}
# Linked [{'size(file_chunk_list)': 75}] chunks from file {'fileId': '191'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '192'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '193'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '194'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '195'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '196'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '197'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '198'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '199'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '200'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '201'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '202'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '203'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '204'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '205'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '206'}
# Linked [{'size(file_chunk_list)': 27}] chunks from file {'fileId': '207'}
# Linked [{'size(file_chunk_list)': 50}] chunks from file {'fileId': '208'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '209'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '210'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '211'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '212'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '213'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '214'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '215'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '216'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '217'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '218'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '219'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '220'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '221'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '222'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '223'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '224'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '225'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '226'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '227'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '228'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '229'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '230'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '231'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '232'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '233'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '234'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '235'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '236'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '237'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '238'}
# Node properties:
# Chunk {chunkId: STRING, title: STRING, formId: STRING, chunkSeqId: INTEGER, text: STRING}
# Blog {title: STRING, source: STRING, fileId: STRING, label: STRING, time: STRING, intro: STRING}
# Relationship properties:
#
# The relationships:
# (:Chunk)-[:PART_OF]->(:Blog)

# %%
#create NEXT relationship between consecutive chunks
for file in file_list:
    cypher = """
      MATCH (from_same_file:Chunk)
      WHERE from_same_file.formId = $formIdParam
      WITH from_same_file
        ORDER BY from_same_file.chunkSeqId ASC
      WITH collect(from_same_file) as file_chunk_list
        CALL apoc.nodes.link(
            file_chunk_list,
            "NEXT",
            {avoidDuplicates: true}
        )
      RETURN size(file_chunk_list)
    """
    len = kg.query(cypher, params={'formIdParam': file['fileId']})
    print(f"Linked {len} chunks from file {file}")
kg.refresh_schema()
print(kg.schema)
# Out:
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '0'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '1'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '2'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '3'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '4'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '5'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '6'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '7'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '8'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '9'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '10'}
# Linked [{'size(file_chunk_list)': 27}] chunks from file {'fileId': '11'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '12'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '13'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '14'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '15'}
# Linked [{'size(file_chunk_list)': 41}] chunks from file {'fileId': '16'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '17'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '18'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '19'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '20'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '21'}
# Linked [{'size(file_chunk_list)': 35}] chunks from file {'fileId': '22'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '23'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '24'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '25'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '26'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '27'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '28'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '29'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '30'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '31'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '32'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '33'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '34'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '35'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '36'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '37'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '38'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '39'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '40'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '41'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '42'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '43'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '44'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '45'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '46'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '47'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '48'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '49'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '50'}
# Linked [{'size(file_chunk_list)': 34}] chunks from file {'fileId': '51'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '52'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '53'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '54'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '55'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '56'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '57'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '58'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '59'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '60'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '61'}
# Linked [{'size(file_chunk_list)': 29}] chunks from file {'fileId': '62'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '63'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '64'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '65'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '66'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '67'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '68'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '69'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '70'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '71'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '72'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '73'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '74'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '75'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '76'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '77'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '78'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '79'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '80'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '81'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '82'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '83'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '84'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '85'}
# Linked [{'size(file_chunk_list)': 39}] chunks from file {'fileId': '86'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '87'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '88'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '89'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '90'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '91'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '92'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '93'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '94'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '95'}
# Linked [{'size(file_chunk_list)': 50}] chunks from file {'fileId': '96'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '97'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '98'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '99'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '100'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '101'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '102'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '103'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '104'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '105'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '106'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '107'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '108'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '109'}
# Linked [{'size(file_chunk_list)': 3}] chunks from file {'fileId': '110'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '111'}
# Linked [{'size(file_chunk_list)': 36}] chunks from file {'fileId': '112'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '113'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '114'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '115'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '116'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '117'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '118'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '119'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '120'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '121'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '122'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '123'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '124'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '125'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '126'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '127'}
# Linked [{'size(file_chunk_list)': 4}] chunks from file {'fileId': '128'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '129'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '130'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '131'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '132'}
# Linked [{'size(file_chunk_list)': 24}] chunks from file {'fileId': '133'}
# Linked [{'size(file_chunk_list)': 29}] chunks from file {'fileId': '134'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '135'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '136'}
# Linked [{'size(file_chunk_list)': 41}] chunks from file {'fileId': '137'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '138'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '139'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '140'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '141'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '142'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '143'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '144'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '145'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '146'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '147'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '148'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '149'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '150'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '151'}
# Linked [{'size(file_chunk_list)': 38}] chunks from file {'fileId': '152'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '153'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '154'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '155'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '156'}
# Linked [{'size(file_chunk_list)': 21}] chunks from file {'fileId': '157'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '158'}
# Linked [{'size(file_chunk_list)': 26}] chunks from file {'fileId': '159'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '160'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '161'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '162'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '163'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '164'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '165'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '166'}
# Linked [{'size(file_chunk_list)': 39}] chunks from file {'fileId': '167'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '168'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '169'}
# Linked [{'size(file_chunk_list)': 33}] chunks from file {'fileId': '170'}
# Linked [{'size(file_chunk_list)': 30}] chunks from file {'fileId': '171'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '172'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '173'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '174'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '175'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '176'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '177'}
# Linked [{'size(file_chunk_list)': 0}] chunks from file {'fileId': '178'}
# Linked [{'size(file_chunk_list)': 32}] chunks from file {'fileId': '179'}
# Linked [{'size(file_chunk_list)': 36}] chunks from file {'fileId': '180'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '181'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '182'}
# Linked [{'size(file_chunk_list)': 37}] chunks from file {'fileId': '183'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '184'}
# Linked [{'size(file_chunk_list)': 28}] chunks from file {'fileId': '185'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '186'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '187'}
# Linked [{'size(file_chunk_list)': 44}] chunks from file {'fileId': '188'}
# Linked [{'size(file_chunk_list)': 19}] chunks from file {'fileId': '189'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '190'}
# Linked [{'size(file_chunk_list)': 75}] chunks from file {'fileId': '191'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '192'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '193'}
# Linked [{'size(file_chunk_list)': 31}] chunks from file {'fileId': '194'}
# Linked [{'size(file_chunk_list)': 25}] chunks from file {'fileId': '195'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '196'}
# Linked [{'size(file_chunk_list)': 6}] chunks from file {'fileId': '197'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '198'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '199'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '200'}
# Linked [{'size(file_chunk_list)': 22}] chunks from file {'fileId': '201'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '202'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '203'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '204'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '205'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '206'}
# Linked [{'size(file_chunk_list)': 27}] chunks from file {'fileId': '207'}
# Linked [{'size(file_chunk_list)': 50}] chunks from file {'fileId': '208'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '209'}
# Linked [{'size(file_chunk_list)': 23}] chunks from file {'fileId': '210'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '211'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '212'}
# Linked [{'size(file_chunk_list)': 15}] chunks from file {'fileId': '213'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '214'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '215'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '216'}
# Linked [{'size(file_chunk_list)': 5}] chunks from file {'fileId': '217'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '218'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '219'}
# Linked [{'size(file_chunk_list)': 20}] chunks from file {'fileId': '220'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '221'}
# Linked [{'size(file_chunk_list)': 13}] chunks from file {'fileId': '222'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '223'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '224'}
# Linked [{'size(file_chunk_list)': 14}] chunks from file {'fileId': '225'}
# Linked [{'size(file_chunk_list)': 10}] chunks from file {'fileId': '226'}
# Linked [{'size(file_chunk_list)': 11}] chunks from file {'fileId': '227'}
# Linked [{'size(file_chunk_list)': 12}] chunks from file {'fileId': '228'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '229'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '230'}
# Linked [{'size(file_chunk_list)': 16}] chunks from file {'fileId': '231'}
# Linked [{'size(file_chunk_list)': 17}] chunks from file {'fileId': '232'}
# Linked [{'size(file_chunk_list)': 8}] chunks from file {'fileId': '233'}
# Linked [{'size(file_chunk_list)': 18}] chunks from file {'fileId': '234'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '235'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '236'}
# Linked [{'size(file_chunk_list)': 9}] chunks from file {'fileId': '237'}
# Linked [{'size(file_chunk_list)': 7}] chunks from file {'fileId': '238'}
# Node properties:
# Chunk {chunkId: STRING, title: STRING, formId: STRING, chunkSeqId: INTEGER, text: STRING}
# Blog {title: STRING, source: STRING, fileId: STRING, label: STRING, time: STRING, intro: STRING}
# Relationship properties:
#
# The relationships:
# (:Chunk)-[:NEXT]->(:Chunk)
# (:Chunk)-[:PART_OF]->(:Blog)

# %%
# create vector index
kg.query("""
         CREATE VECTOR INDEX `vector_chunks` IF NOT EXISTS
          FOR (c:Chunk) ON (c.textEmbedding)
          OPTIONS { indexConfig: {
            `vector.dimensions`: 768,
            `vector.similarity_function`: 'cosine'
         }}
""")
# Out:
# []

# %%
kg.query("SHOW INDEXES")
# Out:
# [{'id': 0,
#   'name': 'index_343aff4e',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'NODE',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 10, 20, 22, 31, 2, 551000000, tzinfo=<UTC>),
#   'readCount': 22811},
#  {'id': 1,
#   'name': 'index_f7700477',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'RELATIONSHIP',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': None,
#   'readCount': 0},
#  {'id': 2,
#   'name': 'vector_chunks',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'VECTOR',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['textEmbedding'],
#   'indexProvider': 'vector-2.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 10, 19, 13, 28, 3, 190000000, tzinfo=<UTC>),
#   'readCount': 84}]

# %%
#set vector property for text embeddings
node_count = 0
for chunk in all_chunks:
    print(f"Creating `:Chunk` node for chunk ID {chunk['chunkId']}")
    kg.query("""
        MATCH (chunk:Chunk) WHERE chunk.chunkId = $chunkParam.chunkId AND chunk.textEmbedding IS NULL
        CALL db.create.setNodeVectorProperty(chunk, "textEmbedding", $chunkParam.textEmbedding[0])
        """, params={'chunkParam': chunk})
    node_count += 1
print(f"Created {node_count} nodes")
# Out:
# Creating `:Chunk` node for chunk ID 0-chunk0000
# Creating `:Chunk` node for chunk ID 0-chunk0001
# Creating `:Chunk` node for chunk ID 0-chunk0002
# Creating `:Chunk` node for chunk ID 0-chunk0003
# Creating `:Chunk` node for chunk ID 0-chunk0004
# Creating `:Chunk` node for chunk ID 0-chunk0005
# Creating `:Chunk` node for chunk ID 0-chunk0006
# Creating `:Chunk` node for chunk ID 0-chunk0007
# Creating `:Chunk` node for chunk ID 0-chunk0008
# Creating `:Chunk` node for chunk ID 0-chunk0009
# Creating `:Chunk` node for chunk ID 0-chunk0010
# Creating `:Chunk` node for chunk ID 0-chunk0011
# Creating `:Chunk` node for chunk ID 0-chunk0012
# Creating `:Chunk` node for chunk ID 0-chunk0013
# Creating `:Chunk` node for chunk ID 0-chunk0014
# Creating `:Chunk` node for chunk ID 0-chunk0015
# Creating `:Chunk` node for chunk ID 0-chunk0016
# Creating `:Chunk` node for chunk ID 0-chunk0017
# Creating `:Chunk` node for chunk ID 0-chunk0018
# Creating `:Chunk` node for chunk ID 0-chunk0019
# Creating `:Chunk` node for chunk ID 1-chunk0000
# Creating `:Chunk` node for chunk ID 1-chunk0001
# Creating `:Chunk` node for chunk ID 1-chunk0002
# Creating `:Chunk` node for chunk ID 1-chunk0003
# Creating `:Chunk` node for chunk ID 1-chunk0004
# Creating `:Chunk` node for chunk ID 1-chunk0005
# Creating `:Chunk` node for chunk ID 1-chunk0006
# Creating `:Chunk` node for chunk ID 1-chunk0007
# Creating `:Chunk` node for chunk ID 2-chunk0000
# Creating `:Chunk` node for chunk ID 2-chunk0001
# Creating `:Chunk` node for chunk ID 2-chunk0002
# Creating `:Chunk` node for chunk ID 2-chunk0003
# Creating `:Chunk` node for chunk ID 2-chunk0004
# Creating `:Chunk` node for chunk ID 2-chunk0005
# Creating `:Chunk` node for chunk ID 2-chunk0006
# Creating `:Chunk` node for chunk ID 2-chunk0007
# Creating `:Chunk` node for chunk ID 2-chunk0008
# Creating `:Chunk` node for chunk ID 2-chunk0009
# Creating `:Chunk` node for chunk ID 2-chunk0010
# Creating `:Chunk` node for chunk ID 2-chunk0011
# Creating `:Chunk` node for chunk ID 2-chunk0012
# Creating `:Chunk` node for chunk ID 2-chunk0013
# Creating `:Chunk` node for chunk ID 2-chunk0014
# Creating `:Chunk` node for chunk ID 2-chunk0015
# Creating `:Chunk` node for chunk ID 2-chunk0016
# Creating `:Chunk` node for chunk ID 2-chunk0017
# Creating `:Chunk` node for chunk ID 3-chunk0000
# Creating `:Chunk` node for chunk ID 3-chunk0001
# Creating `:Chunk` node for chunk ID 3-chunk0002
# Creating `:Chunk` node for chunk ID 3-chunk0003
# Creating `:Chunk` node for chunk ID 3-chunk0004
# Creating `:Chunk` node for chunk ID 3-chunk0005
# Creating `:Chunk` node for chunk ID 3-chunk0006
# Creating `:Chunk` node for chunk ID 3-chunk0007
# Creating `:Chunk` node for chunk ID 3-chunk0008
# Creating `:Chunk` node for chunk ID 3-chunk0009
# Creating `:Chunk` node for chunk ID 3-chunk0010
# Creating `:Chunk` node for chunk ID 4-chunk0000
# Creating `:Chunk` node for chunk ID 4-chunk0001
# Creating `:Chunk` node for chunk ID 4-chunk0002
# Creating `:Chunk` node for chunk ID 4-chunk0003
# Creating `:Chunk` node for chunk ID 4-chunk0004
# Creating `:Chunk` node for chunk ID 4-chunk0005
# Creating `:Chunk` node for chunk ID 4-chunk0006
# Creating `:Chunk` node for chunk ID 4-chunk0007
# Creating `:Chunk` node for chunk ID 4-chunk0008
# Creating `:Chunk` node for chunk ID 4-chunk0009
# Creating `:Chunk` node for chunk ID 4-chunk0010
# Creating `:Chunk` node for chunk ID 4-chunk0011
# Creating `:Chunk` node for chunk ID 4-chunk0012
# Creating `:Chunk` node for chunk ID 4-chunk0013
# Creating `:Chunk` node for chunk ID 4-chunk0014
# Creating `:Chunk` node for chunk ID 4-chunk0015
# Creating `:Chunk` node for chunk ID 4-chunk0016
# Creating `:Chunk` node for chunk ID 4-chunk0017
# Creating `:Chunk` node for chunk ID 4-chunk0018
# Creating `:Chunk` node for chunk ID 4-chunk0019
# Creating `:Chunk` node for chunk ID 4-chunk0020
# Creating `:Chunk` node for chunk ID 4-chunk0021
# Creating `:Chunk` node for chunk ID 5-chunk0000
# Creating `:Chunk` node for chunk ID 5-chunk0001
# Creating `:Chunk` node for chunk ID 5-chunk0002
# Creating `:Chunk` node for chunk ID 5-chunk0003
# Creating `:Chunk` node for chunk ID 5-chunk0004
# Creating `:Chunk` node for chunk ID 5-chunk0005
# Creating `:Chunk` node for chunk ID 5-chunk0006
# Creating `:Chunk` node for chunk ID 5-chunk0007
# Creating `:Chunk` node for chunk ID 5-chunk0008
# Creating `:Chunk` node for chunk ID 5-chunk0009
# Creating `:Chunk` node for chunk ID 5-chunk0010
# Creating `:Chunk` node for chunk ID 5-chunk0011
# Creating `:Chunk` node for chunk ID 5-chunk0012
# Creating `:Chunk` node for chunk ID 5-chunk0013
# Creating `:Chunk` node for chunk ID 5-chunk0014
# Creating `:Chunk` node for chunk ID 5-chunk0015
# Creating `:Chunk` node for chunk ID 5-chunk0016
# Creating `:Chunk` node for chunk ID 5-chunk0017
# Creating `:Chunk` node for chunk ID 5-chunk0018
# Creating `:Chunk` node for chunk ID 5-chunk0019
# Creating `:Chunk` node for chunk ID 5-chunk0020
# Creating `:Chunk` node for chunk ID 5-chunk0021
# Creating `:Chunk` node for chunk ID 5-chunk0022
# Creating `:Chunk` node for chunk ID 5-chunk0023
# Creating `:Chunk` node for chunk ID 5-chunk0024
# Creating `:Chunk` node for chunk ID 5-chunk0025
# Creating `:Chunk` node for chunk ID 5-chunk0026
# Creating `:Chunk` node for chunk ID 5-chunk0027
# Creating `:Chunk` node for chunk ID 5-chunk0028
# Creating `:Chunk` node for chunk ID 5-chunk0029
# Creating `:Chunk` node for chunk ID 5-chunk0030
# Creating `:Chunk` node for chunk ID 5-chunk0031
# Creating `:Chunk` node for chunk ID 5-chunk0032
# Creating `:Chunk` node for chunk ID 6-chunk0000
# Creating `:Chunk` node for chunk ID 6-chunk0001
# Creating `:Chunk` node for chunk ID 6-chunk0002
# Creating `:Chunk` node for chunk ID 6-chunk0003
# Creating `:Chunk` node for chunk ID 6-chunk0004
# Creating `:Chunk` node for chunk ID 6-chunk0005
# Creating `:Chunk` node for chunk ID 6-chunk0006
# Creating `:Chunk` node for chunk ID 6-chunk0007
# Creating `:Chunk` node for chunk ID 6-chunk0008
# Creating `:Chunk` node for chunk ID 6-chunk0009
# Creating `:Chunk` node for chunk ID 6-chunk0010
# Creating `:Chunk` node for chunk ID 6-chunk0011
# Creating `:Chunk` node for chunk ID 6-chunk0012
# Creating `:Chunk` node for chunk ID 6-chunk0013
# Creating `:Chunk` node for chunk ID 6-chunk0014
# Creating `:Chunk` node for chunk ID 6-chunk0015
# Creating `:Chunk` node for chunk ID 6-chunk0016
# Creating `:Chunk` node for chunk ID 6-chunk0017
# Creating `:Chunk` node for chunk ID 6-chunk0018
# Creating `:Chunk` node for chunk ID 6-chunk0019
# Creating `:Chunk` node for chunk ID 6-chunk0020
# Creating `:Chunk` node for chunk ID 6-chunk0021
# Creating `:Chunk` node for chunk ID 6-chunk0022
# Creating `:Chunk` node for chunk ID 6-chunk0023
# Creating `:Chunk` node for chunk ID 6-chunk0024
# Creating `:Chunk` node for chunk ID 7-chunk0000
# Creating `:Chunk` node for chunk ID 7-chunk0001
# Creating `:Chunk` node for chunk ID 7-chunk0002
# Creating `:Chunk` node for chunk ID 7-chunk0003
# Creating `:Chunk` node for chunk ID 7-chunk0004
# Creating `:Chunk` node for chunk ID 7-chunk0005
# Creating `:Chunk` node for chunk ID 7-chunk0006
# Creating `:Chunk` node for chunk ID 7-chunk0007
# Creating `:Chunk` node for chunk ID 7-chunk0008
# Creating `:Chunk` node for chunk ID 7-chunk0009
# Creating `:Chunk` node for chunk ID 7-chunk0010
# Creating `:Chunk` node for chunk ID 7-chunk0011
# Creating `:Chunk` node for chunk ID 7-chunk0012
# Creating `:Chunk` node for chunk ID 7-chunk0013
# Creating `:Chunk` node for chunk ID 7-chunk0014
# Creating `:Chunk` node for chunk ID 7-chunk0015
# Creating `:Chunk` node for chunk ID 8-chunk0000
# Creating `:Chunk` node for chunk ID 8-chunk0001
# Creating `:Chunk` node for chunk ID 8-chunk0002
# Creating `:Chunk` node for chunk ID 8-chunk0003
# Creating `:Chunk` node for chunk ID 8-chunk0004
# Creating `:Chunk` node for chunk ID 8-chunk0005
# Creating `:Chunk` node for chunk ID 8-chunk0006
# Creating `:Chunk` node for chunk ID 8-chunk0007
# Creating `:Chunk` node for chunk ID 8-chunk0008
# Creating `:Chunk` node for chunk ID 8-chunk0009
# Creating `:Chunk` node for chunk ID 8-chunk0010
# Creating `:Chunk` node for chunk ID 8-chunk0011
# Creating `:Chunk` node for chunk ID 8-chunk0012
# Creating `:Chunk` node for chunk ID 8-chunk0013
# Creating `:Chunk` node for chunk ID 9-chunk0000
# Creating `:Chunk` node for chunk ID 9-chunk0001
# Creating `:Chunk` node for chunk ID 9-chunk0002
# Creating `:Chunk` node for chunk ID 9-chunk0003
# Creating `:Chunk` node for chunk ID 9-chunk0004
# Creating `:Chunk` node for chunk ID 9-chunk0005
# Creating `:Chunk` node for chunk ID 9-chunk0006
# Creating `:Chunk` node for chunk ID 9-chunk0007
# Creating `:Chunk` node for chunk ID 9-chunk0008
# Creating `:Chunk` node for chunk ID 9-chunk0009
# Creating `:Chunk` node for chunk ID 9-chunk0010
# Creating `:Chunk` node for chunk ID 9-chunk0011
# Creating `:Chunk` node for chunk ID 9-chunk0012
# Creating `:Chunk` node for chunk ID 9-chunk0013
# Creating `:Chunk` node for chunk ID 9-chunk0014
# Creating `:Chunk` node for chunk ID 9-chunk0015
# Creating `:Chunk` node for chunk ID 9-chunk0016
# Creating `:Chunk` node for chunk ID 9-chunk0017
# Creating `:Chunk` node for chunk ID 9-chunk0018
# Creating `:Chunk` node for chunk ID 9-chunk0019
# Creating `:Chunk` node for chunk ID 10-chunk0000
# Creating `:Chunk` node for chunk ID 10-chunk0001
# Creating `:Chunk` node for chunk ID 10-chunk0002
# Creating `:Chunk` node for chunk ID 10-chunk0003
# Creating `:Chunk` node for chunk ID 10-chunk0004
# Creating `:Chunk` node for chunk ID 10-chunk0005
# Creating `:Chunk` node for chunk ID 10-chunk0006
# Creating `:Chunk` node for chunk ID 10-chunk0007
# Creating `:Chunk` node for chunk ID 10-chunk0008
# Creating `:Chunk` node for chunk ID 10-chunk0009
# Creating `:Chunk` node for chunk ID 10-chunk0010
# Creating `:Chunk` node for chunk ID 10-chunk0011
# Creating `:Chunk` node for chunk ID 10-chunk0012
# Creating `:Chunk` node for chunk ID 10-chunk0013
# Creating `:Chunk` node for chunk ID 11-chunk0000
# Creating `:Chunk` node for chunk ID 11-chunk0001
# Creating `:Chunk` node for chunk ID 11-chunk0002
# Creating `:Chunk` node for chunk ID 11-chunk0003
# Creating `:Chunk` node for chunk ID 11-chunk0004
# Creating `:Chunk` node for chunk ID 11-chunk0005
# Creating `:Chunk` node for chunk ID 11-chunk0006
# Creating `:Chunk` node for chunk ID 11-chunk0007
# Creating `:Chunk` node for chunk ID 11-chunk0008
# Creating `:Chunk` node for chunk ID 11-chunk0009
# Creating `:Chunk` node for chunk ID 11-chunk0010
# Creating `:Chunk` node for chunk ID 11-chunk0011
# Creating `:Chunk` node for chunk ID 11-chunk0012
# Creating `:Chunk` node for chunk ID 11-chunk0013
# Creating `:Chunk` node for chunk ID 11-chunk0014
# Creating `:Chunk` node for chunk ID 11-chunk0015
# Creating `:Chunk` node for chunk ID 11-chunk0016
# Creating `:Chunk` node for chunk ID 11-chunk0017
# Creating `:Chunk` node for chunk ID 11-chunk0018
# Creating `:Chunk` node for chunk ID 11-chunk0019
# Creating `:Chunk` node for chunk ID 11-chunk0020
# Creating `:Chunk` node for chunk ID 11-chunk0021
# Creating `:Chunk` node for chunk ID 11-chunk0022
# Creating `:Chunk` node for chunk ID 11-chunk0023
# Creating `:Chunk` node for chunk ID 11-chunk0024
# Creating `:Chunk` node for chunk ID 11-chunk0025
# Creating `:Chunk` node for chunk ID 11-chunk0026
# Creating `:Chunk` node for chunk ID 12-chunk0000
# Creating `:Chunk` node for chunk ID 12-chunk0001
# Creating `:Chunk` node for chunk ID 12-chunk0002
# Creating `:Chunk` node for chunk ID 12-chunk0003
# Creating `:Chunk` node for chunk ID 12-chunk0004
# Creating `:Chunk` node for chunk ID 12-chunk0005
# Creating `:Chunk` node for chunk ID 12-chunk0006
# Creating `:Chunk` node for chunk ID 12-chunk0007
# Creating `:Chunk` node for chunk ID 12-chunk0008
# Creating `:Chunk` node for chunk ID 12-chunk0009
# Creating `:Chunk` node for chunk ID 12-chunk0010
# Creating `:Chunk` node for chunk ID 12-chunk0011
# Creating `:Chunk` node for chunk ID 12-chunk0012
# Creating `:Chunk` node for chunk ID 12-chunk0013
# Creating `:Chunk` node for chunk ID 12-chunk0014
# Creating `:Chunk` node for chunk ID 12-chunk0015
# Creating `:Chunk` node for chunk ID 12-chunk0016
# Creating `:Chunk` node for chunk ID 12-chunk0017
# Creating `:Chunk` node for chunk ID 12-chunk0018
# Creating `:Chunk` node for chunk ID 12-chunk0019
# Creating `:Chunk` node for chunk ID 12-chunk0020
# Creating `:Chunk` node for chunk ID 12-chunk0021
# Creating `:Chunk` node for chunk ID 12-chunk0022
# Creating `:Chunk` node for chunk ID 12-chunk0023
# Creating `:Chunk` node for chunk ID 12-chunk0024
# Creating `:Chunk` node for chunk ID 12-chunk0025
# Creating `:Chunk` node for chunk ID 12-chunk0026
# Creating `:Chunk` node for chunk ID 12-chunk0027
# Creating `:Chunk` node for chunk ID 13-chunk0000
# Creating `:Chunk` node for chunk ID 13-chunk0001
# Creating `:Chunk` node for chunk ID 13-chunk0002
# Creating `:Chunk` node for chunk ID 13-chunk0003
# Creating `:Chunk` node for chunk ID 13-chunk0004
# Creating `:Chunk` node for chunk ID 13-chunk0005
# Creating `:Chunk` node for chunk ID 13-chunk0006
# Creating `:Chunk` node for chunk ID 13-chunk0007
# Creating `:Chunk` node for chunk ID 13-chunk0008
# Creating `:Chunk` node for chunk ID 13-chunk0009
# Creating `:Chunk` node for chunk ID 13-chunk0010
# Creating `:Chunk` node for chunk ID 13-chunk0011
# Creating `:Chunk` node for chunk ID 13-chunk0012
# Creating `:Chunk` node for chunk ID 13-chunk0013
# Creating `:Chunk` node for chunk ID 14-chunk0000
# Creating `:Chunk` node for chunk ID 14-chunk0001
# Creating `:Chunk` node for chunk ID 14-chunk0002
# Creating `:Chunk` node for chunk ID 14-chunk0003
# Creating `:Chunk` node for chunk ID 14-chunk0004
# Creating `:Chunk` node for chunk ID 15-chunk0000
# Creating `:Chunk` node for chunk ID 15-chunk0001
# Creating `:Chunk` node for chunk ID 15-chunk0002
# Creating `:Chunk` node for chunk ID 15-chunk0003
# Creating `:Chunk` node for chunk ID 15-chunk0004
# Creating `:Chunk` node for chunk ID 15-chunk0005
# Creating `:Chunk` node for chunk ID 15-chunk0006
# Creating `:Chunk` node for chunk ID 15-chunk0007
# Creating `:Chunk` node for chunk ID 15-chunk0008
# Creating `:Chunk` node for chunk ID 15-chunk0009
# Creating `:Chunk` node for chunk ID 15-chunk0010
# Creating `:Chunk` node for chunk ID 15-chunk0011
# Creating `:Chunk` node for chunk ID 15-chunk0012
# Creating `:Chunk` node for chunk ID 15-chunk0013
# Creating `:Chunk` node for chunk ID 16-chunk0000
# Creating `:Chunk` node for chunk ID 16-chunk0001
# Creating `:Chunk` node for chunk ID 16-chunk0002
# Creating `:Chunk` node for chunk ID 16-chunk0003
# Creating `:Chunk` node for chunk ID 16-chunk0004
# Creating `:Chunk` node for chunk ID 16-chunk0005
# Creating `:Chunk` node for chunk ID 16-chunk0006
# Creating `:Chunk` node for chunk ID 16-chunk0007
# Creating `:Chunk` node for chunk ID 16-chunk0008
# Creating `:Chunk` node for chunk ID 16-chunk0009
# Creating `:Chunk` node for chunk ID 16-chunk0010
# Creating `:Chunk` node for chunk ID 16-chunk0011
# Creating `:Chunk` node for chunk ID 16-chunk0012
# Creating `:Chunk` node for chunk ID 16-chunk0013
# Creating `:Chunk` node for chunk ID 16-chunk0014
# Creating `:Chunk` node for chunk ID 16-chunk0015
# Creating `:Chunk` node for chunk ID 16-chunk0016
# Creating `:Chunk` node for chunk ID 16-chunk0017
# Creating `:Chunk` node for chunk ID 16-chunk0018
# Creating `:Chunk` node for chunk ID 16-chunk0019
# Creating `:Chunk` node for chunk ID 16-chunk0020
# Creating `:Chunk` node for chunk ID 16-chunk0021
# Creating `:Chunk` node for chunk ID 16-chunk0022
# Creating `:Chunk` node for chunk ID 16-chunk0023
# Creating `:Chunk` node for chunk ID 16-chunk0024
# Creating `:Chunk` node for chunk ID 16-chunk0025
# Creating `:Chunk` node for chunk ID 16-chunk0026
# Creating `:Chunk` node for chunk ID 16-chunk0027
# Creating `:Chunk` node for chunk ID 16-chunk0028
# Creating `:Chunk` node for chunk ID 16-chunk0029
# Creating `:Chunk` node for chunk ID 16-chunk0030
# Creating `:Chunk` node for chunk ID 16-chunk0031
# Creating `:Chunk` node for chunk ID 16-chunk0032
# Creating `:Chunk` node for chunk ID 16-chunk0033
# Creating `:Chunk` node for chunk ID 16-chunk0034
# Creating `:Chunk` node for chunk ID 16-chunk0035
# Creating `:Chunk` node for chunk ID 16-chunk0036
# Creating `:Chunk` node for chunk ID 16-chunk0037
# Creating `:Chunk` node for chunk ID 16-chunk0038
# Creating `:Chunk` node for chunk ID 16-chunk0039
# Creating `:Chunk` node for chunk ID 16-chunk0040
# Creating `:Chunk` node for chunk ID 17-chunk0000
# Creating `:Chunk` node for chunk ID 17-chunk0001
# Creating `:Chunk` node for chunk ID 17-chunk0002
# Creating `:Chunk` node for chunk ID 17-chunk0003
# Creating `:Chunk` node for chunk ID 17-chunk0004
# Creating `:Chunk` node for chunk ID 17-chunk0005
# Creating `:Chunk` node for chunk ID 17-chunk0006
# Creating `:Chunk` node for chunk ID 17-chunk0007
# Creating `:Chunk` node for chunk ID 17-chunk0008
# Creating `:Chunk` node for chunk ID 17-chunk0009
# Creating `:Chunk` node for chunk ID 17-chunk0010
# Creating `:Chunk` node for chunk ID 17-chunk0011
# Creating `:Chunk` node for chunk ID 17-chunk0012
# Creating `:Chunk` node for chunk ID 17-chunk0013
# Creating `:Chunk` node for chunk ID 17-chunk0014
# Creating `:Chunk` node for chunk ID 17-chunk0015
# Creating `:Chunk` node for chunk ID 17-chunk0016
# Creating `:Chunk` node for chunk ID 17-chunk0017
# Creating `:Chunk` node for chunk ID 17-chunk0018
# Creating `:Chunk` node for chunk ID 17-chunk0019
# Creating `:Chunk` node for chunk ID 17-chunk0020
# Creating `:Chunk` node for chunk ID 17-chunk0021
# Creating `:Chunk` node for chunk ID 17-chunk0022
# Creating `:Chunk` node for chunk ID 17-chunk0023
# Creating `:Chunk` node for chunk ID 17-chunk0024
# Creating `:Chunk` node for chunk ID 18-chunk0000
# Creating `:Chunk` node for chunk ID 18-chunk0001
# Creating `:Chunk` node for chunk ID 18-chunk0002
# Creating `:Chunk` node for chunk ID 18-chunk0003
# Creating `:Chunk` node for chunk ID 18-chunk0004
# Creating `:Chunk` node for chunk ID 18-chunk0005
# Creating `:Chunk` node for chunk ID 18-chunk0006
# Creating `:Chunk` node for chunk ID 18-chunk0007
# Creating `:Chunk` node for chunk ID 18-chunk0008
# Creating `:Chunk` node for chunk ID 18-chunk0009
# Creating `:Chunk` node for chunk ID 18-chunk0010
# Creating `:Chunk` node for chunk ID 18-chunk0011
# Creating `:Chunk` node for chunk ID 18-chunk0012
# Creating `:Chunk` node for chunk ID 18-chunk0013
# Creating `:Chunk` node for chunk ID 18-chunk0014
# Creating `:Chunk` node for chunk ID 18-chunk0015
# Creating `:Chunk` node for chunk ID 19-chunk0000
# Creating `:Chunk` node for chunk ID 19-chunk0001
# Creating `:Chunk` node for chunk ID 19-chunk0002
# Creating `:Chunk` node for chunk ID 19-chunk0003
# Creating `:Chunk` node for chunk ID 19-chunk0004
# Creating `:Chunk` node for chunk ID 19-chunk0005
# Creating `:Chunk` node for chunk ID 19-chunk0006
# Creating `:Chunk` node for chunk ID 19-chunk0007
# Creating `:Chunk` node for chunk ID 19-chunk0008
# Creating `:Chunk` node for chunk ID 19-chunk0009
# Creating `:Chunk` node for chunk ID 19-chunk0010
# Creating `:Chunk` node for chunk ID 19-chunk0011
# Creating `:Chunk` node for chunk ID 19-chunk0012
# Creating `:Chunk` node for chunk ID 19-chunk0013
# Creating `:Chunk` node for chunk ID 19-chunk0014
# Creating `:Chunk` node for chunk ID 20-chunk0000
# Creating `:Chunk` node for chunk ID 20-chunk0001
# Creating `:Chunk` node for chunk ID 20-chunk0002
# Creating `:Chunk` node for chunk ID 20-chunk0003
# Creating `:Chunk` node for chunk ID 20-chunk0004
# Creating `:Chunk` node for chunk ID 20-chunk0005
# Creating `:Chunk` node for chunk ID 20-chunk0006
# Creating `:Chunk` node for chunk ID 20-chunk0007
# Creating `:Chunk` node for chunk ID 20-chunk0008
# Creating `:Chunk` node for chunk ID 20-chunk0009
# Creating `:Chunk` node for chunk ID 20-chunk0010
# Creating `:Chunk` node for chunk ID 20-chunk0011
# Creating `:Chunk` node for chunk ID 20-chunk0012
# Creating `:Chunk` node for chunk ID 20-chunk0013
# Creating `:Chunk` node for chunk ID 20-chunk0014
# Creating `:Chunk` node for chunk ID 20-chunk0015
# Creating `:Chunk` node for chunk ID 20-chunk0016
# Creating `:Chunk` node for chunk ID 20-chunk0017
# Creating `:Chunk` node for chunk ID 20-chunk0018
# Creating `:Chunk` node for chunk ID 20-chunk0019
# Creating `:Chunk` node for chunk ID 20-chunk0020
# Creating `:Chunk` node for chunk ID 20-chunk0021
# Creating `:Chunk` node for chunk ID 20-chunk0022
# Creating `:Chunk` node for chunk ID 20-chunk0023
# Creating `:Chunk` node for chunk ID 21-chunk0000
# Creating `:Chunk` node for chunk ID 21-chunk0001
# Creating `:Chunk` node for chunk ID 21-chunk0002
# Creating `:Chunk` node for chunk ID 21-chunk0003
# Creating `:Chunk` node for chunk ID 21-chunk0004
# Creating `:Chunk` node for chunk ID 21-chunk0005
# Creating `:Chunk` node for chunk ID 21-chunk0006
# Creating `:Chunk` node for chunk ID 21-chunk0007
# Creating `:Chunk` node for chunk ID 21-chunk0008
# Creating `:Chunk` node for chunk ID 22-chunk0000
# Creating `:Chunk` node for chunk ID 22-chunk0001
# Creating `:Chunk` node for chunk ID 22-chunk0002
# Creating `:Chunk` node for chunk ID 22-chunk0003
# Creating `:Chunk` node for chunk ID 22-chunk0004
# Creating `:Chunk` node for chunk ID 22-chunk0005
# Creating `:Chunk` node for chunk ID 22-chunk0006
# Creating `:Chunk` node for chunk ID 22-chunk0007
# Creating `:Chunk` node for chunk ID 22-chunk0008
# Creating `:Chunk` node for chunk ID 22-chunk0009
# Creating `:Chunk` node for chunk ID 22-chunk0010
# Creating `:Chunk` node for chunk ID 22-chunk0011
# Creating `:Chunk` node for chunk ID 22-chunk0012
# Creating `:Chunk` node for chunk ID 22-chunk0013
# Creating `:Chunk` node for chunk ID 22-chunk0014
# Creating `:Chunk` node for chunk ID 22-chunk0015
# Creating `:Chunk` node for chunk ID 22-chunk0016
# Creating `:Chunk` node for chunk ID 22-chunk0017
# Creating `:Chunk` node for chunk ID 22-chunk0018
# Creating `:Chunk` node for chunk ID 22-chunk0019
# Creating `:Chunk` node for chunk ID 22-chunk0020
# Creating `:Chunk` node for chunk ID 22-chunk0021
# Creating `:Chunk` node for chunk ID 22-chunk0022
# Creating `:Chunk` node for chunk ID 22-chunk0023
# Creating `:Chunk` node for chunk ID 22-chunk0024
# Creating `:Chunk` node for chunk ID 22-chunk0025
# Creating `:Chunk` node for chunk ID 22-chunk0026
# Creating `:Chunk` node for chunk ID 22-chunk0027
# Creating `:Chunk` node for chunk ID 22-chunk0028
# Creating `:Chunk` node for chunk ID 22-chunk0029
# Creating `:Chunk` node for chunk ID 22-chunk0030
# Creating `:Chunk` node for chunk ID 22-chunk0031
# Creating `:Chunk` node for chunk ID 22-chunk0032
# Creating `:Chunk` node for chunk ID 22-chunk0033
# Creating `:Chunk` node for chunk ID 22-chunk0034
# Creating `:Chunk` node for chunk ID 23-chunk0000
# Creating `:Chunk` node for chunk ID 23-chunk0001
# Creating `:Chunk` node for chunk ID 23-chunk0002
# Creating `:Chunk` node for chunk ID 23-chunk0003
# Creating `:Chunk` node for chunk ID 23-chunk0004
# Creating `:Chunk` node for chunk ID 23-chunk0005
# Creating `:Chunk` node for chunk ID 23-chunk0006
# Creating `:Chunk` node for chunk ID 23-chunk0007
# Creating `:Chunk` node for chunk ID 23-chunk0008
# Creating `:Chunk` node for chunk ID 23-chunk0009
# Creating `:Chunk` node for chunk ID 23-chunk0010
# Creating `:Chunk` node for chunk ID 23-chunk0011
# Creating `:Chunk` node for chunk ID 23-chunk0012
# Creating `:Chunk` node for chunk ID 23-chunk0013
# Creating `:Chunk` node for chunk ID 23-chunk0014
# Creating `:Chunk` node for chunk ID 23-chunk0015
# Creating `:Chunk` node for chunk ID 23-chunk0016
# Creating `:Chunk` node for chunk ID 23-chunk0017
# Creating `:Chunk` node for chunk ID 23-chunk0018
# Creating `:Chunk` node for chunk ID 23-chunk0019
# Creating `:Chunk` node for chunk ID 23-chunk0020
# Creating `:Chunk` node for chunk ID 23-chunk0021
# Creating `:Chunk` node for chunk ID 23-chunk0022
# Creating `:Chunk` node for chunk ID 23-chunk0023
# Creating `:Chunk` node for chunk ID 23-chunk0024
# Creating `:Chunk` node for chunk ID 24-chunk0000
# Creating `:Chunk` node for chunk ID 24-chunk0001
# Creating `:Chunk` node for chunk ID 24-chunk0002
# Creating `:Chunk` node for chunk ID 24-chunk0003
# Creating `:Chunk` node for chunk ID 24-chunk0004
# Creating `:Chunk` node for chunk ID 25-chunk0000
# Creating `:Chunk` node for chunk ID 25-chunk0001
# Creating `:Chunk` node for chunk ID 25-chunk0002
# Creating `:Chunk` node for chunk ID 25-chunk0003
# Creating `:Chunk` node for chunk ID 25-chunk0004
# Creating `:Chunk` node for chunk ID 25-chunk0005
# Creating `:Chunk` node for chunk ID 25-chunk0006
# Creating `:Chunk` node for chunk ID 25-chunk0007
# Creating `:Chunk` node for chunk ID 25-chunk0008
# Creating `:Chunk` node for chunk ID 25-chunk0009
# Creating `:Chunk` node for chunk ID 25-chunk0010
# Creating `:Chunk` node for chunk ID 25-chunk0011
# Creating `:Chunk` node for chunk ID 25-chunk0012
# Creating `:Chunk` node for chunk ID 25-chunk0013
# Creating `:Chunk` node for chunk ID 25-chunk0014
# Creating `:Chunk` node for chunk ID 25-chunk0015
# Creating `:Chunk` node for chunk ID 25-chunk0016
# Creating `:Chunk` node for chunk ID 26-chunk0000
# Creating `:Chunk` node for chunk ID 26-chunk0001
# Creating `:Chunk` node for chunk ID 26-chunk0002
# Creating `:Chunk` node for chunk ID 26-chunk0003
# Creating `:Chunk` node for chunk ID 26-chunk0004
# Creating `:Chunk` node for chunk ID 26-chunk0005
# Creating `:Chunk` node for chunk ID 26-chunk0006
# Creating `:Chunk` node for chunk ID 26-chunk0007
# Creating `:Chunk` node for chunk ID 26-chunk0008
# Creating `:Chunk` node for chunk ID 26-chunk0009
# Creating `:Chunk` node for chunk ID 26-chunk0010
# Creating `:Chunk` node for chunk ID 26-chunk0011
# Creating `:Chunk` node for chunk ID 26-chunk0012
# Creating `:Chunk` node for chunk ID 26-chunk0013
# Creating `:Chunk` node for chunk ID 26-chunk0014
# Creating `:Chunk` node for chunk ID 26-chunk0015
# Creating `:Chunk` node for chunk ID 26-chunk0016
# Creating `:Chunk` node for chunk ID 26-chunk0017
# Creating `:Chunk` node for chunk ID 26-chunk0018
# Creating `:Chunk` node for chunk ID 26-chunk0019
# Creating `:Chunk` node for chunk ID 26-chunk0020
# Creating `:Chunk` node for chunk ID 26-chunk0021
# Creating `:Chunk` node for chunk ID 26-chunk0022
# Creating `:Chunk` node for chunk ID 27-chunk0000
# Creating `:Chunk` node for chunk ID 27-chunk0001
# Creating `:Chunk` node for chunk ID 27-chunk0002
# Creating `:Chunk` node for chunk ID 27-chunk0003
# Creating `:Chunk` node for chunk ID 27-chunk0004
# Creating `:Chunk` node for chunk ID 27-chunk0005
# Creating `:Chunk` node for chunk ID 27-chunk0006
# Creating `:Chunk` node for chunk ID 27-chunk0007
# Creating `:Chunk` node for chunk ID 27-chunk0008
# Creating `:Chunk` node for chunk ID 30-chunk0000
# Creating `:Chunk` node for chunk ID 30-chunk0001
# Creating `:Chunk` node for chunk ID 30-chunk0002
# Creating `:Chunk` node for chunk ID 30-chunk0003
# Creating `:Chunk` node for chunk ID 30-chunk0004
# Creating `:Chunk` node for chunk ID 30-chunk0005
# Creating `:Chunk` node for chunk ID 30-chunk0006
# Creating `:Chunk` node for chunk ID 30-chunk0007
# Creating `:Chunk` node for chunk ID 30-chunk0008
# Creating `:Chunk` node for chunk ID 30-chunk0009
# Creating `:Chunk` node for chunk ID 30-chunk0010
# Creating `:Chunk` node for chunk ID 31-chunk0000
# Creating `:Chunk` node for chunk ID 31-chunk0001
# Creating `:Chunk` node for chunk ID 31-chunk0002
# Creating `:Chunk` node for chunk ID 31-chunk0003
# Creating `:Chunk` node for chunk ID 31-chunk0004
# Creating `:Chunk` node for chunk ID 31-chunk0005
# Creating `:Chunk` node for chunk ID 31-chunk0006
# Creating `:Chunk` node for chunk ID 31-chunk0007
# Creating `:Chunk` node for chunk ID 31-chunk0008
# Creating `:Chunk` node for chunk ID 31-chunk0009
# Creating `:Chunk` node for chunk ID 31-chunk0010
# Creating `:Chunk` node for chunk ID 31-chunk0011
# Creating `:Chunk` node for chunk ID 31-chunk0012
# Creating `:Chunk` node for chunk ID 31-chunk0013
# Creating `:Chunk` node for chunk ID 31-chunk0014
# Creating `:Chunk` node for chunk ID 31-chunk0015
# Creating `:Chunk` node for chunk ID 36-chunk0000
# Creating `:Chunk` node for chunk ID 36-chunk0001
# Creating `:Chunk` node for chunk ID 36-chunk0002
# Creating `:Chunk` node for chunk ID 36-chunk0003
# Creating `:Chunk` node for chunk ID 36-chunk0004
# Creating `:Chunk` node for chunk ID 36-chunk0005
# Creating `:Chunk` node for chunk ID 36-chunk0006
# Creating `:Chunk` node for chunk ID 36-chunk0007
# Creating `:Chunk` node for chunk ID 36-chunk0008
# Creating `:Chunk` node for chunk ID 37-chunk0000
# Creating `:Chunk` node for chunk ID 37-chunk0001
# Creating `:Chunk` node for chunk ID 37-chunk0002
# Creating `:Chunk` node for chunk ID 37-chunk0003
# Creating `:Chunk` node for chunk ID 37-chunk0004
# Creating `:Chunk` node for chunk ID 37-chunk0005
# Creating `:Chunk` node for chunk ID 37-chunk0006
# Creating `:Chunk` node for chunk ID 37-chunk0007
# Creating `:Chunk` node for chunk ID 37-chunk0008
# Creating `:Chunk` node for chunk ID 37-chunk0009
# Creating `:Chunk` node for chunk ID 37-chunk0010
# Creating `:Chunk` node for chunk ID 37-chunk0011
# Creating `:Chunk` node for chunk ID 37-chunk0012
# Creating `:Chunk` node for chunk ID 37-chunk0013
# Creating `:Chunk` node for chunk ID 37-chunk0014
# Creating `:Chunk` node for chunk ID 37-chunk0015
# Creating `:Chunk` node for chunk ID 37-chunk0016
# Creating `:Chunk` node for chunk ID 37-chunk0017
# Creating `:Chunk` node for chunk ID 37-chunk0018
# Creating `:Chunk` node for chunk ID 37-chunk0019
# Creating `:Chunk` node for chunk ID 37-chunk0020
# Creating `:Chunk` node for chunk ID 37-chunk0021
# Creating `:Chunk` node for chunk ID 37-chunk0022
# Creating `:Chunk` node for chunk ID 37-chunk0023
# Creating `:Chunk` node for chunk ID 37-chunk0024
# Creating `:Chunk` node for chunk ID 37-chunk0025
# Creating `:Chunk` node for chunk ID 37-chunk0026
# Creating `:Chunk` node for chunk ID 37-chunk0027
# Creating `:Chunk` node for chunk ID 37-chunk0028
# Creating `:Chunk` node for chunk ID 37-chunk0029
# Creating `:Chunk` node for chunk ID 38-chunk0000
# Creating `:Chunk` node for chunk ID 38-chunk0001
# Creating `:Chunk` node for chunk ID 38-chunk0002
# Creating `:Chunk` node for chunk ID 38-chunk0003
# Creating `:Chunk` node for chunk ID 38-chunk0004
# Creating `:Chunk` node for chunk ID 38-chunk0005
# Creating `:Chunk` node for chunk ID 38-chunk0006
# Creating `:Chunk` node for chunk ID 38-chunk0007
# Creating `:Chunk` node for chunk ID 38-chunk0008
# Creating `:Chunk` node for chunk ID 38-chunk0009
# Creating `:Chunk` node for chunk ID 38-chunk0010
# Creating `:Chunk` node for chunk ID 38-chunk0011
# Creating `:Chunk` node for chunk ID 38-chunk0012
# Creating `:Chunk` node for chunk ID 38-chunk0013
# Creating `:Chunk` node for chunk ID 38-chunk0014
# Creating `:Chunk` node for chunk ID 38-chunk0015
# Creating `:Chunk` node for chunk ID 38-chunk0016
# Creating `:Chunk` node for chunk ID 38-chunk0017
# Creating `:Chunk` node for chunk ID 38-chunk0018
# Creating `:Chunk` node for chunk ID 38-chunk0019
# Creating `:Chunk` node for chunk ID 38-chunk0020
# Creating `:Chunk` node for chunk ID 38-chunk0021
# Creating `:Chunk` node for chunk ID 39-chunk0000
# Creating `:Chunk` node for chunk ID 39-chunk0001
# Creating `:Chunk` node for chunk ID 39-chunk0002
# Creating `:Chunk` node for chunk ID 39-chunk0003
# Creating `:Chunk` node for chunk ID 39-chunk0004
# Creating `:Chunk` node for chunk ID 39-chunk0005
# Creating `:Chunk` node for chunk ID 39-chunk0006
# Creating `:Chunk` node for chunk ID 39-chunk0007
# Creating `:Chunk` node for chunk ID 39-chunk0008
# Creating `:Chunk` node for chunk ID 39-chunk0009
# Creating `:Chunk` node for chunk ID 39-chunk0010
# Creating `:Chunk` node for chunk ID 39-chunk0011
# Creating `:Chunk` node for chunk ID 39-chunk0012
# Creating `:Chunk` node for chunk ID 39-chunk0013
# Creating `:Chunk` node for chunk ID 39-chunk0014
# Creating `:Chunk` node for chunk ID 39-chunk0015
# Creating `:Chunk` node for chunk ID 39-chunk0016
# Creating `:Chunk` node for chunk ID 40-chunk0000
# Creating `:Chunk` node for chunk ID 40-chunk0001
# Creating `:Chunk` node for chunk ID 40-chunk0002
# Creating `:Chunk` node for chunk ID 40-chunk0003
# Creating `:Chunk` node for chunk ID 40-chunk0004
# Creating `:Chunk` node for chunk ID 40-chunk0005
# Creating `:Chunk` node for chunk ID 40-chunk0006
# Creating `:Chunk` node for chunk ID 40-chunk0007
# Creating `:Chunk` node for chunk ID 40-chunk0008
# Creating `:Chunk` node for chunk ID 40-chunk0009
# Creating `:Chunk` node for chunk ID 40-chunk0010
# Creating `:Chunk` node for chunk ID 40-chunk0011
# Creating `:Chunk` node for chunk ID 40-chunk0012
# Creating `:Chunk` node for chunk ID 41-chunk0000
# Creating `:Chunk` node for chunk ID 41-chunk0001
# Creating `:Chunk` node for chunk ID 41-chunk0002
# Creating `:Chunk` node for chunk ID 41-chunk0003
# Creating `:Chunk` node for chunk ID 41-chunk0004
# Creating `:Chunk` node for chunk ID 41-chunk0005
# Creating `:Chunk` node for chunk ID 41-chunk0006
# Creating `:Chunk` node for chunk ID 41-chunk0007
# Creating `:Chunk` node for chunk ID 41-chunk0008
# Creating `:Chunk` node for chunk ID 41-chunk0009
# Creating `:Chunk` node for chunk ID 41-chunk0010
# Creating `:Chunk` node for chunk ID 41-chunk0011
# Creating `:Chunk` node for chunk ID 41-chunk0012
# Creating `:Chunk` node for chunk ID 41-chunk0013
# Creating `:Chunk` node for chunk ID 41-chunk0014
# Creating `:Chunk` node for chunk ID 42-chunk0000
# Creating `:Chunk` node for chunk ID 42-chunk0001
# Creating `:Chunk` node for chunk ID 42-chunk0002
# Creating `:Chunk` node for chunk ID 42-chunk0003
# Creating `:Chunk` node for chunk ID 42-chunk0004
# Creating `:Chunk` node for chunk ID 42-chunk0005
# Creating `:Chunk` node for chunk ID 42-chunk0006
# Creating `:Chunk` node for chunk ID 42-chunk0007
# Creating `:Chunk` node for chunk ID 42-chunk0008
# Creating `:Chunk` node for chunk ID 42-chunk0009
# Creating `:Chunk` node for chunk ID 42-chunk0010
# Creating `:Chunk` node for chunk ID 42-chunk0011
# Creating `:Chunk` node for chunk ID 42-chunk0012
# Creating `:Chunk` node for chunk ID 42-chunk0013
# Creating `:Chunk` node for chunk ID 42-chunk0014
# Creating `:Chunk` node for chunk ID 42-chunk0015
# Creating `:Chunk` node for chunk ID 42-chunk0016
# Creating `:Chunk` node for chunk ID 43-chunk0000
# Creating `:Chunk` node for chunk ID 43-chunk0001
# Creating `:Chunk` node for chunk ID 43-chunk0002
# Creating `:Chunk` node for chunk ID 43-chunk0003
# Creating `:Chunk` node for chunk ID 43-chunk0004
# Creating `:Chunk` node for chunk ID 43-chunk0005
# Creating `:Chunk` node for chunk ID 43-chunk0006
# Creating `:Chunk` node for chunk ID 43-chunk0007
# Creating `:Chunk` node for chunk ID 43-chunk0008
# Creating `:Chunk` node for chunk ID 43-chunk0009
# Creating `:Chunk` node for chunk ID 43-chunk0010
# Creating `:Chunk` node for chunk ID 43-chunk0011
# Creating `:Chunk` node for chunk ID 43-chunk0012
# Creating `:Chunk` node for chunk ID 43-chunk0013
# Creating `:Chunk` node for chunk ID 43-chunk0014
# Creating `:Chunk` node for chunk ID 43-chunk0015
# Creating `:Chunk` node for chunk ID 43-chunk0016
# Creating `:Chunk` node for chunk ID 43-chunk0017
# Creating `:Chunk` node for chunk ID 43-chunk0018
# Creating `:Chunk` node for chunk ID 43-chunk0019
# Creating `:Chunk` node for chunk ID 43-chunk0020
# Creating `:Chunk` node for chunk ID 43-chunk0021
# Creating `:Chunk` node for chunk ID 43-chunk0022
# Creating `:Chunk` node for chunk ID 43-chunk0023
# Creating `:Chunk` node for chunk ID 44-chunk0000
# Creating `:Chunk` node for chunk ID 44-chunk0001
# Creating `:Chunk` node for chunk ID 44-chunk0002
# Creating `:Chunk` node for chunk ID 44-chunk0003
# Creating `:Chunk` node for chunk ID 44-chunk0004
# Creating `:Chunk` node for chunk ID 44-chunk0005
# Creating `:Chunk` node for chunk ID 44-chunk0006
# Creating `:Chunk` node for chunk ID 44-chunk0007
# Creating `:Chunk` node for chunk ID 44-chunk0008
# Creating `:Chunk` node for chunk ID 44-chunk0009
# Creating `:Chunk` node for chunk ID 44-chunk0010
# Creating `:Chunk` node for chunk ID 44-chunk0011
# Creating `:Chunk` node for chunk ID 44-chunk0012
# Creating `:Chunk` node for chunk ID 44-chunk0013
# Creating `:Chunk` node for chunk ID 44-chunk0014
# Creating `:Chunk` node for chunk ID 45-chunk0000
# Creating `:Chunk` node for chunk ID 45-chunk0001
# Creating `:Chunk` node for chunk ID 45-chunk0002
# Creating `:Chunk` node for chunk ID 45-chunk0003
# Creating `:Chunk` node for chunk ID 45-chunk0004
# Creating `:Chunk` node for chunk ID 46-chunk0000
# Creating `:Chunk` node for chunk ID 46-chunk0001
# Creating `:Chunk` node for chunk ID 46-chunk0002
# Creating `:Chunk` node for chunk ID 46-chunk0003
# Creating `:Chunk` node for chunk ID 46-chunk0004
# Creating `:Chunk` node for chunk ID 46-chunk0005
# Creating `:Chunk` node for chunk ID 46-chunk0006
# Creating `:Chunk` node for chunk ID 46-chunk0007
# Creating `:Chunk` node for chunk ID 46-chunk0008
# Creating `:Chunk` node for chunk ID 46-chunk0009
# Creating `:Chunk` node for chunk ID 46-chunk0010
# Creating `:Chunk` node for chunk ID 46-chunk0011
# Creating `:Chunk` node for chunk ID 46-chunk0012
# Creating `:Chunk` node for chunk ID 46-chunk0013
# Creating `:Chunk` node for chunk ID 46-chunk0014
# Creating `:Chunk` node for chunk ID 46-chunk0015
# Creating `:Chunk` node for chunk ID 46-chunk0016
# Creating `:Chunk` node for chunk ID 46-chunk0017
# Creating `:Chunk` node for chunk ID 47-chunk0000
# Creating `:Chunk` node for chunk ID 47-chunk0001
# Creating `:Chunk` node for chunk ID 47-chunk0002
# Creating `:Chunk` node for chunk ID 47-chunk0003
# Creating `:Chunk` node for chunk ID 47-chunk0004
# Creating `:Chunk` node for chunk ID 47-chunk0005
# Creating `:Chunk` node for chunk ID 47-chunk0006
# Creating `:Chunk` node for chunk ID 47-chunk0007
# Creating `:Chunk` node for chunk ID 47-chunk0008
# Creating `:Chunk` node for chunk ID 47-chunk0009
# Creating `:Chunk` node for chunk ID 47-chunk0010
# Creating `:Chunk` node for chunk ID 47-chunk0011
# Creating `:Chunk` node for chunk ID 47-chunk0012
# Creating `:Chunk` node for chunk ID 47-chunk0013
# Creating `:Chunk` node for chunk ID 47-chunk0014
# Creating `:Chunk` node for chunk ID 47-chunk0015
# Creating `:Chunk` node for chunk ID 47-chunk0016
# Creating `:Chunk` node for chunk ID 47-chunk0017
# Creating `:Chunk` node for chunk ID 47-chunk0018
# Creating `:Chunk` node for chunk ID 47-chunk0019
# Creating `:Chunk` node for chunk ID 47-chunk0020
# Creating `:Chunk` node for chunk ID 48-chunk0000
# Creating `:Chunk` node for chunk ID 48-chunk0001
# Creating `:Chunk` node for chunk ID 48-chunk0002
# Creating `:Chunk` node for chunk ID 48-chunk0003
# Creating `:Chunk` node for chunk ID 48-chunk0004
# Creating `:Chunk` node for chunk ID 48-chunk0005
# Creating `:Chunk` node for chunk ID 48-chunk0006
# Creating `:Chunk` node for chunk ID 48-chunk0007
# Creating `:Chunk` node for chunk ID 48-chunk0008
# Creating `:Chunk` node for chunk ID 48-chunk0009
# Creating `:Chunk` node for chunk ID 48-chunk0010
# Creating `:Chunk` node for chunk ID 48-chunk0011
# Creating `:Chunk` node for chunk ID 48-chunk0012
# Creating `:Chunk` node for chunk ID 48-chunk0013
# Creating `:Chunk` node for chunk ID 48-chunk0014
# Creating `:Chunk` node for chunk ID 48-chunk0015
# Creating `:Chunk` node for chunk ID 48-chunk0016
# Creating `:Chunk` node for chunk ID 49-chunk0000
# Creating `:Chunk` node for chunk ID 49-chunk0001
# Creating `:Chunk` node for chunk ID 49-chunk0002
# Creating `:Chunk` node for chunk ID 49-chunk0003
# Creating `:Chunk` node for chunk ID 49-chunk0004
# Creating `:Chunk` node for chunk ID 49-chunk0005
# Creating `:Chunk` node for chunk ID 49-chunk0006
# Creating `:Chunk` node for chunk ID 49-chunk0007
# Creating `:Chunk` node for chunk ID 49-chunk0008
# Creating `:Chunk` node for chunk ID 49-chunk0009
# Creating `:Chunk` node for chunk ID 49-chunk0010
# Creating `:Chunk` node for chunk ID 49-chunk0011
# Creating `:Chunk` node for chunk ID 49-chunk0012
# Creating `:Chunk` node for chunk ID 49-chunk0013
# Creating `:Chunk` node for chunk ID 49-chunk0014
# Creating `:Chunk` node for chunk ID 49-chunk0015
# Creating `:Chunk` node for chunk ID 49-chunk0016
# Creating `:Chunk` node for chunk ID 49-chunk0017
# Creating `:Chunk` node for chunk ID 49-chunk0018
# Creating `:Chunk` node for chunk ID 49-chunk0019
# Creating `:Chunk` node for chunk ID 49-chunk0020
# Creating `:Chunk` node for chunk ID 49-chunk0021
# Creating `:Chunk` node for chunk ID 49-chunk0022
# Creating `:Chunk` node for chunk ID 49-chunk0023
# Creating `:Chunk` node for chunk ID 49-chunk0024
# Creating `:Chunk` node for chunk ID 49-chunk0025
# Creating `:Chunk` node for chunk ID 49-chunk0026
# Creating `:Chunk` node for chunk ID 49-chunk0027
# Creating `:Chunk` node for chunk ID 49-chunk0028
# Creating `:Chunk` node for chunk ID 49-chunk0029
# Creating `:Chunk` node for chunk ID 50-chunk0000
# Creating `:Chunk` node for chunk ID 50-chunk0001
# Creating `:Chunk` node for chunk ID 50-chunk0002
# Creating `:Chunk` node for chunk ID 50-chunk0003
# Creating `:Chunk` node for chunk ID 50-chunk0004
# Creating `:Chunk` node for chunk ID 50-chunk0005
# Creating `:Chunk` node for chunk ID 50-chunk0006
# Creating `:Chunk` node for chunk ID 50-chunk0007
# Creating `:Chunk` node for chunk ID 50-chunk0008
# Creating `:Chunk` node for chunk ID 50-chunk0009
# Creating `:Chunk` node for chunk ID 50-chunk0010
# Creating `:Chunk` node for chunk ID 50-chunk0011
# Creating `:Chunk` node for chunk ID 50-chunk0012
# Creating `:Chunk` node for chunk ID 50-chunk0013
# Creating `:Chunk` node for chunk ID 50-chunk0014
# Creating `:Chunk` node for chunk ID 51-chunk0000
# Creating `:Chunk` node for chunk ID 51-chunk0001
# Creating `:Chunk` node for chunk ID 51-chunk0002
# Creating `:Chunk` node for chunk ID 51-chunk0003
# Creating `:Chunk` node for chunk ID 51-chunk0004
# Creating `:Chunk` node for chunk ID 51-chunk0005
# Creating `:Chunk` node for chunk ID 51-chunk0006
# Creating `:Chunk` node for chunk ID 51-chunk0007
# Creating `:Chunk` node for chunk ID 51-chunk0008
# Creating `:Chunk` node for chunk ID 51-chunk0009
# Creating `:Chunk` node for chunk ID 51-chunk0010
# Creating `:Chunk` node for chunk ID 51-chunk0011
# Creating `:Chunk` node for chunk ID 51-chunk0012
# Creating `:Chunk` node for chunk ID 51-chunk0013
# Creating `:Chunk` node for chunk ID 51-chunk0014
# Creating `:Chunk` node for chunk ID 51-chunk0015
# Creating `:Chunk` node for chunk ID 51-chunk0016
# Creating `:Chunk` node for chunk ID 51-chunk0017
# Creating `:Chunk` node for chunk ID 51-chunk0018
# Creating `:Chunk` node for chunk ID 51-chunk0019
# Creating `:Chunk` node for chunk ID 51-chunk0020
# Creating `:Chunk` node for chunk ID 51-chunk0021
# Creating `:Chunk` node for chunk ID 51-chunk0022
# Creating `:Chunk` node for chunk ID 51-chunk0023
# Creating `:Chunk` node for chunk ID 51-chunk0024
# Creating `:Chunk` node for chunk ID 51-chunk0025
# Creating `:Chunk` node for chunk ID 51-chunk0026
# Creating `:Chunk` node for chunk ID 51-chunk0027
# Creating `:Chunk` node for chunk ID 51-chunk0028
# Creating `:Chunk` node for chunk ID 51-chunk0029
# Creating `:Chunk` node for chunk ID 51-chunk0030
# Creating `:Chunk` node for chunk ID 51-chunk0031
# Creating `:Chunk` node for chunk ID 51-chunk0032
# Creating `:Chunk` node for chunk ID 51-chunk0033
# Creating `:Chunk` node for chunk ID 52-chunk0000
# Creating `:Chunk` node for chunk ID 52-chunk0001
# Creating `:Chunk` node for chunk ID 52-chunk0002
# Creating `:Chunk` node for chunk ID 52-chunk0003
# Creating `:Chunk` node for chunk ID 52-chunk0004
# Creating `:Chunk` node for chunk ID 52-chunk0005
# Creating `:Chunk` node for chunk ID 52-chunk0006
# Creating `:Chunk` node for chunk ID 52-chunk0007
# Creating `:Chunk` node for chunk ID 52-chunk0008
# Creating `:Chunk` node for chunk ID 52-chunk0009
# Creating `:Chunk` node for chunk ID 52-chunk0010
# Creating `:Chunk` node for chunk ID 52-chunk0011
# Creating `:Chunk` node for chunk ID 52-chunk0012
# Creating `:Chunk` node for chunk ID 52-chunk0013
# Creating `:Chunk` node for chunk ID 52-chunk0014
# Creating `:Chunk` node for chunk ID 53-chunk0000
# Creating `:Chunk` node for chunk ID 53-chunk0001
# Creating `:Chunk` node for chunk ID 53-chunk0002
# Creating `:Chunk` node for chunk ID 53-chunk0003
# Creating `:Chunk` node for chunk ID 53-chunk0004
# Creating `:Chunk` node for chunk ID 53-chunk0005
# Creating `:Chunk` node for chunk ID 53-chunk0006
# Creating `:Chunk` node for chunk ID 53-chunk0007
# Creating `:Chunk` node for chunk ID 53-chunk0008
# Creating `:Chunk` node for chunk ID 53-chunk0009
# Creating `:Chunk` node for chunk ID 53-chunk0010
# Creating `:Chunk` node for chunk ID 53-chunk0011
# Creating `:Chunk` node for chunk ID 53-chunk0012
# Creating `:Chunk` node for chunk ID 53-chunk0013
# Creating `:Chunk` node for chunk ID 53-chunk0014
# Creating `:Chunk` node for chunk ID 54-chunk0000
# Creating `:Chunk` node for chunk ID 54-chunk0001
# Creating `:Chunk` node for chunk ID 54-chunk0002
# Creating `:Chunk` node for chunk ID 54-chunk0003
# Creating `:Chunk` node for chunk ID 54-chunk0004
# Creating `:Chunk` node for chunk ID 54-chunk0005
# Creating `:Chunk` node for chunk ID 54-chunk0006
# Creating `:Chunk` node for chunk ID 54-chunk0007
# Creating `:Chunk` node for chunk ID 54-chunk0008
# Creating `:Chunk` node for chunk ID 54-chunk0009
# Creating `:Chunk` node for chunk ID 54-chunk0010
# Creating `:Chunk` node for chunk ID 54-chunk0011
# Creating `:Chunk` node for chunk ID 54-chunk0012
# Creating `:Chunk` node for chunk ID 54-chunk0013
# Creating `:Chunk` node for chunk ID 54-chunk0014
# Creating `:Chunk` node for chunk ID 54-chunk0015
# Creating `:Chunk` node for chunk ID 54-chunk0016
# Creating `:Chunk` node for chunk ID 54-chunk0017
# Creating `:Chunk` node for chunk ID 54-chunk0018
# Creating `:Chunk` node for chunk ID 54-chunk0019
# Creating `:Chunk` node for chunk ID 54-chunk0020
# Creating `:Chunk` node for chunk ID 55-chunk0000
# Creating `:Chunk` node for chunk ID 55-chunk0001
# Creating `:Chunk` node for chunk ID 55-chunk0002
# Creating `:Chunk` node for chunk ID 55-chunk0003
# Creating `:Chunk` node for chunk ID 55-chunk0004
# Creating `:Chunk` node for chunk ID 55-chunk0005
# Creating `:Chunk` node for chunk ID 55-chunk0006
# Creating `:Chunk` node for chunk ID 55-chunk0007
# Creating `:Chunk` node for chunk ID 55-chunk0008
# Creating `:Chunk` node for chunk ID 55-chunk0009
# Creating `:Chunk` node for chunk ID 55-chunk0010
# Creating `:Chunk` node for chunk ID 55-chunk0011
# Creating `:Chunk` node for chunk ID 55-chunk0012
# Creating `:Chunk` node for chunk ID 55-chunk0013
# Creating `:Chunk` node for chunk ID 55-chunk0014
# Creating `:Chunk` node for chunk ID 55-chunk0015
# Creating `:Chunk` node for chunk ID 55-chunk0016
# Creating `:Chunk` node for chunk ID 55-chunk0017
# Creating `:Chunk` node for chunk ID 55-chunk0018
# Creating `:Chunk` node for chunk ID 55-chunk0019
# Creating `:Chunk` node for chunk ID 55-chunk0020
# Creating `:Chunk` node for chunk ID 56-chunk0000
# Creating `:Chunk` node for chunk ID 56-chunk0001
# Creating `:Chunk` node for chunk ID 56-chunk0002
# Creating `:Chunk` node for chunk ID 56-chunk0003
# Creating `:Chunk` node for chunk ID 56-chunk0004
# Creating `:Chunk` node for chunk ID 56-chunk0005
# Creating `:Chunk` node for chunk ID 56-chunk0006
# Creating `:Chunk` node for chunk ID 56-chunk0007
# Creating `:Chunk` node for chunk ID 56-chunk0008
# Creating `:Chunk` node for chunk ID 57-chunk0000
# Creating `:Chunk` node for chunk ID 57-chunk0001
# Creating `:Chunk` node for chunk ID 57-chunk0002
# Creating `:Chunk` node for chunk ID 57-chunk0003
# Creating `:Chunk` node for chunk ID 57-chunk0004
# Creating `:Chunk` node for chunk ID 57-chunk0005
# Creating `:Chunk` node for chunk ID 57-chunk0006
# Creating `:Chunk` node for chunk ID 57-chunk0007
# Creating `:Chunk` node for chunk ID 57-chunk0008
# Creating `:Chunk` node for chunk ID 57-chunk0009
# Creating `:Chunk` node for chunk ID 57-chunk0010
# Creating `:Chunk` node for chunk ID 57-chunk0011
# Creating `:Chunk` node for chunk ID 57-chunk0012
# Creating `:Chunk` node for chunk ID 57-chunk0013
# Creating `:Chunk` node for chunk ID 57-chunk0014
# Creating `:Chunk` node for chunk ID 57-chunk0015
# Creating `:Chunk` node for chunk ID 57-chunk0016
# Creating `:Chunk` node for chunk ID 57-chunk0017
# Creating `:Chunk` node for chunk ID 57-chunk0018
# Creating `:Chunk` node for chunk ID 57-chunk0019
# Creating `:Chunk` node for chunk ID 58-chunk0000
# Creating `:Chunk` node for chunk ID 58-chunk0001
# Creating `:Chunk` node for chunk ID 58-chunk0002
# Creating `:Chunk` node for chunk ID 58-chunk0003
# Creating `:Chunk` node for chunk ID 58-chunk0004
# Creating `:Chunk` node for chunk ID 58-chunk0005
# Creating `:Chunk` node for chunk ID 58-chunk0006
# Creating `:Chunk` node for chunk ID 58-chunk0007
# Creating `:Chunk` node for chunk ID 58-chunk0008
# Creating `:Chunk` node for chunk ID 58-chunk0009
# Creating `:Chunk` node for chunk ID 58-chunk0010
# Creating `:Chunk` node for chunk ID 58-chunk0011
# Creating `:Chunk` node for chunk ID 59-chunk0000
# Creating `:Chunk` node for chunk ID 59-chunk0001
# Creating `:Chunk` node for chunk ID 59-chunk0002
# Creating `:Chunk` node for chunk ID 59-chunk0003
# Creating `:Chunk` node for chunk ID 59-chunk0004
# Creating `:Chunk` node for chunk ID 59-chunk0005
# Creating `:Chunk` node for chunk ID 59-chunk0006
# Creating `:Chunk` node for chunk ID 59-chunk0007
# ...
# Creating `:Chunk` node for chunk ID 213-chunk0011
# Creating `:Chunk` node for chunk ID 213-chunk0012
# Creating `:Chunk` node for chunk ID 213-chunk0013
# Creating `:Chunk` node for chunk ID 213-chunk0014
# Creating `:Chunk` node for chunk ID 214-chunk0000
# Creating `:Chunk` node for chunk ID 214-chunk0001
# Creating `:Chunk` node for chunk ID 214-chunk0002
# Creating `:Chunk` node for chunk ID 214-chunk0003
# Creating `:Chunk` node for chunk ID 214-chunk0004
# Creating `:Chunk` node for chunk ID 214-chunk0005
# Creating `:Chunk` node for chunk ID 214-chunk0006
# Creating `:Chunk` node for chunk ID 214-chunk0007
# Creating `:Chunk` node for chunk ID 214-chunk0008
# Creating `:Chunk` node for chunk ID 214-chunk0009
# Creating `:Chunk` node for chunk ID 214-chunk0010
# Creating `:Chunk` node for chunk ID 214-chunk0011
# Creating `:Chunk` node for chunk ID 214-chunk0012
# Creating `:Chunk` node for chunk ID 214-chunk0013
# Creating `:Chunk` node for chunk ID 214-chunk0014
# Creating `:Chunk` node for chunk ID 214-chunk0015
# Creating `:Chunk` node for chunk ID 215-chunk0000
# Creating `:Chunk` node for chunk ID 215-chunk0001
# Creating `:Chunk` node for chunk ID 215-chunk0002
# Creating `:Chunk` node for chunk ID 215-chunk0003
# Creating `:Chunk` node for chunk ID 215-chunk0004
# Creating `:Chunk` node for chunk ID 215-chunk0005
# Creating `:Chunk` node for chunk ID 215-chunk0006
# Creating `:Chunk` node for chunk ID 215-chunk0007
# Creating `:Chunk` node for chunk ID 215-chunk0008
# Creating `:Chunk` node for chunk ID 215-chunk0009
# Creating `:Chunk` node for chunk ID 215-chunk0010
# Creating `:Chunk` node for chunk ID 215-chunk0011
# Creating `:Chunk` node for chunk ID 215-chunk0012
# Creating `:Chunk` node for chunk ID 215-chunk0013
# Creating `:Chunk` node for chunk ID 215-chunk0014
# Creating `:Chunk` node for chunk ID 215-chunk0015
# Creating `:Chunk` node for chunk ID 215-chunk0016
# Creating `:Chunk` node for chunk ID 216-chunk0000
# Creating `:Chunk` node for chunk ID 216-chunk0001
# Creating `:Chunk` node for chunk ID 216-chunk0002
# Creating `:Chunk` node for chunk ID 216-chunk0003
# Creating `:Chunk` node for chunk ID 216-chunk0004
# Creating `:Chunk` node for chunk ID 216-chunk0005
# Creating `:Chunk` node for chunk ID 216-chunk0006
# Creating `:Chunk` node for chunk ID 216-chunk0007
# Creating `:Chunk` node for chunk ID 216-chunk0008
# Creating `:Chunk` node for chunk ID 216-chunk0009
# Creating `:Chunk` node for chunk ID 216-chunk0010
# Creating `:Chunk` node for chunk ID 216-chunk0011
# Creating `:Chunk` node for chunk ID 217-chunk0000
# Creating `:Chunk` node for chunk ID 217-chunk0001
# Creating `:Chunk` node for chunk ID 217-chunk0002
# Creating `:Chunk` node for chunk ID 217-chunk0003
# Creating `:Chunk` node for chunk ID 217-chunk0004
# Creating `:Chunk` node for chunk ID 218-chunk0000
# Creating `:Chunk` node for chunk ID 218-chunk0001
# Creating `:Chunk` node for chunk ID 218-chunk0002
# Creating `:Chunk` node for chunk ID 218-chunk0003
# Creating `:Chunk` node for chunk ID 218-chunk0004
# Creating `:Chunk` node for chunk ID 218-chunk0005
# Creating `:Chunk` node for chunk ID 218-chunk0006
# Creating `:Chunk` node for chunk ID 218-chunk0007
# Creating `:Chunk` node for chunk ID 218-chunk0008
# Creating `:Chunk` node for chunk ID 218-chunk0009
# Creating `:Chunk` node for chunk ID 218-chunk0010
# Creating `:Chunk` node for chunk ID 218-chunk0011
# Creating `:Chunk` node for chunk ID 218-chunk0012
# Creating `:Chunk` node for chunk ID 218-chunk0013
# Creating `:Chunk` node for chunk ID 219-chunk0000
# Creating `:Chunk` node for chunk ID 219-chunk0001
# Creating `:Chunk` node for chunk ID 219-chunk0002
# Creating `:Chunk` node for chunk ID 219-chunk0003
# Creating `:Chunk` node for chunk ID 219-chunk0004
# Creating `:Chunk` node for chunk ID 219-chunk0005
# Creating `:Chunk` node for chunk ID 219-chunk0006
# Creating `:Chunk` node for chunk ID 219-chunk0007
# Creating `:Chunk` node for chunk ID 219-chunk0008
# Creating `:Chunk` node for chunk ID 219-chunk0009
# Creating `:Chunk` node for chunk ID 219-chunk0010
# Creating `:Chunk` node for chunk ID 219-chunk0011
# Creating `:Chunk` node for chunk ID 219-chunk0012
# Creating `:Chunk` node for chunk ID 219-chunk0013
# Creating `:Chunk` node for chunk ID 219-chunk0014
# Creating `:Chunk` node for chunk ID 219-chunk0015
# Creating `:Chunk` node for chunk ID 219-chunk0016
# Creating `:Chunk` node for chunk ID 220-chunk0000
# Creating `:Chunk` node for chunk ID 220-chunk0001
# Creating `:Chunk` node for chunk ID 220-chunk0002
# Creating `:Chunk` node for chunk ID 220-chunk0003
# Creating `:Chunk` node for chunk ID 220-chunk0004
# Creating `:Chunk` node for chunk ID 220-chunk0005
# Creating `:Chunk` node for chunk ID 220-chunk0006
# Creating `:Chunk` node for chunk ID 220-chunk0007
# Creating `:Chunk` node for chunk ID 220-chunk0008
# Creating `:Chunk` node for chunk ID 220-chunk0009
# Creating `:Chunk` node for chunk ID 220-chunk0010
# Creating `:Chunk` node for chunk ID 220-chunk0011
# Creating `:Chunk` node for chunk ID 220-chunk0012
# Creating `:Chunk` node for chunk ID 220-chunk0013
# Creating `:Chunk` node for chunk ID 220-chunk0014
# Creating `:Chunk` node for chunk ID 220-chunk0015
# Creating `:Chunk` node for chunk ID 220-chunk0016
# Creating `:Chunk` node for chunk ID 220-chunk0017
# Creating `:Chunk` node for chunk ID 220-chunk0018
# Creating `:Chunk` node for chunk ID 220-chunk0019
# Creating `:Chunk` node for chunk ID 221-chunk0000
# Creating `:Chunk` node for chunk ID 221-chunk0001
# Creating `:Chunk` node for chunk ID 221-chunk0002
# Creating `:Chunk` node for chunk ID 221-chunk0003
# Creating `:Chunk` node for chunk ID 221-chunk0004
# Creating `:Chunk` node for chunk ID 221-chunk0005
# Creating `:Chunk` node for chunk ID 221-chunk0006
# Creating `:Chunk` node for chunk ID 221-chunk0007
# Creating `:Chunk` node for chunk ID 221-chunk0008
# Creating `:Chunk` node for chunk ID 221-chunk0009
# Creating `:Chunk` node for chunk ID 221-chunk0010
# Creating `:Chunk` node for chunk ID 221-chunk0011
# Creating `:Chunk` node for chunk ID 221-chunk0012
# Creating `:Chunk` node for chunk ID 221-chunk0013
# Creating `:Chunk` node for chunk ID 222-chunk0000
# Creating `:Chunk` node for chunk ID 222-chunk0001
# Creating `:Chunk` node for chunk ID 222-chunk0002
# Creating `:Chunk` node for chunk ID 222-chunk0003
# Creating `:Chunk` node for chunk ID 222-chunk0004
# Creating `:Chunk` node for chunk ID 222-chunk0005
# Creating `:Chunk` node for chunk ID 222-chunk0006
# Creating `:Chunk` node for chunk ID 222-chunk0007
# Creating `:Chunk` node for chunk ID 222-chunk0008
# Creating `:Chunk` node for chunk ID 222-chunk0009
# Creating `:Chunk` node for chunk ID 222-chunk0010
# Creating `:Chunk` node for chunk ID 222-chunk0011
# Creating `:Chunk` node for chunk ID 222-chunk0012
# Creating `:Chunk` node for chunk ID 223-chunk0000
# Creating `:Chunk` node for chunk ID 223-chunk0001
# Creating `:Chunk` node for chunk ID 223-chunk0002
# Creating `:Chunk` node for chunk ID 223-chunk0003
# Creating `:Chunk` node for chunk ID 223-chunk0004
# Creating `:Chunk` node for chunk ID 223-chunk0005
# Creating `:Chunk` node for chunk ID 223-chunk0006
# Creating `:Chunk` node for chunk ID 223-chunk0007
# Creating `:Chunk` node for chunk ID 223-chunk0008
# Creating `:Chunk` node for chunk ID 223-chunk0009
# Creating `:Chunk` node for chunk ID 223-chunk0010
# Creating `:Chunk` node for chunk ID 223-chunk0011
# Creating `:Chunk` node for chunk ID 223-chunk0012
# Creating `:Chunk` node for chunk ID 223-chunk0013
# Creating `:Chunk` node for chunk ID 223-chunk0014
# Creating `:Chunk` node for chunk ID 223-chunk0015
# Creating `:Chunk` node for chunk ID 223-chunk0016
# Creating `:Chunk` node for chunk ID 224-chunk0000
# Creating `:Chunk` node for chunk ID 224-chunk0001
# Creating `:Chunk` node for chunk ID 224-chunk0002
# Creating `:Chunk` node for chunk ID 224-chunk0003
# Creating `:Chunk` node for chunk ID 224-chunk0004
# Creating `:Chunk` node for chunk ID 224-chunk0005
# Creating `:Chunk` node for chunk ID 224-chunk0006
# Creating `:Chunk` node for chunk ID 224-chunk0007
# Creating `:Chunk` node for chunk ID 224-chunk0008
# Creating `:Chunk` node for chunk ID 224-chunk0009
# Creating `:Chunk` node for chunk ID 224-chunk0010
# Creating `:Chunk` node for chunk ID 224-chunk0011
# Creating `:Chunk` node for chunk ID 224-chunk0012
# Creating `:Chunk` node for chunk ID 224-chunk0013
# Creating `:Chunk` node for chunk ID 224-chunk0014
# Creating `:Chunk` node for chunk ID 224-chunk0015
# Creating `:Chunk` node for chunk ID 224-chunk0016
# Creating `:Chunk` node for chunk ID 225-chunk0000
# Creating `:Chunk` node for chunk ID 225-chunk0001
# Creating `:Chunk` node for chunk ID 225-chunk0002
# Creating `:Chunk` node for chunk ID 225-chunk0003
# Creating `:Chunk` node for chunk ID 225-chunk0004
# Creating `:Chunk` node for chunk ID 225-chunk0005
# Creating `:Chunk` node for chunk ID 225-chunk0006
# Creating `:Chunk` node for chunk ID 225-chunk0007
# Creating `:Chunk` node for chunk ID 225-chunk0008
# Creating `:Chunk` node for chunk ID 225-chunk0009
# Creating `:Chunk` node for chunk ID 225-chunk0010
# Creating `:Chunk` node for chunk ID 225-chunk0011
# Creating `:Chunk` node for chunk ID 225-chunk0012
# Creating `:Chunk` node for chunk ID 225-chunk0013
# Creating `:Chunk` node for chunk ID 226-chunk0000
# Creating `:Chunk` node for chunk ID 226-chunk0001
# Creating `:Chunk` node for chunk ID 226-chunk0002
# Creating `:Chunk` node for chunk ID 226-chunk0003
# Creating `:Chunk` node for chunk ID 226-chunk0004
# Creating `:Chunk` node for chunk ID 226-chunk0005
# Creating `:Chunk` node for chunk ID 226-chunk0006
# Creating `:Chunk` node for chunk ID 226-chunk0007
# Creating `:Chunk` node for chunk ID 226-chunk0008
# Creating `:Chunk` node for chunk ID 226-chunk0009
# Creating `:Chunk` node for chunk ID 227-chunk0000
# Creating `:Chunk` node for chunk ID 227-chunk0001
# Creating `:Chunk` node for chunk ID 227-chunk0002
# Creating `:Chunk` node for chunk ID 227-chunk0003
# Creating `:Chunk` node for chunk ID 227-chunk0004
# Creating `:Chunk` node for chunk ID 227-chunk0005
# Creating `:Chunk` node for chunk ID 227-chunk0006
# Creating `:Chunk` node for chunk ID 227-chunk0007
# Creating `:Chunk` node for chunk ID 227-chunk0008
# Creating `:Chunk` node for chunk ID 227-chunk0009
# Creating `:Chunk` node for chunk ID 227-chunk0010
# Creating `:Chunk` node for chunk ID 228-chunk0000
# Creating `:Chunk` node for chunk ID 228-chunk0001
# Creating `:Chunk` node for chunk ID 228-chunk0002
# Creating `:Chunk` node for chunk ID 228-chunk0003
# Creating `:Chunk` node for chunk ID 228-chunk0004
# Creating `:Chunk` node for chunk ID 228-chunk0005
# Creating `:Chunk` node for chunk ID 228-chunk0006
# Creating `:Chunk` node for chunk ID 228-chunk0007
# Creating `:Chunk` node for chunk ID 228-chunk0008
# Creating `:Chunk` node for chunk ID 228-chunk0009
# Creating `:Chunk` node for chunk ID 228-chunk0010
# Creating `:Chunk` node for chunk ID 228-chunk0011
# Creating `:Chunk` node for chunk ID 229-chunk0000
# Creating `:Chunk` node for chunk ID 229-chunk0001
# Creating `:Chunk` node for chunk ID 229-chunk0002
# Creating `:Chunk` node for chunk ID 229-chunk0003
# Creating `:Chunk` node for chunk ID 229-chunk0004
# Creating `:Chunk` node for chunk ID 229-chunk0005
# Creating `:Chunk` node for chunk ID 229-chunk0006
# Creating `:Chunk` node for chunk ID 229-chunk0007
# Creating `:Chunk` node for chunk ID 229-chunk0008
# Creating `:Chunk` node for chunk ID 230-chunk0000
# Creating `:Chunk` node for chunk ID 230-chunk0001
# Creating `:Chunk` node for chunk ID 230-chunk0002
# Creating `:Chunk` node for chunk ID 230-chunk0003
# Creating `:Chunk` node for chunk ID 230-chunk0004
# Creating `:Chunk` node for chunk ID 230-chunk0005
# Creating `:Chunk` node for chunk ID 230-chunk0006
# Creating `:Chunk` node for chunk ID 230-chunk0007
# Creating `:Chunk` node for chunk ID 231-chunk0000
# Creating `:Chunk` node for chunk ID 231-chunk0001
# Creating `:Chunk` node for chunk ID 231-chunk0002
# Creating `:Chunk` node for chunk ID 231-chunk0003
# Creating `:Chunk` node for chunk ID 231-chunk0004
# Creating `:Chunk` node for chunk ID 231-chunk0005
# Creating `:Chunk` node for chunk ID 231-chunk0006
# Creating `:Chunk` node for chunk ID 231-chunk0007
# Creating `:Chunk` node for chunk ID 231-chunk0008
# Creating `:Chunk` node for chunk ID 231-chunk0009
# Creating `:Chunk` node for chunk ID 231-chunk0010
# Creating `:Chunk` node for chunk ID 231-chunk0011
# Creating `:Chunk` node for chunk ID 231-chunk0012
# Creating `:Chunk` node for chunk ID 231-chunk0013
# Creating `:Chunk` node for chunk ID 231-chunk0014
# Creating `:Chunk` node for chunk ID 231-chunk0015
# Creating `:Chunk` node for chunk ID 232-chunk0000
# Creating `:Chunk` node for chunk ID 232-chunk0001
# Creating `:Chunk` node for chunk ID 232-chunk0002
# Creating `:Chunk` node for chunk ID 232-chunk0003
# Creating `:Chunk` node for chunk ID 232-chunk0004
# Creating `:Chunk` node for chunk ID 232-chunk0005
# Creating `:Chunk` node for chunk ID 232-chunk0006
# Creating `:Chunk` node for chunk ID 232-chunk0007
# Creating `:Chunk` node for chunk ID 232-chunk0008
# Creating `:Chunk` node for chunk ID 232-chunk0009
# Creating `:Chunk` node for chunk ID 232-chunk0010
# Creating `:Chunk` node for chunk ID 232-chunk0011
# Creating `:Chunk` node for chunk ID 232-chunk0012
# Creating `:Chunk` node for chunk ID 232-chunk0013
# Creating `:Chunk` node for chunk ID 232-chunk0014
# Creating `:Chunk` node for chunk ID 232-chunk0015
# Creating `:Chunk` node for chunk ID 232-chunk0016
# Creating `:Chunk` node for chunk ID 233-chunk0000
# Creating `:Chunk` node for chunk ID 233-chunk0001
# Creating `:Chunk` node for chunk ID 233-chunk0002
# Creating `:Chunk` node for chunk ID 233-chunk0003
# Creating `:Chunk` node for chunk ID 233-chunk0004
# Creating `:Chunk` node for chunk ID 233-chunk0005
# Creating `:Chunk` node for chunk ID 233-chunk0006
# Creating `:Chunk` node for chunk ID 233-chunk0007
# Creating `:Chunk` node for chunk ID 234-chunk0000
# Creating `:Chunk` node for chunk ID 234-chunk0001
# Creating `:Chunk` node for chunk ID 234-chunk0002
# Creating `:Chunk` node for chunk ID 234-chunk0003
# Creating `:Chunk` node for chunk ID 234-chunk0004
# Creating `:Chunk` node for chunk ID 234-chunk0005
# Creating `:Chunk` node for chunk ID 234-chunk0006
# Creating `:Chunk` node for chunk ID 234-chunk0007
# Creating `:Chunk` node for chunk ID 234-chunk0008
# Creating `:Chunk` node for chunk ID 234-chunk0009
# Creating `:Chunk` node for chunk ID 234-chunk0010
# Creating `:Chunk` node for chunk ID 234-chunk0011
# Creating `:Chunk` node for chunk ID 234-chunk0012
# Creating `:Chunk` node for chunk ID 234-chunk0013
# Creating `:Chunk` node for chunk ID 234-chunk0014
# Creating `:Chunk` node for chunk ID 234-chunk0015
# Creating `:Chunk` node for chunk ID 234-chunk0016
# Creating `:Chunk` node for chunk ID 234-chunk0017
# Creating `:Chunk` node for chunk ID 235-chunk0000
# Creating `:Chunk` node for chunk ID 235-chunk0001
# Creating `:Chunk` node for chunk ID 235-chunk0002
# Creating `:Chunk` node for chunk ID 235-chunk0003
# Creating `:Chunk` node for chunk ID 235-chunk0004
# Creating `:Chunk` node for chunk ID 235-chunk0005
# Creating `:Chunk` node for chunk ID 235-chunk0006
# Creating `:Chunk` node for chunk ID 236-chunk0000
# Creating `:Chunk` node for chunk ID 236-chunk0001
# Creating `:Chunk` node for chunk ID 236-chunk0002
# Creating `:Chunk` node for chunk ID 236-chunk0003
# Creating `:Chunk` node for chunk ID 236-chunk0004
# Creating `:Chunk` node for chunk ID 236-chunk0005
# Creating `:Chunk` node for chunk ID 236-chunk0006
# Creating `:Chunk` node for chunk ID 237-chunk0000
# Creating `:Chunk` node for chunk ID 237-chunk0001
# Creating `:Chunk` node for chunk ID 237-chunk0002
# Creating `:Chunk` node for chunk ID 237-chunk0003
# Creating `:Chunk` node for chunk ID 237-chunk0004
# Creating `:Chunk` node for chunk ID 237-chunk0005
# Creating `:Chunk` node for chunk ID 237-chunk0006
# Creating `:Chunk` node for chunk ID 237-chunk0007
# Creating `:Chunk` node for chunk ID 237-chunk0008
# Creating `:Chunk` node for chunk ID 238-chunk0000
# Creating `:Chunk` node for chunk ID 238-chunk0001
# Creating `:Chunk` node for chunk ID 238-chunk0002
# Creating `:Chunk` node for chunk ID 238-chunk0003
# Creating `:Chunk` node for chunk ID 238-chunk0004
# Creating `:Chunk` node for chunk ID 238-chunk0005
# Creating `:Chunk` node for chunk ID 238-chunk0006
# Created 4020 nodes

# %%
emd = kg.query("""
              MATCH (chunk:Chunk)
              RETURN chunk.chunkId AS id, chunk.textEmbedding AS emb""")

# %%
emd

# %% [markdown]
# # Vector Similarity Search
#
# With the vector database, we can perform search based on embeddings.

# %%
VECTOR_INDEX_NAME = 'vector_chunks'
def neo4j_vector_search(question):
  question_embedding = get_embeddings(question)[0]
  """Search for similar nodes using the Neo4j vector index"""
  vector_search_query = """
    CALL db.index.vector.queryNodes($index_name, $top_k, $question_embedding) yield node, score
    RETURN score, node.title AS title, node.text AS text
  """
  similar = kg.query(vector_search_query,
                     params={
                      'question': question,
                      'question_embedding': question_embedding,
                      'index_name':VECTOR_INDEX_NAME,
                      'top_k': 3})
  return similar

# %%
search_results = neo4j_vector_search(
    'Ansvarlig KI er hele organisasjonen sitt ansvar'
)
search_results
# Out:
# [{'score': 0.7677822113037109,
#   'title': 'Ansvarlig KI er hele organisasjonen sitt ansvar!.json',
#   'text': 'lenger. I Kantega har vi sett at det ofte er andre aspekter rundt utvikling av KI som smerter mest. Ansvarlig KIVi som har KI som vårt fagfelt i Kantega har de siste årene jobbet mye med temaet ansvarlig KI. Vi ønsker at oppdragene og prosjektene vi jobber i skal utføres på en måte som gir en trygghet og tillit i resten av organisasjonen. Det skal være åpenhet og transparens i det vi gjør.I denne artikkelen ønsker vi derfor å trekke fram sentrale elementer for å sikre at vi lager ansvarlig KI.Figuren over'},
#  {'score': 0.7663803100585938,
#   'title': 'Ansvarlig KI er hele organisasjonen sitt ansvar!.json',
#   'text': 'for å sikre at vi lager ansvarlig KI.Figuren over viser en typisk syklus for et data science-prosjekt. Hvis vi ser på de ulike boksene, forstår vi at dette ikke er noe som kun berører data scientister, men derimot hele organisasjonen.På samme måte som at et data science-prosjekt omfatter hele organisasjonen, er ansvarlig KI også noe hele organisasjonen har ansvaret for. I seksjonene under presenterer vi hvilke grep som bør gjøres i de ulike stadiene for å gjennomføre KI-prosjekter på en ansvarlig og trygg'},
#  {'score': 0.7634849548339844,
#   'title': 'Mitt prosjekt er viktigere enn ditt.json',
#   'text': 'både for deg selv og for dem som må ta den endelige avgjørelsen.Kontroll med helheten behøver ikke å bety at du blir diktert eller overstyrtNår jeg bruker begrepet styring i dette innlegget, er det i betydningen at virksomheten har «en nødvendig kontroll med helheten». Du som avdelingsleder er del av virksomheten og av denne helheten, men kontroll med helheten behøver ikke å bety at du blir diktert eller overstyrt. Tvert imot skal «styringen» ta opp i seg ditt syn på bedriftens beste, og du selv får delta'}]
